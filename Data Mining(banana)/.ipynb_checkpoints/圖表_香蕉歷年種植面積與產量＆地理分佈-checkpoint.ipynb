# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
import json
import re
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv("cleaned data/產量_臺灣香蕉生產概況(2011~2019).csv")
df
# Out:
#        年度  地區別 果品類別     種植株數     收穫株數  種植面積_公頃  收穫面積_公頃  每株平均產量_公斤  \
# 0    2019  新北市   香蕉   108619   102262    74.99    71.01      13.74
# 1    2019  台北市   香蕉    12830    12830    10.36    10.36      12.55
# 2    2019  桃園市   香蕉    44420    43940    57.11    56.47      18.85
# 3    2019  台中市   香蕉   574129   560455   629.71   614.39      15.54
# 4    2019  台南市   香蕉  1481610  1476420  1062.65  1057.46      16.26
# ..    ...  ...  ...      ...      ...      ...      ...        ...
# 193  2011  基隆市   香蕉     3786     3786     3.57     3.57       9.22
# 194  2011  新竹市   香蕉     8802     8802     5.64     5.64      14.38
# 195  2011  嘉義市   香蕉    79710    79710    53.14    53.14      12.05
# 196  2011  金門縣   香蕉        0        0     0.00     0.00       0.00
# 197  2011  連江縣   香蕉        0        0     0.00     0.00       0.00
#
#      每公頃平均產量_公斤     產量_公噸
# 0      19793.48   1405.54
# 1      15543.15    161.03
# 2      14666.65    828.23
# 3      14178.52   8711.14
# 4      22703.58  24008.13
# ..          ...       ...
# 193     9782.07     34.92
# 194    22448.58    126.61
# 195    18081.60    960.86
# 196        0.00      0.00
# 197        0.00      0.00
#
# [198 rows x 10 columns]

# %% [markdown]
# ### 選取欲使用欄位

# %%
cols = ['年度', '地區別', '果品類別', '種植面積_公頃', '收穫面積_公頃', '產量_公噸']
df_test = df[cols]

# %%
df_test.dtypes
# Out:
# 年度           int64
# 地區別         object
# 果品類別        object
# 種植面積_公頃    float64
# 收穫面積_公頃    float64
# 產量_公噸      float64
# dtype: object

# %% [markdown]
# ### 輔助圖表(2011~2019變化)

# %% [markdown]
# #### 總產量趨勢圖

# %%
df.groupby("年度").sum()
# Out:
#           種植株數      收穫株數   種植面積_公頃   收穫面積_公頃  每株平均產量_公斤  每公頃平均產量_公斤      產量_公噸
# 年度
# 2011  20971974  20103612  13788.32  13257.18     293.62   400678.97  305739.59
# 2012  20039523  19547136  13248.75  12947.23     291.23   403129.56  295264.57
# 2013  20195626  19699616  13343.58  13042.40     288.76   394175.80  291292.49
# 2014  21344675  20135253  13997.00  13290.00     285.00   390040.00  299899.00
# 2015  22264196  21397948  14605.44  14093.10     253.56   346563.41  274066.17
# 2016  24459685  23919663  16016.25  15697.01     233.32   317470.19  257558.68
# 2017  25802954  24104244  16841.64  15803.75     289.83   404807.01  356016.97
# 2018  25649008  23597696  16640.00  15447.00     311.00   437199.00  356238.00
# 2019  24994633  22625433  16341.72  14913.99     308.59   434114.19  342628.59

# %%
x = np.arange(2011, 2020)
y = df.groupby("年度").sum()

# %%
fig, ax1 = plt.subplots(figsize=(8,6))

width = 0.2
ax1.set_xticks(x)
ax1.plot(x, y["產量_公噸"], "--", marker="o", color="black")
ax1.set_xlabel("Year")
ax1.set_ylabel("Production(ton)", color="black")
ax1.tick_params(axis="y", labelcolor="black")

ax2 = ax1.twinx()
ax2.bar(x-width, y["種植面積_公頃"], width=0.4, alpha=0.4, label="planted area")
ax2.bar(x+width, y["收穫面積_公頃"], width=0.4, alpha=0.4, label="harvested area")
ax2.set_ylabel("Area(hectare)", color="blue")
ax2.tick_params(axis="y", labelcolor="blue")

fig.tight_layout()
plt.title("Banana Area & Proudction")
plt.legend()
# plt.savefig("banana area & production.jpg", bbox_inches="tight")
plt.show()

# %%
df.dtypes
# Out:
# 年度              int64
# 地區別            object
# 果品類別           object
# 種植株數            int64
# 收穫株數            int64
# 種植面積_公頃       float64
# 收穫面積_公頃       float64
# 每株平均產量_公斤     float64
# 每公頃平均產量_公斤    float64
# 產量_公噸         float64
# dtype: object

# %% [markdown]
# ### 取得2019年度全國香蕉生產資料

# %%
data = df.loc[(df["年度"] == 2019)]
data
# Out:
#       年度  地區別 果品類別     種植株數     收穫株數  種植面積_公頃  收穫面積_公頃  每株平均產量_公斤  每公頃平均產量_公斤  \
# 0   2019  新北市   香蕉   108619   102262    74.99    71.01      13.74    19793.48
# 1   2019  台北市   香蕉    12830    12830    10.36    10.36      12.55    15543.15
# 2   2019  桃園市   香蕉    44420    43940    57.11    56.47      18.85    14666.65
# 3   2019  台中市   香蕉   574129   560455   629.71   614.39      15.54    14178.52
# 4   2019  台南市   香蕉  1481610  1476420  1062.65  1057.46      16.26    22703.58
# 5   2019  高雄市   香蕉  3874181  3806097  2155.98  2117.37      13.76    24739.26
# 6   2019  宜蘭縣   香蕉   170454   168384   114.10   112.72      18.05    26956.74
# 7   2019  新竹縣   香蕉   154451   153659   107.42   106.89      12.28    17655.75
# 8   2019  苗栗縣   香蕉   151576   151576   115.54   115.54      19.05    24988.74
# 9   2019  彰化縣   香蕉   197594   194955   132.91   131.20      16.22    24100.68
# 10  2019  南投縣   香蕉  3817700  3803870  3118.81  3108.11      15.67    19174.86
# 11  2019  雲林縣   香蕉  1218031  1103495   674.57   613.61      16.51    29696.71
# 12  2019  嘉義縣   香蕉  4160750  4082037  2658.58  2608.03      14.65    22923.44
# 13  2019  屏東縣   香蕉  7059538  5510250  4124.81  3219.63      15.65    26783.11
# 14  2019  台東縣   香蕉   826426   796771   559.82   539.79      14.45    21323.32
# 15  2019  花蓮縣   香蕉  1049888   567244   681.87   369.72      13.20    20251.62
# 16  2019  澎湖縣   香蕉     2571     2571     2.60     2.60      16.47    16286.92
# 17  2019  基隆市   香蕉     5228     5228     3.98     3.98       9.57    12575.63
# 18  2019  新竹市   香蕉     9597     8349     6.15     5.35      10.91    17021.50
# 19  2019  嘉義市   香蕉    73440    73440    48.96    48.96      15.31    22958.03
# 20  2019  金門縣   香蕉     1600     1600     0.80     0.80       9.90    19792.50
# 21  2019  連江縣   香蕉        0        0     0.00     0.00       0.00        0.00
#
#        產量_公噸
# 0    1405.54
# 1     161.03
# 2     828.23
# 3    8711.14
# 4   24008.13
# 5   52382.17
# 6    3038.56
# 7    1887.22
# 8    2887.20
# 9    3162.01
# 10  59597.58
# 11  18222.20
# 12  59785.02
# 13  86231.69
# 14  11510.12
# 15   7487.43
# 16     42.35
# 17     50.05
# 18     91.06
# 19   1124.03
# 20     15.83
# 21      0.00

# %%
df_2019 = data[["地區別", "果品類別", "產量_公噸"]].sort_values(by="產量_公噸", ascending=False)

# %%
df_2019["地區別"] = df_2019["地區別"].str.replace("台", "臺")

# %%
df_2019.columns = ["COUNTYNAME","fruits", "production"]

# %%
df_2019.reset_index(drop=True, inplace=True)

# %%
df_2019
# Out:
#    COUNTYNAME fruits  production
# 0         屏東縣     香蕉    86231.69
# 1         嘉義縣     香蕉    59785.02
# 2         南投縣     香蕉    59597.58
# 3         高雄市     香蕉    52382.17
# 4         臺南市     香蕉    24008.13
# 5         雲林縣     香蕉    18222.20
# 6         臺東縣     香蕉    11510.12
# 7         臺中市     香蕉     8711.14
# 8         花蓮縣     香蕉     7487.43
# 9         彰化縣     香蕉     3162.01
# 10        宜蘭縣     香蕉     3038.56
# 11        苗栗縣     香蕉     2887.20
# 12        新竹縣     香蕉     1887.22
# 13        新北市     香蕉     1405.54
# 14        嘉義市     香蕉     1124.03
# 15        桃園市     香蕉      828.23
# 16        臺北市     香蕉      161.03
# 17        新竹市     香蕉       91.06
# 18        基隆市     香蕉       50.05
# 19        澎湖縣     香蕉       42.35
# 20        金門縣     香蕉       15.83
# 21        連江縣     香蕉        0.00

# %% [markdown]
# ## 透過GeoPandas將上面的結果顯示於地圖

# %% [markdown]
# ### 從政府資料開放平台取得台灣縣市行政圖的邊界&經緯度
#
# [台灣縣市地圖](https://data.gov.tw/dataset/7441)

# %%
city_shp = gpd.read_file("geopandas use/mapdata202008310842/COUNTY_MOI_1090820.shp", encoding="utf-8")

# %%
city_shp
# Out:
#    COUNTYID COUNTYCODE COUNTYNAME          COUNTYENG  \
# 0         Z      09007        連江縣  Lienchiang County
# 1         G      10002        宜蘭縣       Yilan County
# 2         N      10007        彰化縣    Changhua County
# 3         M      10008        南投縣      Nantou County
# 4         P      10009        雲林縣      Yunlin County
# 5         C      10017        基隆市       Keelung City
# 6         A      63000        臺北市        Taipei City
# 7         F      65000        新北市    New Taipei City
# 8         B      66000        臺中市      Taichung City
# 9         D      67000        臺南市        Tainan City
# 10        H      68000        桃園市       Taoyuan City
# 11        K      10005        苗栗縣      Miaoli County
# 12        I      10020        嘉義市        Chiayi City
# 13        Q      10010        嘉義縣      Chiayi County
# 14        W      09020        金門縣      Kinmen County
# 15        E      64000        高雄市     Kaohsiung City
# 16        V      10014        臺東縣     Taitung County
# 17        U      10015        花蓮縣     Hualien County
# 18        X      10016        澎湖縣      Penghu County
# 19        O      10018        新竹市       Hsinchu City
# 20        J      10004        新竹縣     Hsinchu County
# 21        T      10013        屏東縣    Pingtung County
#
#                                              geometry
# 0   MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1   MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2   POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3   POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4   MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 5   MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...
# 6   POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 7   POLYGON ((121.53752 25.30003, 121.53768 25.300...
# 8   POLYGON ((121.32834 24.43304, 121.32845 24.432...
# 9   POLYGON ((120.44025 23.41308, 120.44040 23.413...
# 10  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 11  POLYGON ((121.00820 24.64432, 121.00828 24.644...
# 12  POLYGON ((120.44758 23.51819, 120.44767 23.518...
# 13  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...
# 14  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...
# 15  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...
# 16  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 17  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 18  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...
# 19  POLYGON ((120.92532 24.85478, 120.92545 24.854...
# 20  POLYGON ((121.03813 24.94638, 121.03822 24.946...
# 21  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...

# %% [markdown]
# ### 台灣地圖

# %%
fig,ax = plt.subplots(figsize = (10, 10))
city_shp.plot(ax=ax, color="grey") #cmap="RdBu")

ax.set_xlim(117,123)
ax.set_ylim(21,26)
# Out:
# (21.0, 26.0)

# %% [markdown]
# ### 將df_2019banana資料與city_shp進行merge

# %%
whole_data = pd.merge(city_shp, df_2019, on="COUNTYNAME", how="left")

# %%
whole_data
# Out:
#    COUNTYID COUNTYCODE COUNTYNAME          COUNTYENG  \
# 0         Z      09007        連江縣  Lienchiang County
# 1         G      10002        宜蘭縣       Yilan County
# 2         N      10007        彰化縣    Changhua County
# 3         M      10008        南投縣      Nantou County
# 4         P      10009        雲林縣      Yunlin County
# 5         C      10017        基隆市       Keelung City
# 6         A      63000        臺北市        Taipei City
# 7         F      65000        新北市    New Taipei City
# 8         B      66000        臺中市      Taichung City
# 9         D      67000        臺南市        Tainan City
# 10        H      68000        桃園市       Taoyuan City
# 11        K      10005        苗栗縣      Miaoli County
# 12        I      10020        嘉義市        Chiayi City
# 13        Q      10010        嘉義縣      Chiayi County
# 14        W      09020        金門縣      Kinmen County
# 15        E      64000        高雄市     Kaohsiung City
# 16        V      10014        臺東縣     Taitung County
# 17        U      10015        花蓮縣     Hualien County
# 18        X      10016        澎湖縣      Penghu County
# 19        O      10018        新竹市       Hsinchu City
# 20        J      10004        新竹縣     Hsinchu County
# 21        T      10013        屏東縣    Pingtung County
#
#                                              geometry fruits  production
# 0   MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...     香蕉        0.00
# 1   MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...     香蕉     3038.56
# 2   POLYGON ((120.45655 24.20719, 120.48589 24.197...     香蕉     3162.01
# 3   POLYGON ((121.27086 24.23661, 121.27108 24.236...     香蕉    59597.58
# 4   MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...     香蕉    18222.20
# 5   MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...     香蕉       50.05
# 6   POLYGON ((121.57098 25.19717, 121.57097 25.197...     香蕉      161.03
# 7   POLYGON ((121.53752 25.30003, 121.53768 25.300...     香蕉     1405.54
# 8   POLYGON ((121.32834 24.43304, 121.32845 24.432...     香蕉     8711.14
# 9   POLYGON ((120.44025 23.41308, 120.44040 23.413...     香蕉    24008.13
# 10  POLYGON ((121.26381 25.12198, 121.26668 25.120...     香蕉      828.23
# 11  POLYGON ((121.00820 24.64432, 121.00828 24.644...     香蕉     2887.20
# 12  POLYGON ((120.44758 23.51819, 120.44767 23.518...     香蕉     1124.03
# 13  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...     香蕉    59785.02
# 14  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...     香蕉       15.83
# 15  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...     香蕉    52382.17
# 16  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...     香蕉    11510.12
# 17  POLYGON ((121.63127 24.37049, 121.63144 24.370...     香蕉     7487.43
# 18  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...     香蕉       42.35
# 19  POLYGON ((120.92532 24.85478, 120.92545 24.854...     香蕉       91.06
# 20  POLYGON ((121.03813 24.94638, 121.03822 24.946...     香蕉     1887.22
# 21  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...     香蕉    86231.69

# %% [markdown]
# ### Visualize the result on map

# %%
fig,ax = plt.subplots(figsize = (10, 10))
whole_data.plot(ax=ax, column="production", cmap="YlGn")

ax.set_xlim(118,123)
ax.set_ylim(21,26)
ax.set_title("2019 Taiwan banana production overview", size = 20)
ax.set_facecolor("skyblue")

# %% [markdown]
# ### 後續問題
# - 如何加上顏色條?
# - 排行榜?
