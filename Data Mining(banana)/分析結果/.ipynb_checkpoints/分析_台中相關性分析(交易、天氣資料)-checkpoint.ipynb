# %%
import pandas as pd
import numpy as np
import pymysql
import seaborn as sns
from sqlalchemy import create_engine
import matplotlib.pyplot as plt 
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## 香蕉交易量排行榜
# 根據交易資料統計，台中交易市場為最大，因此選擇以台中為主要分析資料，氣候測站選擇南投 => **尚未驗證**
# - 2011~2019累計成交量
#
# <img src='image/banana transaction ranking.png'>

# %%
username = 'root'
password = 'yuting1101'
host_port = 'localhost:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
fruit = "banana"
market = "台中市"
df_test = pd.read_sql(f"{fruit}_{market}", engine)
df_test.tail()
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 3868 2021-08-04        30.9     23041.0               30.8       19.7
# 3869 2021-08-05        31.8     22484.0               25.6       18.1
# 3870 2021-08-06        30.4     28395.0               32.7       19.4
# 3871 2021-08-07        31.9     20433.0               24.0       20.6
# 3872 2021-08-08        35.2     20832.0               27.0       23.3
#
#       banana_前日平均價  banana_5日平均價
# 3868          30.3          30.1
# 3869          30.9          30.8
# 3870          31.8          30.8
# 3871          30.4          31.1
# 3872          31.9          32.0

# %%
len(df_test)
# Out:
# 3873

# %%
df_test = df_test.set_index("日期")

# %% [markdown]
# ## 交易資料 => 使用台中市場

# %%
df_price = pd.read_csv("cleaned data/價格_全國香蕉交易資料(初步清洗).csv", usecols=[0, 1, 2, 3, 4, 5, 6, 8])
df_price.head()
# Out:
#            日期       市場     產品    上價    中價    下價  平均價(元/公斤) 交易量(公斤)
# 0  2011-01-01  104 台北二  A1 香蕉  35.0  32.1  25.6       31.4     NaN
# 1  2011-01-02  104 台北二  A1 香蕉  35.1  33.1  25.8       32.0     NaN
# 2  2011-01-04  104 台北二  A1 香蕉  35.8  33.1  27.0       32.4     NaN
# 3  2011-01-05  104 台北二  A1 香蕉  36.5  33.9  27.8       33.2     NaN
# 4  2011-01-06  104 台北二  A1 香蕉  38.2  35.5  28.9       34.7     NaN

# %%
## 只留下台中市場資料
df_price_taichung = df_price.loc[df_price["市場"] == "400 台中市"]

# %%
df_price_taichung["日期"] = pd.to_datetime(df_price_taichung["日期"])
df_price_taichung.set_index("日期", inplace=True)

# %%
df_price_taichung
# Out:
#                  市場     產品    上價    中價    下價  平均價(元/公斤) 交易量(公斤)
# 日期
# 2011-01-01  400 台中市  A1 香蕉  29.4  22.9  12.9       22.1     NaN
# 2011-01-02  400 台中市  A1 香蕉  27.1  22.4  14.3       21.7     NaN
# 2011-01-04  400 台中市  A1 香蕉  29.6  22.9  14.6       24.9     NaN
# 2011-01-05  400 台中市  A1 香蕉  27.3  22.3  16.0       23.6     NaN
# 2011-01-06  400 台中市  A1 香蕉  29.2  22.6  12.4       24.5     NaN
# ...             ...    ...   ...   ...   ...        ...     ...
# 2021-06-10  400 台中市  A1 香蕉  25.8  23.2  13.8       23.1     NaN
# 2021-06-11  400 台中市  A1 香蕉  26.0  23.8  17.0       23.7     NaN
# 2021-06-12  400 台中市  A1 香蕉  26.2  18.6  11.9       22.7     NaN
# 2021-06-13  400 台中市  A1 香蕉  27.5  23.0  15.0       23.7     NaN
# 2021-06-14  400 台中市  A1 香蕉  28.8  24.1  16.8       25.0     NaN
#
# [3145 rows x 7 columns]

# %% [markdown]
# ### 補上休市資料
# - 目前使用ffill（補前值），這方法不太好，雖補齊休假日空缺，但是否影響資料整體尚待評估 => 使用resample("D")，以日為單位重採集資料

# %%
df_price_taichung = df_price_taichung.resample("D").interpolate().fillna(method="ffill")
df_price_taichung
# Out:
#                  市場     產品     上價     中價     下價  平均價(元/公斤)  交易量(公斤)
# 日期
# 2011-01-01  400 台中市  A1 香蕉  29.40  22.90  12.90       22.1      NaN
# 2011-01-02  400 台中市  A1 香蕉  27.10  22.40  14.30       21.7      NaN
# 2011-01-03  400 台中市  A1 香蕉  28.35  22.65  14.45       23.3      NaN
# 2011-01-04  400 台中市  A1 香蕉  29.60  22.90  14.60       24.9      NaN
# 2011-01-05  400 台中市  A1 香蕉  27.30  22.30  16.00       23.6      NaN
# ...             ...    ...    ...    ...    ...        ...      ...
# 2021-06-10  400 台中市  A1 香蕉  25.80  23.20  13.80       23.1      NaN
# 2021-06-11  400 台中市  A1 香蕉  26.00  23.80  17.00       23.7      NaN
# 2021-06-12  400 台中市  A1 香蕉  26.20  18.60  11.90       22.7      NaN
# 2021-06-13  400 台中市  A1 香蕉  27.50  23.00  15.00       23.7      NaN
# 2021-06-14  400 台中市  A1 香蕉  28.80  24.10  16.80       25.0      NaN
#
# [3818 rows x 7 columns]

# %% [markdown]
# ### merge

# %%
df_output = pd.merge(df_price_taichung, df_test, left_index=True, right_index=True, how="left")
df_output.tail()
# Out:
#                  市場     產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)  banana_平均價  \
# 日期
# 2021-06-10  400 台中市  A1 香蕉  25.8  23.2  13.8       23.1      NaN        23.1
# 2021-06-11  400 台中市  A1 香蕉  26.0  23.8  17.0       23.7      NaN        23.7
# 2021-06-12  400 台中市  A1 香蕉  26.2  18.6  11.9       22.7      NaN        22.7
# 2021-06-13  400 台中市  A1 香蕉  27.5  23.0  15.0       23.7      NaN        23.7
# 2021-06-14  400 台中市  A1 香蕉  28.8  24.1  16.8       25.0      NaN        25.0
#
#             banana_交易量  scarletbanana_平均價  guava_平均價  banana_前日平均價  \
# 日期
# 2021-06-10     30348.0               28.7       32.6          23.2
# 2021-06-11     20520.0               31.5       27.6          23.1
# 2021-06-12     28971.0               30.1       25.3          23.7
# 2021-06-13     20250.0               31.3       20.8          22.7
# 2021-06-14     11775.0               26.1       21.9          23.7
#
#             banana_5日平均價
# 日期
# 2021-06-10          22.5
# 2021-06-11          22.6
# 2021-06-12          22.7
# 2021-06-13          23.3
# 2021-06-14          23.6

# %%
df_output.drop(columns=["banana_平均價", "banana_交易量"], inplace=True)

# %%
df_output.columns
# Out:
# Index(['市場', '產品', '上價', '中價', '下價', '平均價(元/公斤)', '交易量(公斤)',
#        'scarletbanana_平均價', 'guava_平均價', 'banana_前日平均價', 'banana_5日平均價'],
#       dtype='object')

# %%
# 改成英文欄位以利後續使用
eng_cols_name = ["Market", "Product", "High price", "Mid price", "Low price", "Average price", "Volume(kg)", 
                 'scarletbanana_Avg_p', 'guava_Avg_p', 'banana_Avg_p(-1d)', 'banana_Avg_p(5d)']
df_output.columns = eng_cols_name

# %%
df_output
# Out:
#              Market Product  High price  Mid price  Low price  Average price  \
# 日期
# 2011-01-01  400 台中市   A1 香蕉       29.40      22.90      12.90           22.1
# 2011-01-02  400 台中市   A1 香蕉       27.10      22.40      14.30           21.7
# 2011-01-03  400 台中市   A1 香蕉       28.35      22.65      14.45           23.3
# 2011-01-04  400 台中市   A1 香蕉       29.60      22.90      14.60           24.9
# 2011-01-05  400 台中市   A1 香蕉       27.30      22.30      16.00           23.6
# ...             ...     ...         ...        ...        ...            ...
# 2021-06-10  400 台中市   A1 香蕉       25.80      23.20      13.80           23.1
# 2021-06-11  400 台中市   A1 香蕉       26.00      23.80      17.00           23.7
# 2021-06-12  400 台中市   A1 香蕉       26.20      18.60      11.90           22.7
# 2021-06-13  400 台中市   A1 香蕉       27.50      23.00      15.00           23.7
# 2021-06-14  400 台中市   A1 香蕉       28.80      24.10      16.80           25.0
#
#             Volume(kg)  scarletbanana_Avg_p  guava_Avg_p  banana_Avg_p(-1d)  \
# 日期
# 2011-01-01         NaN                 29.7         33.7               22.1
# 2011-01-02         NaN                 27.5         36.1               22.1
# 2011-01-03         NaN                 32.3         36.1               21.7
# 2011-01-04         NaN                 37.1         36.1               23.3
# 2011-01-05         NaN                 41.2         35.6               24.9
# ...                ...                  ...          ...                ...
# 2021-06-10         NaN                 28.7         32.6               23.2
# 2021-06-11         NaN                 31.5         27.6               23.1
# 2021-06-12         NaN                 30.1         25.3               23.7
# 2021-06-13         NaN                 31.3         20.8               22.7
# 2021-06-14         NaN                 26.1         21.9               23.7
#
#             banana_Avg_p(5d)
# 日期
# 2011-01-01              23.1
# 2011-01-02              23.1
# 2011-01-03              23.1
# 2011-01-04              23.1
# 2011-01-05              23.1
# ...                      ...
# 2021-06-10              22.5
# 2021-06-11              22.6
# 2021-06-12              22.7
# 2021-06-13              23.3
# 2021-06-14              23.6
#
# [3818 rows x 11 columns]

# %% [markdown]
# ### 新增欄位需求
# - 移動平均（5日均價）

# %% [markdown]
# ## 天氣資料 => 使用日月潭測站資料

# %% [markdown]
# ### 主要欄位中文名稱
#
# <img src='image/weather_columns(definition).png' width=1600>

# %% [markdown]
# ### 異常值符號代表意義&處理方式

# %%
dict_symbol = {"Symbol":["T", "x", "&", "V", "/", "..."],
               "Explanation":["微量(小於 0.1mm)", "故障", "降水量資料累積於後", "風向不定", "不明", "無觀測"],
               "Replacement":[0.0, "ffill", "ffill", "ffill", "ffill", "ffill"]
              }
df_symbol = pd.DataFrame(dict_symbol)
df_symbol
# Out:
#   Symbol   Explanation Replacement
# 0      T  微量(小於 0.1mm)           0
# 1      x            故障       ffill
# 2      &     降水量資料累積於後       ffill
# 3      V          風向不定       ffill
# 4      /            不明       ffill
# 5    ...           無觀測       ffill

# %% [markdown]
# ### 中英欄位對照表

# %%
col_data = "觀測時間(LST)ObsTime、測站氣壓(hPa)StnPres、海平面氣壓(hPa)SeaPres、測站最高氣壓(hPa)StnPresMax、測站最高氣壓時間(LST)StnPresMaxTime、測站最低氣壓(hPa)StnPresMin、測站最低氣壓時間(LST)StnPresMinTime、氣溫(℃)Temperature、最高氣溫(℃)T Max、最高氣溫時間(LST)T Max Time、最低氣溫(℃)T Min、最低氣溫時間(LST)T Min Time、露點溫度(℃)Td dew point、相對溼度(%)RH、最小相對溼度(%)RHMin、最小相對溼度時間(LST)RHMinTime、風速(m/s)WS、風向(360degree)WD、最大陣風(m/s)WSGust、最大陣風風向(360degree)WDGust、最大陣風風速時間(LST)WGustTime、降水量(mm)Precp、降水時數(hr)PrecpHour、10分鐘最大降水量(mm)PrecpMax10、10分鐘最大降水起始時間(LST)PrecpMax10Time、一小時最大降水量(mm)PrecpHrMax、一小時最大降水量起始時間(LST)PrecpHrMaxTime、日照時數(hr)SunShine、日照率(%)SunShineRate、全天空日射量(MJ/㎡)GloblRad、能見度(km)VisbMean、A型蒸發量(mm)EvapA"
datas = [i for i in col_data.split("、")]
chi,eng =[],[]
for data in datas:
    chi.append(data.split(")")[0]+")")
    eng.append(data.split(")")[1])
df_columns_name = pd.DataFrame({"英文名稱":eng, 
                                "中文名稱":chi})
df_columns_name
# Out:
#               英文名稱               中文名稱
# 0          ObsTime          觀測時間(LST)
# 1          StnPres          測站氣壓(hPa)
# 2          SeaPres         海平面氣壓(hPa)
# 3       StnPresMax        測站最高氣壓(hPa)
# 4   StnPresMaxTime      測站最高氣壓時間(LST)
# 5       StnPresMin        測站最低氣壓(hPa)
# 6   StnPresMinTime      測站最低氣壓時間(LST)
# 7      Temperature              氣溫(℃)
# 8            T Max            最高氣溫(℃)
# 9       T Max Time        最高氣溫時間(LST)
# 10           T Min            最低氣溫(℃)
# 11      T Min Time        最低氣溫時間(LST)
# 12    Td dew point            露點溫度(℃)
# 13              RH            相對溼度(%)
# 14           RHMin          最小相對溼度(%)
# 15       RHMinTime      最小相對溼度時間(LST)
# 16              WS            風速(m/s)
# 17              WD      風向(360degree)
# 18          WSGust          最大陣風(m/s)
# 19          WDGust  最大陣風風向(360degree)
# 20       WGustTime      最大陣風風速時間(LST)
# 21           Precp            降水量(mm)
# 22       PrecpHour           降水時數(hr)
# 23      PrecpMax10      10分鐘最大降水量(mm)
# 24  PrecpMax10Time  10分鐘最大降水起始時間(LST)
# 25      PrecpHrMax       一小時最大降水量(mm)
# 26  PrecpHrMaxTime  一小時最大降水量起始時間(LST)
# 27        SunShine           日照時數(hr)
# 28    SunShineRate             日照率(%)
# 29        GloblRad       全天空日射量(MJ/㎡)
# 30        VisbMean            能見度(km)
# 31           EvapA          A型蒸發量(mm)

# %%
df_weather_taichung = pd.read_csv("cleaned data/weather_data/日月潭.csv")
df_weather_taichung
# Out:
#       ObsTime StnPres  SeaPres StnPresMax     StnPresMaxTime StnPresMin  \
# 0           1  904.3   1530.8      905.3   2010-01-01 09:24      903.3
# 1           2  903.1   1522.7      904.8   2010-01-02 00:04      901.7
# 2           3  902.5   1513.9      904.1   2010-01-03 08:05      900.8
# 3           4  902.3   1512.9      903.5   2010-01-04 09:31      900.9
# 4           5  902.8   1518.9      904.8   2010-01-05 09:14      901.3
# ...       ...     ...      ...        ...                ...        ...
# 4194       26    ...      ...        ...                ...        ...
# 4195       27    ...      ...        ...                ...        ...
# 4196       28    ...      ...        ...                ...        ...
# 4197       29    ...      ...        ...                ...        ...
# 4198       30    ...      ...        ...                ...        ...
#
#          StnPresMinTime Temperature  T Max         T Max Time  ... PrecpMax60  \
# 0     2010-01-01 14:12        13.4   16.3   2010-01-01 14:29   ...       0.0
# 1     2010-01-02 14:32        14.6   17.6   2010-01-02 11:09   ...       0.7
# 2     2010-01-03 14:29        12.6   18.1   2010-01-03 13:21   ...       6.0
# 3     2010-01-04 14:15        13.8   19.7   2010-01-04 13:38   ...       0.0
# 4     2010-01-05 13:47        13.7   19.3   2010-01-05 13:27   ...       0.0
# ...                 ...         ...    ...                ...  ...        ...
# 4194               ...         ...    ...                ...   ...       ...
# 4195               ...         ...    ...                ...   ...       ...
# 4196               ...         ...    ...                ...   ...       ...
# 4197               ...         ...    ...                ...   ...       ...
# 4198               ...         ...    ...                ...   ...       ...
#
#          PrecpMax60Time SunShine SunShineRate GloblRad VisbMean  EvapA  \
# 0                  ...      0.1          0.9     4.63     20.0    0.9
# 1     2010-01-02 20:35      1.1         10.3     5.22     20.9   -0.5
# 2     2010-01-03 04:29      4.2         39.4     9.23     14.2   -0.9
# 3                  ...      8.1         76.0    14.42     19.7    0.6
# 4                  ...      1.5         14.1     7.78     18.2   -0.7
# ...                 ...      ...          ...      ...      ...    ...
# 4194               ...      ...          ...      ...      ...    ...
# 4195               ...      ...          ...      ...      ...    ...
# 4196               ...      ...          ...      ...      ...    ...
# 4197               ...      ...          ...      ...      ...    ...
# 4198               ...      ...          ...      ...      ...    ...
#
#      UVI Max       UVI Max Time Cloud Amount
# 0         2   2010-01-01 11:00          9.5
# 1         2   2010-01-02 12:00          9.2
# 2         5   2010-01-03 13:00          8.4
# 3         5   2010-01-04 13:00          3.8
# 4         3   2010-01-05 13:00          7.0
# ...      ...                ...          ...
# 4194    ...                ...          ...
# 4195    ...                ...          ...
# 4196    ...                ...          ...
# 4197    ...                ...          ...
# 4198    ...                ...          ...
#
# [4199 rows x 35 columns]

# %%
df_weather_taichung.dtypes
# Out:
# ObsTime            int64
# StnPres           object
# SeaPres           object
# StnPresMax        object
# StnPresMaxTime    object
# StnPresMin        object
# StnPresMinTime    object
# Temperature       object
# T Max             object
# T Max Time        object
# T Min             object
# T Min Time        object
# Td dew point      object
# RH                object
# RHMin             object
# RHMinTime         object
# WS                object
# WD                object
# WSGust            object
# WDGust            object
# WGustTime         object
# Precp             object
# PrecpHour         object
# PrecpMax10        object
# PrecpMax10Time    object
# PrecpMax60        object
# PrecpMax60Time    object
# SunShine          object
# SunShineRate      object
# GloblRad          object
# VisbMean          object
# EvapA             object
# UVI Max           object
# UVI Max Time      object
# Cloud Amount      object
# dtype: object

# %%
# 為後續資料清洗，從df_weather_taichungd拷貝一份當成df_test，避免改動到原檔案導致重新讀取
# 刪除ObsTime欄位
df_test = df_weather_taichung.copy()
df_test.drop(columns="ObsTime", inplace=True)

# %%
df_test
# Out:
#      StnPres  SeaPres StnPresMax     StnPresMaxTime StnPresMin  \
# 0     904.3   1530.8      905.3   2010-01-01 09:24      903.3
# 1     903.1   1522.7      904.8   2010-01-02 00:04      901.7
# 2     902.5   1513.9      904.1   2010-01-03 08:05      900.8
# 3     902.3   1512.9      903.5   2010-01-04 09:31      900.9
# 4     902.8   1518.9      904.8   2010-01-05 09:14      901.3
# ...      ...      ...        ...                ...        ...
# 4194    ...      ...        ...                ...        ...
# 4195    ...      ...        ...                ...        ...
# 4196    ...      ...        ...                ...        ...
# 4197    ...      ...        ...                ...        ...
# 4198    ...      ...        ...                ...        ...
#
#          StnPresMinTime Temperature  T Max         T Max Time  T Min  ...  \
# 0     2010-01-01 14:12        13.4   16.3   2010-01-01 14:29   11.1   ...
# 1     2010-01-02 14:32        14.6   17.6   2010-01-02 11:09   12.6   ...
# 2     2010-01-03 14:29        12.6   18.1   2010-01-03 13:21   10.4   ...
# 3     2010-01-04 14:15        13.8   19.7   2010-01-04 13:38    9.8   ...
# 4     2010-01-05 13:47        13.7   19.3   2010-01-05 13:27   10.8   ...
# ...                 ...         ...    ...                ...    ...  ...
# 4194               ...         ...    ...                ...    ...   ...
# 4195               ...         ...    ...                ...    ...   ...
# 4196               ...         ...    ...                ...    ...   ...
# 4197               ...         ...    ...                ...    ...   ...
# 4198               ...         ...    ...                ...    ...   ...
#
#      PrecpMax60     PrecpMax60Time SunShine SunShineRate GloblRad VisbMean  \
# 0          0.0                ...      0.1          0.9     4.63     20.0
# 1          0.7   2010-01-02 20:35      1.1         10.3     5.22     20.9
# 2          6.0   2010-01-03 04:29      4.2         39.4     9.23     14.2
# 3          0.0                ...      8.1         76.0    14.42     19.7
# 4          0.0                ...      1.5         14.1     7.78     18.2
# ...         ...                ...      ...          ...      ...      ...
# 4194       ...                ...      ...          ...      ...      ...
# 4195       ...                ...      ...          ...      ...      ...
# 4196       ...                ...      ...          ...      ...      ...
# 4197       ...                ...      ...          ...      ...      ...
# 4198       ...                ...      ...          ...      ...      ...
#
#       EvapA UVI Max       UVI Max Time Cloud Amount
# 0      0.9       2   2010-01-01 11:00          9.5
# 1     -0.5       2   2010-01-02 12:00          9.2
# 2     -0.9       5   2010-01-03 13:00          8.4
# 3      0.6       5   2010-01-04 13:00          3.8
# 4     -0.7       3   2010-01-05 13:00          7.0
# ...     ...     ...                ...          ...
# 4194   ...     ...                ...          ...
# 4195   ...     ...                ...          ...
# 4196   ...     ...                ...          ...
# 4197   ...     ...                ...          ...
# 4198   ...     ...                ...          ...
#
# [4199 rows x 34 columns]

# %%
# 去除 \xa0 = space
df_test = df_test.applymap(lambda x: x.replace("\xa0",""))

# %%
# 將"..."取代為np.nan
df_test = df_test.replace("...", np.nan)

# %%
# dropna => 刪除欄位全部為null的row
df_test.dropna(how="all", inplace=True)
df_test.tail()
# Out:
#      StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 4178   898.6  1493.7      900.4  2021-06-10 00:03      896.5
# 4179   899.3  1502.2      901.8  2021-06-11 21:31      897.9
# 4180   901.7  1524.9      903.6  2021-06-12 22:07      900.5
# 4181   901.4  1522.1      903.1  2021-06-13 00:01      898.8
# 4182   898.8  1498.2      901.2  2021-06-14 00:05      897.3
#
#         StnPresMinTime Temperature T Max        T Max Time T Min  ...  \
# 4178  2021-06-10 16:00        22.4  28.5  2021-06-10 13:55  19.1  ...
# 4179  2021-06-11 07:02        23.2  28.6  2021-06-11 12:54  19.6  ...
# 4180  2021-06-12 16:20        22.5  28.9  2021-06-12 12:34  19.4  ...
# 4181  2021-06-13 16:51        23.1  29.4  2021-06-13 12:57  20.1  ...
# 4182  2021-06-14 16:57        23.5  29.0  2021-06-14 13:10  20.4  ...
#
#      PrecpMax60    PrecpMax60Time SunShine SunShineRate GloblRad VisbMean  \
# 4178        6.0  2021-06-10 00:01      4.4         32.5    16.21     22.5
# 4179        0.5  2021-06-11 19:59      3.8         28.1    16.23     25.5
# 4180       14.5  2021-06-12 16:06      2.8         20.7    14.51      7.5
# 4181       11.5  2021-06-13 17:03      4.9         35.4    20.10     22.5
# 4182        0.0               NaN      6.3         46.5    22.43     25.8
#
#      EvapA UVI Max      UVI Max Time Cloud Amount
# 4178  -2.8       8  2021-06-10 14:00          7.2
# 4179  -2.0       9  2021-06-11 13:00          7.5
# 4180  -3.1       9  2021-06-12 13:00          7.8
# 4181  -3.9       9  2021-06-13 13:00          6.2
# 4182   4.2      10  2021-06-14 12:00          5.8
#
# [5 rows x 34 columns]

# %%
# 新增欄位「日期」，做為稍後合併兩個dataframe的鍵值
df_test["日期"] =  df_test["StnPresMaxTime"].apply(lambda x: x[:10])
df_test
# Out:
#      StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0      904.3  1530.8      905.3  2010-01-01 09:24      903.3
# 1      903.1  1522.7      904.8  2010-01-02 00:04      901.7
# 2      902.5  1513.9      904.1  2010-01-03 08:05      900.8
# 3      902.3  1512.9      903.5  2010-01-04 09:31      900.9
# 4      902.8  1518.9      904.8  2010-01-05 09:14      901.3
# ...      ...     ...        ...               ...        ...
# 4178   898.6  1493.7      900.4  2021-06-10 00:03      896.5
# 4179   899.3  1502.2      901.8  2021-06-11 21:31      897.9
# 4180   901.7  1524.9      903.6  2021-06-12 22:07      900.5
# 4181   901.4  1522.1      903.1  2021-06-13 00:01      898.8
# 4182   898.8  1498.2      901.2  2021-06-14 00:05      897.3
#
#         StnPresMinTime Temperature T Max        T Max Time T Min  ...  \
# 0     2010-01-01 14:12        13.4  16.3  2010-01-01 14:29  11.1  ...
# 1     2010-01-02 14:32        14.6  17.6  2010-01-02 11:09  12.6  ...
# 2     2010-01-03 14:29        12.6  18.1  2010-01-03 13:21  10.4  ...
# 3     2010-01-04 14:15        13.8  19.7  2010-01-04 13:38   9.8  ...
# 4     2010-01-05 13:47        13.7  19.3  2010-01-05 13:27  10.8  ...
# ...                ...         ...   ...               ...   ...  ...
# 4178  2021-06-10 16:00        22.4  28.5  2021-06-10 13:55  19.1  ...
# 4179  2021-06-11 07:02        23.2  28.6  2021-06-11 12:54  19.6  ...
# 4180  2021-06-12 16:20        22.5  28.9  2021-06-12 12:34  19.4  ...
# 4181  2021-06-13 16:51        23.1  29.4  2021-06-13 12:57  20.1  ...
# 4182  2021-06-14 16:57        23.5  29.0  2021-06-14 13:10  20.4  ...
#
#         PrecpMax60Time SunShine SunShineRate GloblRad VisbMean EvapA UVI Max  \
# 0                  NaN      0.1          0.9     4.63     20.0   0.9       2
# 1     2010-01-02 20:35      1.1         10.3     5.22     20.9  -0.5       2
# 2     2010-01-03 04:29      4.2         39.4     9.23     14.2  -0.9       5
# 3                  NaN      8.1         76.0    14.42     19.7   0.6       5
# 4                  NaN      1.5         14.1     7.78     18.2  -0.7       3
# ...                ...      ...          ...      ...      ...   ...     ...
# 4178  2021-06-10 00:01      4.4         32.5    16.21     22.5  -2.8       8
# 4179  2021-06-11 19:59      3.8         28.1    16.23     25.5  -2.0       9
# 4180  2021-06-12 16:06      2.8         20.7    14.51      7.5  -3.1       9
# 4181  2021-06-13 17:03      4.9         35.4    20.10     22.5  -3.9       9
# 4182               NaN      6.3         46.5    22.43     25.8   4.2      10
#
#           UVI Max Time Cloud Amount          日期
# 0     2010-01-01 11:00          9.5  2010-01-01
# 1     2010-01-02 12:00          9.2  2010-01-02
# 2     2010-01-03 13:00          8.4  2010-01-03
# 3     2010-01-04 13:00          3.8  2010-01-04
# 4     2010-01-05 13:00          7.0  2010-01-05
# ...                ...          ...         ...
# 4178  2021-06-10 14:00          7.2  2021-06-10
# 4179  2021-06-11 13:00          7.5  2021-06-11
# 4180  2021-06-12 13:00          7.8  2021-06-12
# 4181  2021-06-13 13:00          6.2  2021-06-13
# 4182  2021-06-14 12:00          5.8  2021-06-14
#
# [4183 rows x 35 columns]

# %%
# 刪除幾個不必要的時間欄位
df_columns = list(df_test.columns)
time_cols = list(filter(lambda x : re.findall(".*Time", x), df_columns))

# %%
time_cols
# Out:
# ['StnPresMaxTime',
#  'StnPresMinTime',
#  'T Max Time',
#  'T Min Time',
#  'RHMinTime',
#  'WGustTime',
#  'PrecpMax10Time',
#  'PrecpMax60Time',
#  'UVI Max Time']

# %%
df_test.drop(columns=time_cols, inplace=True)

# %% [markdown]
# ### 找出無法轉換資料型態的欄位，並對其進行處理

# %%
# transform to numeric type => 準備fail_col來存放失敗欄位，稍後處理
fail_col = []
for col in list(df_test.columns):
    try:
        df_test[col] = df_test[col].apply(pd.to_numeric)
    except:
        print(f"{col}:轉換失敗")
        fail_col.append(col)
# Out:
# Precp:轉換失敗
# PrecpMax10:轉換失敗
# PrecpMax60:轉換失敗
# GloblRad:轉換失敗
# EvapA:轉換失敗
# UVI Max:轉換失敗
# Cloud Amount:轉換失敗
# 日期:轉換失敗

# %%
df_test["WD"].sum()
# Out:
# 1000160

# %%
# WD (wind direction)
# 將缺值（Ｘ）取代成眾數
# df_test.loc[~(df_test["WD"].str.isnumeric()), "WD"] = df_test["WD"].mode()[0]

# %%
# WSGust(最大陣風)
# unique()找出後解決
# 問題 => 如何快速找到不為float的欄位（isnumeric無效）

df_test["WSGust"].unique()
df_test.loc[(df_test["WSGust"] == "X"), "WSGust"] = np.nan
df_test["WSGust"].fillna(method="ffill", inplace=True)

# %%
# WDGust(最大陣風方向)
#df_test.loc[~(df_test["WDGust"].str.isnumeric()), "WDGust"] = df_test["WDGust"].mode()[0]

# %%
# Precp(降水量)
# 無雨時 => T 
# bad_data = list(filter(lambda x :re.match("[^(\d\.\d)]", x), list(df_test["Precp"])))

df_test.loc[(df_test["Precp"] == "T")]
df_test.loc[df_test["PrecpMax10"] == "T", "PrecpMax10"] = 0.0
df_test.loc[(df_test["Precp"] == "T"), ["Precp", "PrecpMax10", "PrecpMax60"]] = 0.0

# %%
# EvapA (A型蒸發量)
df_test.loc[(df_test["EvapA"] == "/"), "EvapA"] = np.nan
df_test["EvapA"].fillna(method="ffill", inplace=True)

# %%
df_test.loc[df_test["UVI Max"] == "X"]
# Out:
#      StnPres  SeaPres  StnPresMax  StnPresMin  Temperature  T Max  T Min  \
# 591    903.1   1538.7       904.5       902.0         23.4   30.2   20.3
# 592    902.2   1530.2       903.7       900.8         23.3   30.4   19.7
# 593    901.8   1525.8       902.9       900.6         23.4   30.4   19.6
# 594    902.0   1528.8       903.3       900.7         23.7   30.7   20.1
# 595    902.4   1530.5       903.7       901.3         22.8   28.8   18.6
# 596    902.2   1529.1       903.2       901.2         23.1   30.1   19.3
# 597    901.3   1520.3       902.6       899.9         22.9   29.7   20.2
# 598    899.9   1507.1       901.1       898.6         23.1   28.4   20.2
# 599    898.7   1495.0       900.1       897.2         22.8   28.8   19.9
# 600    898.4   1491.0       899.4       896.9         21.7   26.8   19.0
# 601    896.7   1475.3       898.2       895.0         22.9   27.9   19.5
# 602    896.2   1472.0       897.2       894.8         23.9   28.9   19.9
# 603    894.5   1457.0       896.0       893.1         24.1   28.3   21.4
# 604    890.1   1412.6       893.9       887.3         23.1   26.4   20.0
# 605    885.5   1367.7       888.8       881.9         23.6   28.2   21.0
# 606    888.7   1397.4       890.3       887.5         22.2   24.8   20.8
# 607    891.7   1424.9       893.9       889.1         21.2   23.5   18.9
# 790    902.8   1527.9       904.9       901.4         18.9   24.0   16.1
#
#      Td dew point  RH  RHMin  ...  PrecpMax10  PrecpMax60  SunShine  \
# 591          20.4  84     65  ...         0.0         0.0       5.7
# 592          19.6  80     65  ...         0.5         0.5       7.4
# 593          19.0  77     60  ...         0.0         0.0       9.5
# 594          19.5  78     55  ...         6.5        10.5       9.4
# 595          19.6  83     67  ...         0.0         0.0       7.5
# 596          20.5  85     65  ...         0.0         0.0       5.2
# 597          20.0  84     65  ...         0.0         0.0       4.3
# 598          19.8  82     67  ...         0.0         0.0       7.1
# 599          19.7  83     64  ...           0           0       6.5
# 600          19.7  89     74  ...        15.5        52.0       2.9
# 601          19.8  83     66  ...         0.0         0.0       6.1
# 602          20.6  82     63  ...         0.0         0.0       6.5
# 603          21.5  85     76  ...         0.5         0.5       3.7
# 604          18.0  74     55  ...         1.0         2.5       0.5
# 605          19.5  78     55  ...         1.0         1.0       0.2
# 606          20.1  89     64  ...         1.0         2.0       0.0
# 607          18.3  84     65  ...         1.0         2.0       0.0
# 790          14.8  77     66  ...         0.0         0.0       7.6
#
#      SunShineRate GloblRad  VisbMean EvapA UVI Max  Cloud Amount          日期
# 591          44.1    15.44      20.3   3.0       X           6.8  2011-08-15
# 592          57.4    16.51      16.5  -3.0       X           5.7  2011-08-16
# 593          73.8    21.04      24.2   4.0       X           2.8  2011-08-17
# 594          73.1    21.55      18.3  -6.1       X           3.7  2011-08-18
# 595          58.4    18.84      20.8   4.9       X           6.5  2011-08-19
# 596          40.6    15.01      11.3   3.9       X           6.3  2011-08-20
# 597          33.6    15.71       8.0   3.4       X           5.0  2011-08-21
# 598          55.6    19.14       5.0   2.3       X           5.8  2011-08-22
# 599          51.0    14.48       7.3  -2.7       X           5.2  2011-08-23
# 600          22.8     8.24       6.0  -4.2       X           6.8  2011-08-24
# 601          48.0    13.97      20.0   2.4       X           5.7  2011-08-25
# 602          51.3    16.12      15.7   3.1       X           6.7  2011-08-26
# 603          29.2    12.97       8.2  -2.0       X           7.3  2011-08-27
# 604           4.0     2.64      20.2  -1.1       X           9.7  2011-08-28
# 605           1.6     6.21      21.7  -0.4       X          10.0  2011-08-29
# 606           0.0     5.44       3.4  -0.5       X          10.0  2011-08-30
# 607           0.0     5.46      17.5  -0.6       X          10.0  2011-08-31
# 790          65.6    15.76      14.2   2.7       X           3.7  2012-03-01
#
# [18 rows x 26 columns]

# %%
# UVI Max (最大紫外線)
df_test.loc[df_test["UVI Max"] == "X", "UVI Max"] = np.nan
df_test["UVI Max"].fillna(method="ffill", inplace=True)

# %%
df_test.iloc[2,:]
# Out:
# StnPres              902.5
# SeaPres             1513.9
# StnPresMax           904.1
# StnPresMin           900.8
# Temperature           12.6
# T Max                 18.1
# T Min                 10.4
# Td dew point          11.7
# RH                      95
# RHMin                   69
# WS                     1.7
# WD                     290
# WSGust                10.2
# WDGust                 320
# Precp                 18.0
# PrecpHour              9.8
# PrecpMax10             2.5
# PrecpMax60             6.0
# SunShine               4.2
# SunShineRate          39.4
# GloblRad              9.23
# VisbMean              14.2
# EvapA                 -0.9
# UVI Max                  5
# Cloud Amount           8.4
# 日期              2010-01-03
# Name: 2, dtype: object

# %%
# Clound Amount
df_test.loc[(df_test["Cloud Amount"] == "/"), "Cloud Amount"] = np.nan
df_test["Cloud Amount"].fillna(method="ffill", inplace=True)

# %%
# GloblRad 
df_test.loc[(df_test['GloblRad'] == "X"), 'GloblRad'] = np.nan
df_test["GloblRad"].fillna(method="ffill", inplace=True)

# %% [markdown]
# ### 轉換數值
#
# 注意：
# - 類別型欄位 => WD、WDGust、WSGust、UVI Max
# - 時間序列欄位 => 日期
# - 其餘皆數值欄位

# %%
df_test.dtypes
# Out:
# StnPres         float64
# SeaPres         float64
# StnPresMax      float64
# StnPresMin      float64
# Temperature     float64
# T Max           float64
# T Min           float64
# Td dew point    float64
# RH                int64
# RHMin             int64
# WS              float64
# WD                int64
# WSGust          float64
# WDGust            int64
# Precp            object
# PrecpHour       float64
# PrecpMax10       object
# PrecpMax60       object
# SunShine        float64
# SunShineRate    float64
# GloblRad         object
# VisbMean        float64
# EvapA            object
# UVI Max          object
# Cloud Amount     object
# 日期               object
# dtype: object

# %%
fail_col
# Out:
# ['Precp',
#  'PrecpMax10',
#  'PrecpMax60',
#  'GloblRad',
#  'EvapA',
#  'UVI Max',
#  'Cloud Amount',
#  '日期']

# %%
cols = ["Precp", 'PrecpMax10', 'PrecpMax60','EvapA', "GloblRad","UVI Max", "Cloud Amount"]
df_test[cols] = df_test[cols].apply(pd.to_numeric)

# %%
df_test.dtypes
# Out:
# StnPres         float64
# SeaPres         float64
# StnPresMax      float64
# StnPresMin      float64
# Temperature     float64
# T Max           float64
# T Min           float64
# Td dew point    float64
# RH                int64
# RHMin             int64
# WS              float64
# WD                int64
# WSGust          float64
# WDGust            int64
# Precp           float64
# PrecpHour       float64
# PrecpMax10      float64
# PrecpMax60      float64
# SunShine        float64
# SunShineRate    float64
# GloblRad        float64
# VisbMean        float64
# EvapA           float64
# UVI Max           int64
# Cloud Amount    float64
# 日期               object
# dtype: object

# %% [markdown]
# ### 重新排序欄位

# %%
cols = list(df_test.columns)
df_test = df_test[[cols[-1]] + cols[:-1]]

# %%
df_test["日期"] = pd.to_datetime(df_test["日期"])

# %%
df_test.set_index("日期", drop=True, inplace=True)

# %%
# 取代原本的df_weather_taichung
df_weather_taichung = df_test

# %%
df_weather_taichung
# Out:
#             StnPres  SeaPres  StnPresMax  StnPresMin  Temperature  T Max  \
# 日期
# 2010-01-01    904.3   1530.8       905.3       903.3         13.4   16.3
# 2010-01-02    903.1   1522.7       904.8       901.7         14.6   17.6
# 2010-01-03    902.5   1513.9       904.1       900.8         12.6   18.1
# 2010-01-04    902.3   1512.9       903.5       900.9         13.8   19.7
# 2010-01-05    902.8   1518.9       904.8       901.3         13.7   19.3
# ...             ...      ...         ...         ...          ...    ...
# 2021-06-10    898.6   1493.7       900.4       896.5         22.4   28.5
# 2021-06-11    899.3   1502.2       901.8       897.9         23.2   28.6
# 2021-06-12    901.7   1524.9       903.6       900.5         22.5   28.9
# 2021-06-13    901.4   1522.1       903.1       898.8         23.1   29.4
# 2021-06-14    898.8   1498.2       901.2       897.3         23.5   29.0
#
#             T Min  Td dew point  RH  RHMin  ...  PrecpHour  PrecpMax10  \
# 日期                                          ...
# 2010-01-01   11.1          11.1  86     68  ...        0.0         0.0
# 2010-01-02   12.6          11.6  83     68  ...        4.9         0.4
# 2010-01-03   10.4          11.7  95     69  ...        9.8         2.5
# 2010-01-04    9.8          10.1  80     57  ...        0.0         0.0
# 2010-01-05   10.8           8.9  74     44  ...        0.0         0.0
# ...           ...           ...  ..    ...  ...        ...         ...
# 2021-06-10   19.1          20.5  89     67  ...        6.2         2.5
# 2021-06-11   19.6          20.9  88     68  ...        0.3         0.5
# 2021-06-12   19.4          21.2  93     65  ...        6.2         7.5
# 2021-06-13   20.1          20.7  87     67  ...        1.7         5.5
# 2021-06-14   20.4          21.0  86     63  ...        0.0         0.0
#
#             PrecpMax60  SunShine  SunShineRate  GloblRad  VisbMean  EvapA  \
# 日期
# 2010-01-01         0.0       0.1           0.9      4.63      20.0    0.9
# 2010-01-02         0.7       1.1          10.3      5.22      20.9   -0.5
# 2010-01-03         6.0       4.2          39.4      9.23      14.2   -0.9
# 2010-01-04         0.0       8.1          76.0     14.42      19.7    0.6
# 2010-01-05         0.0       1.5          14.1      7.78      18.2   -0.7
# ...                ...       ...           ...       ...       ...    ...
# 2021-06-10         6.0       4.4          32.5     16.21      22.5   -2.8
# 2021-06-11         0.5       3.8          28.1     16.23      25.5   -2.0
# 2021-06-12        14.5       2.8          20.7     14.51       7.5   -3.1
# 2021-06-13        11.5       4.9          35.4     20.10      22.5   -3.9
# 2021-06-14         0.0       6.3          46.5     22.43      25.8    4.2
#
#             UVI Max  Cloud Amount
# 日期
# 2010-01-01        2           9.5
# 2010-01-02        2           9.2
# 2010-01-03        5           8.4
# 2010-01-04        5           3.8
# 2010-01-05        3           7.0
# ...             ...           ...
# 2021-06-10        8           7.2
# 2021-06-11        9           7.5
# 2021-06-12        9           7.8
# 2021-06-13        9           6.2
# 2021-06-14       10           5.8
#
# [4183 rows x 25 columns]

# %% [markdown]
# ## 使用index以leftjoin方式，合併兩個dataframe

# %%
df_merged = df_output.merge(df_weather_taichung, how="left", on="日期")

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3818 entries, 2011-01-01 to 2021-06-14
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Market               3818 non-null   object
#  1   Product              3818 non-null   object
#  2   High price           3818 non-null   float64
#  3   Mid price            3818 non-null   float64
#  4   Low price            3818 non-null   float64
#  5   Average price        3818 non-null   float64
#  6   Volume(kg)           0 non-null      float64
#  7   scarletbanana_Avg_p  3818 non-null   float64
#  8   guava_Avg_p          3818 non-null   float64
#  9   banana_Avg_p(-1d)    3818 non-null   float64
#  10  banana_Avg_p(5d)     3818 non-null   float64
#  11  StnPres              3818 non-null   float64
#  12  SeaPres              3818 non-null   float64
#  13  StnPresMax           3818 non-null   float64
#  14  StnPresMin           3818 non-null   float64
#  15  Temperature          3818 non-null   float64
#  16  T Max                3818 non-null   float64
#  17  T Min                3818 non-null   float64
#  18  Td dew point         3818 non-null   float64
#  19  RH                   3818 non-null   int64
#  20  RHMin                3818 non-null   int64
#  21  WS                   3818 non-null   float64
#  22  WD                   3818 non-null   int64
#  23  WSGust               3818 non-null   float64
#  24  WDGust               3818 non-null   int64
#  25  Precp                3818 non-null   float64
#  26  PrecpHour            3818 non-null   float64
#  27  PrecpMax10           3818 non-null   float64
#  28  PrecpMax60           3818 non-null   float64
#  29  SunShine             3818 non-null   float64
#  30  SunShineRate         3818 non-null   float64
#  31  GloblRad             3818 non-null   float64
#  32  VisbMean             3818 non-null   float64
#  33  EvapA                3818 non-null   float64
#  34  UVI Max              3818 non-null   int64
#  35  Cloud Amount         3818 non-null   float64
# dtypes: float64(29), int64(5), object(2)
# memory usage: 1.1+ MB

# %%
df_merged.head()
# Out:
#              Market Product  High price  Mid price  Low price  Average price  \
# 日期
# 2011-01-01  400 台中市   A1 香蕉       29.40      22.90      12.90           22.1
# 2011-01-02  400 台中市   A1 香蕉       27.10      22.40      14.30           21.7
# 2011-01-03  400 台中市   A1 香蕉       28.35      22.65      14.45           23.3
# 2011-01-04  400 台中市   A1 香蕉       29.60      22.90      14.60           24.9
# 2011-01-05  400 台中市   A1 香蕉       27.30      22.30      16.00           23.6
#
#             Volume(kg)  scarletbanana_Avg_p  guava_Avg_p  banana_Avg_p(-1d)  \
# 日期
# 2011-01-01         NaN                 29.7         33.7               22.1
# 2011-01-02         NaN                 27.5         36.1               22.1
# 2011-01-03         NaN                 32.3         36.1               21.7
# 2011-01-04         NaN                 37.1         36.1               23.3
# 2011-01-05         NaN                 41.2         35.6               24.9
#
#             ...  PrecpHour  PrecpMax10  PrecpMax60  SunShine  SunShineRate  \
# 日期          ...
# 2011-01-01  ...        0.0         0.0         0.0       9.6          90.2
# 2011-01-02  ...        0.0         0.0         0.0       9.7          91.1
# 2011-01-03  ...        0.0         0.0         0.0       1.1          10.3
# 2011-01-04  ...        0.0         0.0         0.0       6.4          60.0
# 2011-01-05  ...        4.4         0.5         0.5       5.1          47.8
#
#             GloblRad  VisbMean  EvapA  UVI Max  Cloud Amount
# 日期
# 2011-01-01     12.96      10.0    1.8        5           1.3
# 2011-01-02     13.20      10.8    2.0        6           1.7
# 2011-01-03      3.39      11.0    0.4        3           8.8
# 2011-01-04     11.96      14.0   -1.4        6           5.8
# 2011-01-05     10.17      17.0   -1.2        6           7.0
#
# [5 rows x 36 columns]

# %%
# 輸出合併檔案
df_merged.to_csv("analysis data/台中_香蕉合併資料(價格&天氣).csv")

# %% [markdown]
# ### 相關性分析

# %%
df_num = df_merged.select_dtypes(include=["int64", "float64"])
df_num
# Out:
#             High price  Mid price  Low price  Average price  Volume(kg)  \
# 日期
# 2011-01-01       29.40      22.90      12.90           22.1         NaN
# 2011-01-02       27.10      22.40      14.30           21.7         NaN
# 2011-01-03       28.35      22.65      14.45           23.3         NaN
# 2011-01-04       29.60      22.90      14.60           24.9         NaN
# 2011-01-05       27.30      22.30      16.00           23.6         NaN
# ...                ...        ...        ...            ...         ...
# 2021-06-10       25.80      23.20      13.80           23.1         NaN
# 2021-06-11       26.00      23.80      17.00           23.7         NaN
# 2021-06-12       26.20      18.60      11.90           22.7         NaN
# 2021-06-13       27.50      23.00      15.00           23.7         NaN
# 2021-06-14       28.80      24.10      16.80           25.0         NaN
#
#             scarletbanana_Avg_p  guava_Avg_p  banana_Avg_p(-1d)  \
# 日期
# 2011-01-01                 29.7         33.7               22.1
# 2011-01-02                 27.5         36.1               22.1
# 2011-01-03                 32.3         36.1               21.7
# 2011-01-04                 37.1         36.1               23.3
# 2011-01-05                 41.2         35.6               24.9
# ...                         ...          ...                ...
# 2021-06-10                 28.7         32.6               23.2
# 2021-06-11                 31.5         27.6               23.1
# 2021-06-12                 30.1         25.3               23.7
# 2021-06-13                 31.3         20.8               22.7
# 2021-06-14                 26.1         21.9               23.7
#
#             banana_Avg_p(5d)  StnPres  ...  PrecpHour  PrecpMax10  PrecpMax60  \
# 日期                                     ...
# 2011-01-01              23.1    903.2  ...        0.0         0.0         0.0
# 2011-01-02              23.1    905.0  ...        0.0         0.0         0.0
# 2011-01-03              23.1    904.4  ...        0.0         0.0         0.0
# 2011-01-04              23.1    904.7  ...        0.0         0.0         0.0
# 2011-01-05              23.1    904.5  ...        4.4         0.5         0.5
# ...                      ...      ...  ...        ...         ...         ...
# 2021-06-10              22.5    898.6  ...        6.2         2.5         6.0
# 2021-06-11              22.6    899.3  ...        0.3         0.5         0.5
# 2021-06-12              22.7    901.7  ...        6.2         7.5        14.5
# 2021-06-13              23.3    901.4  ...        1.7         5.5        11.5
# 2021-06-14              23.6    898.8  ...        0.0         0.0         0.0
#
#             SunShine  SunShineRate  GloblRad  VisbMean  EvapA  UVI Max  \
# 日期
# 2011-01-01       9.6          90.2     12.96      10.0    1.8        5
# 2011-01-02       9.7          91.1     13.20      10.8    2.0        6
# 2011-01-03       1.1          10.3      3.39      11.0    0.4        3
# 2011-01-04       6.4          60.0     11.96      14.0   -1.4        6
# 2011-01-05       5.1          47.8     10.17      17.0   -1.2        6
# ...              ...           ...       ...       ...    ...      ...
# 2021-06-10       4.4          32.5     16.21      22.5   -2.8        8
# 2021-06-11       3.8          28.1     16.23      25.5   -2.0        9
# 2021-06-12       2.8          20.7     14.51       7.5   -3.1        9
# 2021-06-13       4.9          35.4     20.10      22.5   -3.9        9
# 2021-06-14       6.3          46.5     22.43      25.8    4.2       10
#
#             Cloud Amount
# 日期
# 2011-01-01           1.3
# 2011-01-02           1.7
# 2011-01-03           8.8
# 2011-01-04           5.8
# 2011-01-05           7.0
# ...                  ...
# 2021-06-10           7.2
# 2021-06-11           7.5
# 2021-06-12           7.8
# 2021-06-13           6.2
# 2021-06-14           5.8
#
# [3818 rows x 34 columns]

# %%
# 變換欄位順序 => 把average price拉出來放在最後一欄
col_target = list(df_num["Average price"])
df_num.drop(columns="Average price", inplace=True)
df_num.insert(26, "Average price", col_target)

# %%
df_num
# Out:
#             High price  Mid price  Low price  Volume(kg)  scarletbanana_Avg_p  \
# 日期
# 2011-01-01       29.40      22.90      12.90         NaN                 29.7
# 2011-01-02       27.10      22.40      14.30         NaN                 27.5
# 2011-01-03       28.35      22.65      14.45         NaN                 32.3
# 2011-01-04       29.60      22.90      14.60         NaN                 37.1
# 2011-01-05       27.30      22.30      16.00         NaN                 41.2
# ...                ...        ...        ...         ...                  ...
# 2021-06-10       25.80      23.20      13.80         NaN                 28.7
# 2021-06-11       26.00      23.80      17.00         NaN                 31.5
# 2021-06-12       26.20      18.60      11.90         NaN                 30.1
# 2021-06-13       27.50      23.00      15.00         NaN                 31.3
# 2021-06-14       28.80      24.10      16.80         NaN                 26.1
#
#             guava_Avg_p  banana_Avg_p(-1d)  banana_Avg_p(5d)  StnPres  \
# 日期
# 2011-01-01         33.7               22.1              23.1    903.2
# 2011-01-02         36.1               22.1              23.1    905.0
# 2011-01-03         36.1               21.7              23.1    904.4
# 2011-01-04         36.1               23.3              23.1    904.7
# 2011-01-05         35.6               24.9              23.1    904.5
# ...                 ...                ...               ...      ...
# 2021-06-10         32.6               23.2              22.5    898.6
# 2021-06-11         27.6               23.1              22.6    899.3
# 2021-06-12         25.3               23.7              22.7    901.7
# 2021-06-13         20.8               22.7              23.3    901.4
# 2021-06-14         21.9               23.7              23.6    898.8
#
#             SeaPres  ...  PrecpMax10  PrecpMax60  Average price  SunShine  \
# 日期                   ...
# 2011-01-01   1517.6  ...         0.0         0.0           22.1       9.6
# 2011-01-02   1533.4  ...         0.0         0.0           21.7       9.7
# 2011-01-03   1528.6  ...         0.0         0.0           23.3       1.1
# 2011-01-04   1532.7  ...         0.0         0.0           24.9       6.4
# 2011-01-05   1535.5  ...         0.5         0.5           23.6       5.1
# ...             ...  ...         ...         ...            ...       ...
# 2021-06-10   1493.7  ...         2.5         6.0           23.1       4.4
# 2021-06-11   1502.2  ...         0.5         0.5           23.7       3.8
# 2021-06-12   1524.9  ...         7.5        14.5           22.7       2.8
# 2021-06-13   1522.1  ...         5.5        11.5           23.7       4.9
# 2021-06-14   1498.2  ...         0.0         0.0           25.0       6.3
#
#             SunShineRate  GloblRad  VisbMean  EvapA  UVI Max  Cloud Amount
# 日期
# 2011-01-01          90.2     12.96      10.0    1.8        5           1.3
# 2011-01-02          91.1     13.20      10.8    2.0        6           1.7
# 2011-01-03          10.3      3.39      11.0    0.4        3           8.8
# 2011-01-04          60.0     11.96      14.0   -1.4        6           5.8
# 2011-01-05          47.8     10.17      17.0   -1.2        6           7.0
# ...                  ...       ...       ...    ...      ...           ...
# 2021-06-10          32.5     16.21      22.5   -2.8        8           7.2
# 2021-06-11          28.1     16.23      25.5   -2.0        9           7.5
# 2021-06-12          20.7     14.51       7.5   -3.1        9           7.8
# 2021-06-13          35.4     20.10      22.5   -3.9        9           6.2
# 2021-06-14          46.5     22.43      25.8    4.2       10           5.8
#
# [3818 rows x 34 columns]

# %%
df_num.hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8);

# %%
df_num_corr = df_num.corr()["Average price"][:-1]
df_num_corr
golden_features_list = df_num_corr[abs(df_num_corr) > 0.3].sort_values(ascending=False)
golden_features_list
# Out:
# Average price          1.000000
# banana_Avg_p(5d)       0.994256
# banana_Avg_p(-1d)      0.992499
# High price             0.991878
# Mid price              0.987450
# Low price              0.933741
# scarletbanana_Avg_p    0.764350
# guava_Avg_p            0.421073
# StnPresMax             0.326155
# StnPres                0.309694
# T Max                 -0.303373
# T Min                 -0.337118
# Td dew point          -0.337585
# Temperature           -0.337669
# Name: Average price, dtype: float64

# %% [markdown]
# #### 相關係數（Correlation）

# %%
for i in range(0, len(df_num.columns), 7):
    sns.pairplot(data = df_num, diag_kind= None,
                 x_vars = df_num.columns[i:i+7],
                 y_vars = 'Average price')

# %% [markdown]
# ### Feature to feature relationship

# %%
corr = df_num.drop('Average price', axis=1).corr()
plt.figure(figsize=(12, 10))

sns.heatmap(corr[(corr >= 0.3) | (corr <= -0.4)],
cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
annot=True, annot_kws={"size": 8}, square=True);
