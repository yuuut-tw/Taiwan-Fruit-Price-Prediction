# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, RepeatVector
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from tensorflow import keras

# %% [markdown]
# ### MySQL連線

# %%
username = 'root'
password = pwd
host_port = 'localhost:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
# test
fruit = "banana"
market = "台北二"
df= pd.read_sql(f"{fruit}_{market}", engine)
df
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 0    2011-01-01        31.4      9645.0               36.5       45.0
# 1    2011-01-02        32.0     12230.0               50.0       47.5
# 2    2011-01-03        32.2     12103.0               46.2       47.5
# 3    2011-01-04        32.4     11976.0               42.5       47.5
# 4    2011-01-05        33.2      7520.0               34.8       45.8
# ...         ...         ...         ...                ...        ...
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價
# 0             31.4          32.2
# 1             31.4          32.2
# 2             32.0          32.2
# 3             32.2          32.2
# 4             32.4          32.2
# ...            ...           ...
# 3868          35.2          37.7
# 3869          37.9          38.3
# 3870          40.7          38.0
# 3871          38.3          39.6
# 3872          46.1          42.1
#
# [3873 rows x 7 columns]

# %% [markdown]
# ### 四大市場共同測試

# %%
from my_libs.my_model_trainer_banana import *

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"]}
markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []

# 參數設定
n_future = 7
n_past = 60
epochs = 30
batch_size = 128


for Fruit, Type in fruits.items():
    for market in markets:
        print(f"Ongoing: {Fruit}_{market}" + "==="*30)
        
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=n_future, n_past=n_past)

        # 創造momdel
        model = model_creator(n_past=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=epochs, batch_size=batch_size)

        # 訓練集驗證
        prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        X_test, y_test = split_Xy(test_set_sc, n_future=n_future, n_past=n_past)

        # 測試集驗證
        prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        pred_list.append(prediction_test)
        actual_list.append(actual_test)
        
        # 儲存模型
        trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_predict_adjusted/{market}.h5")
# Out:
# Ongoing: banana_台北二==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 64)            18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 96ms/step - loss: 659215.6875 - val_loss: 2.1089
#
# Epoch 00001: val_loss improved from inf to 2.10887, saving model to weights.h5
# Epoch 2/30
# 19/19 [==============================] - 1s 76ms/step - loss: 4.1240 - val_loss: 1.6094
#
# Epoch 00002: val_loss improved from 2.10887 to 1.60941, saving model to weights.h5
# Epoch 3/30
# 19/19 [==============================] - 1s 79ms/step - loss: 3.5301 - val_loss: 1.2535
#
# Epoch 00003: val_loss improved from 1.60941 to 1.25352, saving model to weights.h5
# Epoch 4/30
# 19/19 [==============================] - 1s 76ms/step - loss: 3.0465 - val_loss: 0.9733
#
# Epoch 00004: val_loss improved from 1.25352 to 0.97328, saving model to weights.h5
# Epoch 5/30
# 19/19 [==============================] - 1s 77ms/step - loss: 2.6609 - val_loss: 0.7410
#
# Epoch 00005: val_loss improved from 0.97328 to 0.74098, saving model to weights.h5
# Epoch 6/30
# 19/19 [==============================] - 1s 76ms/step - loss: 2.3420 - val_loss: 0.5877
#
# Epoch 00006: val_loss improved from 0.74098 to 0.58766, saving model to weights.h5
# Epoch 7/30
# 19/19 [==============================] - 2s 80ms/step - loss: 2.0986 - val_loss: 0.4800
#
# Epoch 00007: val_loss improved from 0.58766 to 0.48003, saving model to weights.h5
# Epoch 8/30
# 19/19 [==============================] - 1s 79ms/step - loss: 1.8991 - val_loss: 0.4006
#
# Epoch 00008: val_loss improved from 0.48003 to 0.40063, saving model to weights.h5
# Epoch 9/30
# 19/19 [==============================] - 2s 80ms/step - loss: 1.7427 - val_loss: 0.3414
#
# Epoch 00009: val_loss improved from 0.40063 to 0.34143, saving model to weights.h5
# Epoch 10/30
# 19/19 [==============================] - 1s 77ms/step - loss: 1.6246 - val_loss: 0.2975
#
# Epoch 00010: val_loss improved from 0.34143 to 0.29748, saving model to weights.h5
# Epoch 11/30
# 19/19 [==============================] - 1s 77ms/step - loss: 1.5122 - val_loss: 0.2657
#
# Epoch 00011: val_loss improved from 0.29748 to 0.26570, saving model to weights.h5
# Epoch 12/30
# 19/19 [==============================] - 1s 76ms/step - loss: 1.4177 - val_loss: 0.2435
#
# Epoch 00012: val_loss improved from 0.26570 to 0.24349, saving model to weights.h5
# Epoch 13/30
# 19/19 [==============================] - 2s 81ms/step - loss: 1.3402 - val_loss: 0.2296
#
# Epoch 00013: val_loss improved from 0.24349 to 0.22964, saving model to weights.h5
# Epoch 14/30
# 19/19 [==============================] - 1s 78ms/step - loss: 1.2835 - val_loss: 0.2219
#
# Epoch 00014: val_loss improved from 0.22964 to 0.22188, saving model to weights.h5
# Epoch 15/30
# 19/19 [==============================] - 1s 77ms/step - loss: 1.2354 - val_loss: 0.2189
#
# Epoch 00015: val_loss improved from 0.22188 to 0.21887, saving model to weights.h5
# Epoch 16/30
# 19/19 [==============================] - 2s 93ms/step - loss: 1.2128 - val_loss: 0.2198
#
# Epoch 00016: val_loss did not improve from 0.21887
# Epoch 17/30
# 19/19 [==============================] - 2s 93ms/step - loss: 1.1533 - val_loss: 0.2229
#
# Epoch 00017: val_loss did not improve from 0.21887
# Epoch 18/30
# 19/19 [==============================] - 2s 94ms/step - loss: 1.1431 - val_loss: 0.2288
#
# Epoch 00018: val_loss did not improve from 0.21887
# Epoch 19/30
# 19/19 [==============================] - 2s 93ms/step - loss: 1.1038 - val_loss: 0.2358
#
# Epoch 00019: val_loss did not improve from 0.21887
# Epoch 20/30
# 19/19 [==============================] - 2s 92ms/step - loss: 1.0951 - val_loss: 0.2435
#
# Epoch 00020: val_loss did not improve from 0.21887
# Epoch 21/30
# 19/19 [==============================] - 2s 92ms/step - loss: 1.0885 - val_loss: 0.2514
#
# Epoch 00021: val_loss did not improve from 0.21887
# Epoch 22/30
# 19/19 [==============================] - 2s 90ms/step - loss: 1.0711 - val_loss: 0.2606
#
# Epoch 00022: val_loss did not improve from 0.21887
# Epoch 23/30
# 19/19 [==============================] - 2s 91ms/step - loss: 1.0633 - val_loss: 0.2695
#
# Epoch 00023: val_loss did not improve from 0.21887
# Epoch 24/30
# 19/19 [==============================] - 2s 90ms/step - loss: 1.0753 - val_loss: 0.2775
#
# Epoch 00024: val_loss did not improve from 0.21887
# Epoch 25/30
# 19/19 [==============================] - 2s 92ms/step - loss: 1.0552 - val_loss: 0.2849
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.21887
# Epoch 00025: early stopping
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: banana_台北一==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 103ms/step - loss: 1.3213 - val_loss: 0.9044
#
# Epoch 00001: val_loss improved from inf to 0.90442, saving model to weights.h5
# Epoch 2/30
# 19/19 [==============================] - 2s 118ms/step - loss: 1.1921 - val_loss: 0.1874
#
# Epoch 00002: val_loss improved from 0.90442 to 0.18738, saving model to weights.h5
# Epoch 3/30
# 19/19 [==============================] - 2s 107ms/step - loss: 0.8034 - val_loss: 0.3233
#
# Epoch 00003: val_loss did not improve from 0.18738
# Epoch 4/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.7800 - val_loss: 0.2543
#
# Epoch 00004: val_loss did not improve from 0.18738
# Epoch 5/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.6412 - val_loss: 0.2237
#
# Epoch 00005: val_loss did not improve from 0.18738
# Epoch 6/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.4841 - val_loss: 0.1173
#
# Epoch 00006: val_loss improved from 0.18738 to 0.11727, saving model to weights.h5
# Epoch 7/30
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3842 - val_loss: 0.0729
#
# Epoch 00007: val_loss improved from 0.11727 to 0.07292, saving model to weights.h5
# Epoch 8/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3569 - val_loss: 0.0737
#
# Epoch 00008: val_loss did not improve from 0.07292
# Epoch 9/30
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3099 - val_loss: 0.0503
#
# Epoch 00009: val_loss improved from 0.07292 to 0.05028, saving model to weights.h5
# Epoch 10/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.2754 - val_loss: 0.0459
#
# Epoch 00010: val_loss improved from 0.05028 to 0.04588, saving model to weights.h5
# Epoch 11/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2801 - val_loss: 0.0442
#
# Epoch 00011: val_loss improved from 0.04588 to 0.04418, saving model to weights.h5
# Epoch 12/30
# 19/19 [==============================] - 2s 103ms/step - loss: 0.2667 - val_loss: 0.0453
#
# Epoch 00012: val_loss did not improve from 0.04418
# Epoch 13/30
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2568 - val_loss: 0.0468
#
# Epoch 00013: val_loss did not improve from 0.04418
# Epoch 14/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2464 - val_loss: 0.0376
#
# Epoch 00014: val_loss improved from 0.04418 to 0.03764, saving model to weights.h5
# Epoch 15/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2310 - val_loss: 0.0402
#
# Epoch 00015: val_loss did not improve from 0.03764
# Epoch 16/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.2208 - val_loss: 0.0449
#
# Epoch 00016: val_loss did not improve from 0.03764
# Epoch 17/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.2146 - val_loss: 0.0373
#
# Epoch 00017: val_loss improved from 0.03764 to 0.03726, saving model to weights.h5
# Epoch 18/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2048 - val_loss: 0.0403
#
# Epoch 00018: val_loss did not improve from 0.03726
# Epoch 19/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2041 - val_loss: 0.0491
#
# Epoch 00019: val_loss did not improve from 0.03726
# Epoch 20/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.1930 - val_loss: 0.0421
#
# Epoch 00020: val_loss did not improve from 0.03726
# Epoch 21/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.1902 - val_loss: 0.0466
#
# Epoch 00021: val_loss did not improve from 0.03726
# Epoch 22/30
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1767 - val_loss: 0.0338
#
# Epoch 00022: val_loss improved from 0.03726 to 0.03384, saving model to weights.h5
# Epoch 23/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.1802 - val_loss: 0.0464
#
# Epoch 00023: val_loss did not improve from 0.03384
# Epoch 24/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.1769 - val_loss: 0.0426
#
# Epoch 00024: val_loss did not improve from 0.03384
# Epoch 25/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1664 - val_loss: 0.0571
#
# Epoch 00025: val_loss did not improve from 0.03384
# Epoch 26/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.1691 - val_loss: 0.0513
#
# Epoch 00026: val_loss did not improve from 0.03384
# Epoch 27/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1656 - val_loss: 0.0729
#
# Epoch 00027: val_loss did not improve from 0.03384
# Epoch 28/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.1665 - val_loss: 0.0638
#
# Epoch 00028: val_loss did not improve from 0.03384
# Epoch 29/30
# 19/19 [==============================] - 2s 96ms/step - loss: 0.1593 - val_loss: 0.1223
#
# Epoch 00029: val_loss did not improve from 0.03384
# Epoch 30/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.1729 - val_loss: 0.0961
#
# Epoch 00030: val_loss did not improve from 0.03384
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: banana_三重區==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 100ms/step - loss: 2.1708 - val_loss: 1.6310
#
# Epoch 00001: val_loss improved from inf to 1.63099, saving model to weights.h5
# Epoch 2/30
# 19/19 [==============================] - 2s 100ms/step - loss: 1.9939 - val_loss: 0.3658
#
# Epoch 00002: val_loss improved from 1.63099 to 0.36580, saving model to weights.h5
# Epoch 3/30
# 19/19 [==============================] - 2s 95ms/step - loss: 1.1338 - val_loss: 0.4303
#
# Epoch 00003: val_loss did not improve from 0.36580
# Epoch 4/30
# 19/19 [==============================] - 2s 92ms/step - loss: 1.2170 - val_loss: 0.2716
#
# Epoch 00004: val_loss improved from 0.36580 to 0.27161, saving model to weights.h5
# Epoch 5/30
# 19/19 [==============================] - 2s 92ms/step - loss: 1.0139 - val_loss: 0.2685
#
# Epoch 00005: val_loss improved from 0.27161 to 0.26852, saving model to weights.h5
# Epoch 6/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.8732 - val_loss: 0.2449
#
# Epoch 00006: val_loss improved from 0.26852 to 0.24490, saving model to weights.h5
# Epoch 7/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.7076 - val_loss: 0.2603
#
# Epoch 00007: val_loss did not improve from 0.24490
# Epoch 8/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.5467 - val_loss: 0.0916
#
# Epoch 00008: val_loss improved from 0.24490 to 0.09161, saving model to weights.h5
# Epoch 9/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.4124 - val_loss: 0.0711
#
# Epoch 00009: val_loss improved from 0.09161 to 0.07114, saving model to weights.h5
# Epoch 10/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.3815 - val_loss: 0.0746
#
# Epoch 00010: val_loss did not improve from 0.07114
# Epoch 11/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.3728 - val_loss: 0.0916
#
# Epoch 00011: val_loss did not improve from 0.07114
# Epoch 12/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.3386 - val_loss: 0.0878
#
# Epoch 00012: val_loss did not improve from 0.07114
# Epoch 13/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.3158 - val_loss: 0.0652
#
# Epoch 00013: val_loss improved from 0.07114 to 0.06516, saving model to weights.h5
# Epoch 14/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3029 - val_loss: 0.1085
#
# Epoch 00014: val_loss did not improve from 0.06516
# Epoch 15/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2865 - val_loss: 0.0595
#
# Epoch 00015: val_loss improved from 0.06516 to 0.05951, saving model to weights.h5
# Epoch 16/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2810 - val_loss: 0.0841
#
# Epoch 00016: val_loss did not improve from 0.05951
# Epoch 17/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.2834 - val_loss: 0.0598
#
# Epoch 00017: val_loss did not improve from 0.05951
# Epoch 18/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.2683 - val_loss: 0.0783
#
# Epoch 00018: val_loss did not improve from 0.05951
# Epoch 19/30
# 19/19 [==============================] - 2s 104ms/step - loss: 0.2591 - val_loss: 0.0743
#
# Epoch 00019: val_loss did not improve from 0.05951
# Epoch 20/30
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2584 - val_loss: 0.0460
#
# Epoch 00020: val_loss improved from 0.05951 to 0.04597, saving model to weights.h5
# Epoch 21/30
# 19/19 [==============================] - 2s 103ms/step - loss: 0.2436 - val_loss: 0.0708
#
# Epoch 00021: val_loss did not improve from 0.04597
# Epoch 22/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.2313 - val_loss: 0.0589
#
# Epoch 00022: val_loss did not improve from 0.04597
# Epoch 23/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2134 - val_loss: 0.0826
#
# Epoch 00023: val_loss did not improve from 0.04597
# Epoch 24/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2304 - val_loss: 0.0390
#
# Epoch 00024: val_loss improved from 0.04597 to 0.03898, saving model to weights.h5
# Epoch 25/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.2237 - val_loss: 0.0559
#
# Epoch 00025: val_loss did not improve from 0.03898
# Epoch 26/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2235 - val_loss: 0.0827
#
# Epoch 00026: val_loss did not improve from 0.03898
# Epoch 27/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2137 - val_loss: 0.0470
#
# Epoch 00027: val_loss did not improve from 0.03898
# Epoch 28/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2096 - val_loss: 0.0506
#
# Epoch 00028: val_loss did not improve from 0.03898
# Epoch 29/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.2102 - val_loss: 0.0374
#
# Epoch 00029: val_loss improved from 0.03898 to 0.03742, saving model to weights.h5
# Epoch 30/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2109 - val_loss: 0.0668
#
# Epoch 00030: val_loss did not improve from 0.03742
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: banana_台中市==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 5s 107ms/step - loss: 1.7166 - val_loss: 0.5245
#
# Epoch 00001: val_loss improved from inf to 0.52446, saving model to weights.h5
# Epoch 2/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.9734 - val_loss: 0.6437
#
# Epoch 00002: val_loss did not improve from 0.52446
# Epoch 3/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.8360 - val_loss: 0.1868
#
# Epoch 00003: val_loss improved from 0.52446 to 0.18680, saving model to weights.h5
# Epoch 4/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.5816 - val_loss: 0.1124
#
# Epoch 00004: val_loss improved from 0.18680 to 0.11244, saving model to weights.h5
# Epoch 5/30
# 19/19 [==============================] - 2s 97ms/step - loss: 0.7138 - val_loss: 0.2185
#
# Epoch 00005: val_loss did not improve from 0.11244
# Epoch 6/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.5770 - val_loss: 0.1286
#
# Epoch 00006: val_loss did not improve from 0.11244
# Epoch 7/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.3822 - val_loss: 0.0818
#
# Epoch 00007: val_loss improved from 0.11244 to 0.08177, saving model to weights.h5
# Epoch 8/30
# 19/19 [==============================] - 2s 87ms/step - loss: 0.3188 - val_loss: 0.0547
#
# Epoch 00008: val_loss improved from 0.08177 to 0.05470, saving model to weights.h5
# Epoch 9/30
# 19/19 [==============================] - 2s 87ms/step - loss: 0.3033 - val_loss: 0.1045
#
# Epoch 00009: val_loss did not improve from 0.05470
# Epoch 10/30
# 19/19 [==============================] - 2s 87ms/step - loss: 0.3050 - val_loss: 0.1377
#
# Epoch 00010: val_loss did not improve from 0.05470
# Epoch 11/30
# 19/19 [==============================] - 2s 85ms/step - loss: 0.2772 - val_loss: 0.0656
#
# Epoch 00011: val_loss did not improve from 0.05470
# Epoch 12/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.2462 - val_loss: 0.0811
#
# Epoch 00012: val_loss did not improve from 0.05470
# Epoch 13/30
# 19/19 [==============================] - 2s 87ms/step - loss: 0.2226 - val_loss: 0.0355
#
# Epoch 00013: val_loss improved from 0.05470 to 0.03546, saving model to weights.h5
# Epoch 14/30
# 19/19 [==============================] - 2s 86ms/step - loss: 0.2512 - val_loss: 0.1440
#
# Epoch 00014: val_loss did not improve from 0.03546
# Epoch 15/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2363 - val_loss: 0.0351
#
# Epoch 00015: val_loss improved from 0.03546 to 0.03512, saving model to weights.h5
# Epoch 16/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.2378 - val_loss: 0.1424
#
# Epoch 00016: val_loss did not improve from 0.03512
# Epoch 17/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.2155 - val_loss: 0.0375
#
# Epoch 00017: val_loss did not improve from 0.03512
# Epoch 18/30
# 19/19 [==============================] - 2s 87ms/step - loss: 0.1867 - val_loss: 0.0837
#
# Epoch 00018: val_loss did not improve from 0.03512
# Epoch 19/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.1814 - val_loss: 0.0287
#
# Epoch 00019: val_loss improved from 0.03512 to 0.02874, saving model to weights.h5
# Epoch 20/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.1799 - val_loss: 0.0730
#
# Epoch 00020: val_loss did not improve from 0.02874
# Epoch 21/30
# 19/19 [==============================] - 2s 100ms/step - loss: 0.1687 - val_loss: 0.0268
#
# Epoch 00021: val_loss improved from 0.02874 to 0.02683, saving model to weights.h5
# Epoch 22/30
# 19/19 [==============================] - 2s 104ms/step - loss: 0.1652 - val_loss: 0.0716
#
# Epoch 00022: val_loss did not improve from 0.02683
# Epoch 23/30
# 19/19 [==============================] - 2s 102ms/step - loss: 0.1671 - val_loss: 0.0264
#
# Epoch 00023: val_loss improved from 0.02683 to 0.02642, saving model to weights.h5
# Epoch 24/30
# 19/19 [==============================] - 2s 99ms/step - loss: 0.1574 - val_loss: 0.0555
#
# Epoch 00024: val_loss did not improve from 0.02642
# Epoch 25/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1582 - val_loss: 0.0283
#
# Epoch 00025: val_loss did not improve from 0.02642
# Epoch 26/30
# 19/19 [==============================] - 2s 97ms/step - loss: 0.1413 - val_loss: 0.0383
#
# Epoch 00026: val_loss did not improve from 0.02642
# Epoch 27/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1409 - val_loss: 0.0367
#
# Epoch 00027: val_loss did not improve from 0.02642
# Epoch 28/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1360 - val_loss: 0.0479
#
# Epoch 00028: val_loss did not improve from 0.02642
# Epoch 29/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.1315 - val_loss: 0.0267
#
# Epoch 00029: val_loss did not improve from 0.02642
# Epoch 30/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.1333 - val_loss: 0.0351
#
# Epoch 00030: val_loss did not improve from 0.02642
# X's shape: (708, 60, 6)
# y's shape: (708, 7)

# %% [markdown]
# ### Visualization

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True) #, squeeze=True)

markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = "Banana"

n = 7
index = 300
for i in list(range(4)):
    ax = fig.add_subplot(2, 2, i+1)
    ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="o")
    ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
    if i <= 4:
        fruit = fruits[0]
    else:
        fruit = fruits[1]
        
    ax.set_title(f"{markets[i%4]} - {fruit} price forecast (7 days)")
    ax.legend(loc="upper right")

# %% [markdown]
# ### 預測結果評估(rmse, mape, mad)
# - mape : 平均絕對百分比誤差(Mean absolute percentage error)
# - rmse : 均方根差(root-mean-square error)
# - mad : 平均絕對偏差（Mean Absolute Deviation)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# 數值評估
def evaluation_funcs(y_pred, y_true):
    RMSE = round(mean_squared_error(y_pred, y_true, squared=False), 2)
    MAPE = round(np.mean(np.abs((y_true - y_pred) / y_true)) * 100, 2)
    MAD = round(sum(np.abs((y_true - y_pred) / len(y_true))), 2)
    
    return RMSE, MAPE, MAD

# %%
rmse_output = []
mape_output = []
mad_output = []

index = 300

for i in list(range(4)):
    RMSE, MAPE, MAD = evaluation_funcs(pred_list[i][index], actual_list[i][index])
    rmse_output.append(RMSE)
    mape_output.append(MAPE)
    mad_output.append(MAD)

indexs = ['Banana_Taipei1', 'Banana_Taipei2', 'Banana_Sanchong', 'Banana_Taichung']
df_result_evaluation = pd.DataFrame({"RMSE" : rmse_output,
                                     "MAPE" : mape_output,
                                     "MAD" : mad_output}, index= indexs)

df_result_evaluation
# Out:
#                  RMSE  MAPE   MAD
# Banana_Taipei1   2.33  5.30  2.12
# Banana_Taipei2   1.19  2.93  1.06
# Banana_Sanchong  0.77  1.74  0.62
# Banana_Taichung  1.31  2.80  1.02
