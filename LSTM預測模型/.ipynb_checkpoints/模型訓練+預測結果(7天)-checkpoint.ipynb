# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

from tensorflow import keras

# %% [markdown]
# ### Loading Data From Database(MySQL)

# %%
username = 'yuting'
password = 'yuting'
host_port = '35.194.136.165:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
# test

fruit = "banana"
market = "台北二"
df_test = pd.read_sql(f"{fruit}_{market}", engine)
df_test.head()
# Out:
#           日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 0 2011-01-01        31.4      9645.0               36.5       45.0
# 1 2011-01-02        32.0     12230.0               50.0       47.5
# 2 2011-01-03        32.2     12103.0               46.2       47.5
# 3 2011-01-04        32.4     11976.0               42.5       47.5
# 4 2011-01-05        33.2      7520.0               34.8       45.8
#
#    banana_前日平均價  banana_5日平均價
# 0          31.4          32.2
# 1          31.4          32.2
# 2          32.0          32.2
# 3          32.2          32.2
# 4          32.4          32.2

# %% [markdown]
# ### 模型訓練

# %% [markdown]
# ##### 訓練集&測試集

# %%
def train_test_split(df):
    test_samples = int(df.shape[0]*0.2)
    
    # 訓練集
    train_data = df.iloc[:-test_samples, :]
    #train_data.drop(columns="日期", inplace=True)
    train_set = train_data.iloc[:, 1:].values           # 取得train_set(array)
 
    
    # 測試集
    test_data = df.iloc[-test_samples:, :]
    #test_data.drop(columns="日期", inplace=True)
    test_set = test_data.iloc[:, 1:].values             # 取得test_set(array)
       
    return train_set, test_set

# %% [markdown]
# ##### 資料標準化

# %%
def data_normalization(input_set):
    
    # 訓練集(scaler)
    sc = StandardScaler()
    input_set_sc = sc.fit_transform(input_set[:, :])

    sc_target = StandardScaler()
    sc_target.fit_transform(input_set[:, 0:1])
    
    return input_set_sc, sc_target

# %% [markdown]
# ##### 創造X、y資料

# %%
def split_Xy(input_set_sc, n_future, n_past):
    X = []
    y = []

    for i in range(n_past, len(input_set_sc)-n_future+1): # 扣掉最後預測天數已符合y_test的length 
        X.append(input_set_sc[i-n_past:i, :])             # X = 前30天資料
        y.append(input_set_sc[i:i+n_future, 0])           # y = 後7天價格

    X, y = np.array(X), np.array(y) 
    
    print("X's shape: {}".format(X.shape))
    print("y's shape: {}".format(y.shape))
    
    return X, y

# %% [markdown]
# ##### 建立模型

# %%
def model_creator(n_steps, n_features):
    model = Sequential()
    
    # 1st layer 
    # input_shape => n_step, n_feature 

    model.add(LSTM(units=64, activation="relu", input_shape=(n_steps, n_features), return_sequences=True)) 

    model.add(LSTM(units=32, activation="relu", return_sequences=False))          

    model.add(Dropout(0.2))

    model.add(Dense(y_train.shape[1]))          

    model.summary() 
     
    return model

# %% [markdown]
# ##### 訓練模型

# %%
def model_trainer(model, X_train, y_train, epoch, batch_size):
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    # 提升訓練效率
    es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
    rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
    mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
    
    history = model.fit(X_train, y_train, epochs=epoch, 
                        batch_size=batch_size,
                        callbacks=[es, rlr, mcp], 
                        validation_split=0.1, 
                        verbose=1)
    # 視覺化
#     plt.plot(history.history['loss'], label='Training loss')
#     plt.plot(history.history['val_loss'], label='Validation loss')
#     plt.legend()
    print("loss: ", history.history['loss'][-1])
    print("val_loss: ", history.history['val_loss'][-1])
    
    return model

# %% [markdown]
# ##### 驗證模型準確率

# %%
def model_validation(model, X, y, sc_target):
    
    # 預測
    prediction = model.predict(X)
    prediction = sc_target.inverse_transform(prediction)
    actual = sc_target.inverse_transform(y)
    
    rmse_result = []
    for i in range(len(prediction)):
        rmse = mean_squared_error(prediction[i], actual[i], squared=False)
        rmse_result.append(rmse)

    pd.DataFrame({"rmse":rmse_result}).plot()
    
    return prediction, actual

# %%
from my_libs.my_model_trainer import *

# %% [markdown]
# ### 從SQL取資料進行模型訓練 => 完成後存成h5檔(共8個)

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']


for Fruit, Type in fruits.items():
    for market in markets:
    
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=7, n_past=30)

        # 創造momdel
        model = model_creator(n_steps=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=12, batch_size=128)

        # 訓練集驗證
        # prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        # test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        # X_test, y_test = split_Xy(test_set_sc, n_future=5, n_past=30)

        # 測試集驗證
        # prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        # 儲存模型
        # trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_Price/{market}.h5")
# Out:
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 55ms/step - loss: 0.6568 - val_loss: 0.0703
#
# Epoch 00001: val_loss improved from inf to 0.07031, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.3146 - val_loss: 0.0536
#
# Epoch 00002: val_loss improved from 0.07031 to 0.05360, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.2035 - val_loss: 0.0499
#
# Epoch 00003: val_loss improved from 0.05360 to 0.04989, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.1632 - val_loss: 0.0403
#
# Epoch 00004: val_loss improved from 0.04989 to 0.04032, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1544 - val_loss: 0.0389
#
# Epoch 00005: val_loss improved from 0.04032 to 0.03893, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1389 - val_loss: 0.0380
#
# Epoch 00006: val_loss improved from 0.03893 to 0.03804, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 38ms/step - loss: 0.1288 - val_loss: 0.0389
#
# Epoch 00007: val_loss did not improve from 0.03804
# Epoch 8/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1172 - val_loss: 0.0381
#
# Epoch 00008: val_loss did not improve from 0.03804
# Epoch 9/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1099 - val_loss: 0.0365
#
# Epoch 00009: val_loss improved from 0.03804 to 0.03651, saving model to weights.h5
# Epoch 10/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1034 - val_loss: 0.0402
#
# Epoch 00010: val_loss did not improve from 0.03651
# Epoch 11/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1039 - val_loss: 0.0370
#
# Epoch 00011: val_loss did not improve from 0.03651
# Epoch 12/12
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0949 - val_loss: 0.0401
#
# Epoch 00012: val_loss did not improve from 0.03651
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 30, 64)            18176
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 52ms/step - loss: 0.7104 - val_loss: 0.1025
#
# Epoch 00001: val_loss improved from inf to 0.10245, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.3112 - val_loss: 0.0986
#
# Epoch 00002: val_loss improved from 0.10245 to 0.09861, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 38ms/step - loss: 0.1876 - val_loss: 0.0726
#
# Epoch 00003: val_loss improved from 0.09861 to 0.07262, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1549 - val_loss: 0.0703
#
# Epoch 00004: val_loss improved from 0.07262 to 0.07028, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1480 - val_loss: 0.0663
#
# Epoch 00005: val_loss improved from 0.07028 to 0.06634, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.1423 - val_loss: 0.0636
#
# Epoch 00006: val_loss improved from 0.06634 to 0.06364, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1342 - val_loss: 0.0557
#
# Epoch 00007: val_loss improved from 0.06364 to 0.05568, saving model to weights.h5
# Epoch 8/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1232 - val_loss: 0.0608
#
# Epoch 00008: val_loss did not improve from 0.05568
# Epoch 9/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1163 - val_loss: 0.0591
#
# Epoch 00009: val_loss did not improve from 0.05568
# Epoch 10/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1097 - val_loss: 0.0526
#
# Epoch 00010: val_loss improved from 0.05568 to 0.05263, saving model to weights.h5
# Epoch 11/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1072 - val_loss: 0.0509
#
# Epoch 00011: val_loss improved from 0.05263 to 0.05087, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1025 - val_loss: 0.0552
#
# Epoch 00012: val_loss did not improve from 0.05087
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 30, 64)            18176
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 5s 60ms/step - loss: 0.8315 - val_loss: 0.1419
#
# Epoch 00001: val_loss improved from inf to 0.14191, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.3833 - val_loss: 0.1043
#
# Epoch 00002: val_loss improved from 0.14191 to 0.10430, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.1953 - val_loss: 0.0953
#
# Epoch 00003: val_loss improved from 0.10430 to 0.09534, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 39ms/step - loss: 0.1555 - val_loss: 0.0869
#
# Epoch 00004: val_loss improved from 0.09534 to 0.08690, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1271 - val_loss: 0.0827
#
# Epoch 00005: val_loss improved from 0.08690 to 0.08268, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1137 - val_loss: 0.0778
#
# Epoch 00006: val_loss improved from 0.08268 to 0.07777, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1039 - val_loss: 0.0723
#
# Epoch 00007: val_loss improved from 0.07777 to 0.07225, saving model to weights.h5
# Epoch 8/12
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0981 - val_loss: 0.0660
#
# Epoch 00008: val_loss improved from 0.07225 to 0.06596, saving model to weights.h5
# Epoch 9/12
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0891 - val_loss: 0.0630
#
# Epoch 00009: val_loss improved from 0.06596 to 0.06301, saving model to weights.h5
# Epoch 10/12
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0819 - val_loss: 0.0671
#
# Epoch 00010: val_loss did not improve from 0.06301
# Epoch 11/12
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0803 - val_loss: 0.0623
#
# Epoch 00011: val_loss improved from 0.06301 to 0.06227, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0797 - val_loss: 0.0573
#
# Epoch 00012: val_loss improved from 0.06227 to 0.05728, saving model to weights.h5
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 30, 64)            18176
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 3s 49ms/step - loss: 0.5206 - val_loss: 0.0856
#
# Epoch 00001: val_loss improved from inf to 0.08563, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.2171 - val_loss: 0.0626
#
# Epoch 00002: val_loss improved from 0.08563 to 0.06258, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.1517 - val_loss: 0.0549
#
# Epoch 00003: val_loss improved from 0.06258 to 0.05486, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.1310 - val_loss: 0.0515
#
# Epoch 00004: val_loss improved from 0.05486 to 0.05149, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 39ms/step - loss: 0.1180 - val_loss: 0.0513
#
# Epoch 00005: val_loss improved from 0.05149 to 0.05131, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.1072 - val_loss: 0.0479
#
# Epoch 00006: val_loss improved from 0.05131 to 0.04787, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0996 - val_loss: 0.0471
#
# Epoch 00007: val_loss improved from 0.04787 to 0.04706, saving model to weights.h5
# Epoch 8/12
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0982 - val_loss: 0.0449
#
# Epoch 00008: val_loss improved from 0.04706 to 0.04494, saving model to weights.h5
# Epoch 9/12
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0908 - val_loss: 0.0460
#
# Epoch 00009: val_loss did not improve from 0.04494
# Epoch 10/12
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0841 - val_loss: 0.0426
#
# Epoch 00010: val_loss improved from 0.04494 to 0.04265, saving model to weights.h5
# Epoch 11/12
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0797 - val_loss: 0.0406
#
# Epoch 00011: val_loss improved from 0.04265 to 0.04059, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0763 - val_loss: 0.0404
#
# Epoch 00012: val_loss improved from 0.04059 to 0.04045, saving model to weights.h5
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 30, 64)            18176
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 54ms/step - loss: 0.8190 - val_loss: 0.3865
#
# Epoch 00001: val_loss improved from inf to 0.38649, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 39ms/step - loss: 0.4704 - val_loss: 0.2084
#
# Epoch 00002: val_loss improved from 0.38649 to 0.20839, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 41ms/step - loss: 0.3243 - val_loss: 0.1410
#
# Epoch 00003: val_loss improved from 0.20839 to 0.14095, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.2511 - val_loss: 0.1471
#
# Epoch 00004: val_loss did not improve from 0.14095
# Epoch 5/12
# 22/22 [==============================] - 1s 40ms/step - loss: 0.2106 - val_loss: 0.1351
#
# Epoch 00005: val_loss improved from 0.14095 to 0.13512, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1904 - val_loss: 0.1191
#
# Epoch 00006: val_loss improved from 0.13512 to 0.11906, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1771 - val_loss: 0.1272
#
# Epoch 00007: val_loss did not improve from 0.11906
# Epoch 8/12
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1705 - val_loss: 0.1289
#
# Epoch 00008: val_loss did not improve from 0.11906
# Epoch 9/12
# 22/22 [==============================] - 1s 50ms/step - loss: 0.1622 - val_loss: 0.1397
#
# Epoch 00009: val_loss did not improve from 0.11906
# Epoch 10/12
# 22/22 [==============================] - 1s 48ms/step - loss: 0.1534 - val_loss: 0.1162
#
# Epoch 00010: val_loss improved from 0.11906 to 0.11619, saving model to weights.h5
# Epoch 11/12
# 22/22 [==============================] - 1s 50ms/step - loss: 0.1458 - val_loss: 0.1298
#
# Epoch 00011: val_loss did not improve from 0.11619
# Epoch 12/12
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1429 - val_loss: 0.1195
#
# Epoch 00012: val_loss did not improve from 0.11619
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 49ms/step - loss: 0.7882 - val_loss: 0.4039
#
# Epoch 00001: val_loss improved from inf to 0.40385, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.4374 - val_loss: 0.1899
#
# Epoch 00002: val_loss improved from 0.40385 to 0.18986, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.3013 - val_loss: 0.1235
#
# Epoch 00003: val_loss improved from 0.18986 to 0.12351, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.2408 - val_loss: 0.1131
#
# Epoch 00004: val_loss improved from 0.12351 to 0.11314, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.2171 - val_loss: 0.1094
#
# Epoch 00005: val_loss improved from 0.11314 to 0.10945, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 49ms/step - loss: 0.2005 - val_loss: 0.1189
#
# Epoch 00006: val_loss did not improve from 0.10945
# Epoch 7/12
# 22/22 [==============================] - 1s 50ms/step - loss: 0.1872 - val_loss: 0.1184
#
# Epoch 00007: val_loss did not improve from 0.10945
# Epoch 8/12
# 22/22 [==============================] - 1s 49ms/step - loss: 0.1785 - val_loss: 0.1199
#
# Epoch 00008: val_loss did not improve from 0.10945
# Epoch 9/12
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1760 - val_loss: 0.1199
#
# Epoch 00009: val_loss did not improve from 0.10945
# Epoch 10/12
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1701 - val_loss: 0.1132
#
# Epoch 00010: val_loss did not improve from 0.10945
# Epoch 11/12
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1656 - val_loss: 0.1270
#
# Epoch 00011: val_loss did not improve from 0.10945
# Epoch 12/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1619 - val_loss: 0.1132
#
# Epoch 00012: val_loss did not improve from 0.10945
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 53ms/step - loss: 0.7853 - val_loss: 0.3409
#
# Epoch 00001: val_loss improved from inf to 0.34087, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.4302 - val_loss: 0.2175
#
# Epoch 00002: val_loss improved from 0.34087 to 0.21751, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 43ms/step - loss: 0.2992 - val_loss: 0.1570
#
# Epoch 00003: val_loss improved from 0.21751 to 0.15704, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 49ms/step - loss: 0.2301 - val_loss: 0.1289
#
# Epoch 00004: val_loss improved from 0.15704 to 0.12887, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1944 - val_loss: 0.1234
#
# Epoch 00005: val_loss improved from 0.12887 to 0.12341, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1718 - val_loss: 0.1229
#
# Epoch 00006: val_loss improved from 0.12341 to 0.12293, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 66ms/step - loss: 0.1642 - val_loss: 0.1302
#
# Epoch 00007: val_loss did not improve from 0.12293
# Epoch 8/12
# 22/22 [==============================] - 2s 79ms/step - loss: 0.1540 - val_loss: 0.1198
#
# Epoch 00008: val_loss improved from 0.12293 to 0.11984, saving model to weights.h5
# Epoch 9/12
# 22/22 [==============================] - 2s 74ms/step - loss: 0.1587 - val_loss: 0.1291
#
# Epoch 00009: val_loss did not improve from 0.11984
# Epoch 10/12
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1429 - val_loss: 0.1195
#
# Epoch 00010: val_loss improved from 0.11984 to 0.11954, saving model to weights.h5
# Epoch 11/12
# 22/22 [==============================] - 1s 48ms/step - loss: 0.1405 - val_loss: 0.1191
#
# Epoch 00011: val_loss improved from 0.11954 to 0.11905, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 63ms/step - loss: 0.1308 - val_loss: 0.1206
#
# Epoch 00012: val_loss did not improve from 0.11905
# X's shape: (3061, 30, 6)
# y's shape: (3061, 7)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 5s 67ms/step - loss: 0.7912 - val_loss: 0.3199
#
# Epoch 00001: val_loss improved from inf to 0.31994, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 45ms/step - loss: 0.4701 - val_loss: 0.1853
#
# Epoch 00002: val_loss improved from 0.31994 to 0.18528, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 52ms/step - loss: 0.3278 - val_loss: 0.1261
#
# Epoch 00003: val_loss improved from 0.18528 to 0.12612, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 52ms/step - loss: 0.2312 - val_loss: 0.1571
#
# Epoch 00004: val_loss did not improve from 0.12612
# Epoch 5/12
# 22/22 [==============================] - 1s 56ms/step - loss: 0.1889 - val_loss: 0.0749
#
# Epoch 00005: val_loss improved from 0.12612 to 0.07486, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 56ms/step - loss: 0.1654 - val_loss: 0.0711
#
# Epoch 00006: val_loss improved from 0.07486 to 0.07111, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1463 - val_loss: 0.0714
#
# Epoch 00007: val_loss did not improve from 0.07111
# Epoch 8/12
# 22/22 [==============================] - 1s 48ms/step - loss: 0.1358 - val_loss: 0.0720
#
# Epoch 00008: val_loss did not improve from 0.07111
# Epoch 9/12
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1319 - val_loss: 0.0682
#
# Epoch 00009: val_loss improved from 0.07111 to 0.06816, saving model to weights.h5
# Epoch 10/12
# 22/22 [==============================] - 1s 55ms/step - loss: 0.1294 - val_loss: 0.0688
#
# Epoch 00010: val_loss did not improve from 0.06816
# Epoch 11/12
# 22/22 [==============================] - 1s 60ms/step - loss: 0.1237 - val_loss: 0.0587
#
# Epoch 00011: val_loss improved from 0.06816 to 0.05870, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 53ms/step - loss: 0.1182 - val_loss: 0.0629
#
# Epoch 00012: val_loss did not improve from 0.05870

# %% [markdown]
# ### 從SQL取分析資料進行價格預測
# - 直接透過query取得資料進行分析
# - 預測結果存入DB

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']


for Fruit, Type in fruits.items():
    for market in markets:
        
        product = Type[0]
        same = Type[1]
        sub = Type[2]
        
        # 從SQL讀取分析資料，轉換成矩陣
        df_set = pd.read_sql_query(f"""select `{product}_平均價`, `{product}_交易量`, `{same}_平均價`, 
                                       `{sub}_平均價`, `{product}_前日平均價`, `{product}_5日平均價` 
                                       from {product}_{market}
                                       order by `日期` desc
                                       limit 30""", con).values 
        
        # 標準化
        df_set_sc, sc_target = data_normalization(df_set)
        
        # reshape => 需符合input的shape
        df_set_sc = df_set_sc.reshape(-1, 30, 6)
        
        # 載入model
        model_loaded = keras.models.load_model(f"models/{product}_Price/{market}.h5")
        
        # 進行預測
        pred_result = model_loaded(df_set_sc) # 使用model_loaded.predict(df_set_sc)會跳出tensorflow wwarning
        
        # 透過inverse_transform還原為原本數值
        output = sc_target.inverse_transform(pred_result)
        
        print(f"{Fruit}_{market}市場未來7日預測價: ", output.reshape(-1).round(1))
# Out:
# banana_台北二市場未來7日預測價:  [35.8 35.9 36.1 35.7 35.8 36.2 36.1]
# banana_台北一市場未來7日預測價:  [29.2 29.1 29.4 29.5 29.6 29.4 29.3]
# banana_三重區市場未來7日預測價:  [30.2 30.1 30.1 29.9 30.5 30.5 30.2]
# banana_台中市市場未來7日預測價:  [30.1 30.2 30.1 30.2 30.1 30.2 30.2]
# guava_台北二市場未來7日預測價:  [37.3 36.7 36.9 37.  37.7 37.6 37.9]
# guava_台北一市場未來7日預測價:  [36.3 36.6 36.1 36.9 36.7 36.2 37. ]
# guava_三重區市場未來7日預測價:  [29.4 29.2 29.3 29.2 30.  29.3 29.7]
# guava_台中市市場未來7日預測價:  [28.4 29.2 29.6 29.2 29.  28.9 29.1]
