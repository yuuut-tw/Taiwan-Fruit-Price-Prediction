# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

from tensorflow import keras

# %% [markdown]
# ### Loading Data From Database(MySQL)

# %%
username = 'yuting'
password = 'yuting'
host_port = '35.194.136.165:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
# test

fruit = "banana"
market = "台北二"
df_test = pd.read_sql(f"{fruit}_{market}", engine)
df_test.tail()
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價
# 3868          35.2          37.7
# 3869          37.9          38.3
# 3870          40.7          38.0
# 3871          38.3          39.6
# 3872          46.1          42.1

# %% [markdown]
# ### LSTM模型訓練

# %% [markdown]
# ##### 訓練集&測試集

# %%
def train_test_split(df):
    test_samples = int(df.shape[0]*0.2) # 82
    
    # 訓練集
    train_data = df.iloc[:-test_samples, :]
    #train_data.drop(columns="日期", inplace=True)
    train_set = train_data.iloc[:, 1:].values           # 取得train_set(array)
 
    
    # 測試集
    test_data = df.iloc[-test_samples:, :]
    #test_data.drop(columns="日期", inplace=True)
    test_set = test_data.iloc[:, 1:].values             # 取得test_set(array)
       
    return train_set, test_set

# %% [markdown]
# ##### 資料標準化

# %%
def data_normalization(input_set):
    
    # 訓練集(scaler)
    sc = StandardScaler()
    input_set_sc = sc.fit_transform(input_set[:, :])

    sc_target = StandardScaler()
    sc_target.fit_transform(input_set[:, 0:1])
    
    return input_set_sc, sc_target

# %% [markdown]
# ##### 創造X、y資料

# %%
def split_Xy(input_set_sc, n_future, n_past):
    X = []
    y = []

    for i in range(n_past, len(input_set_sc)-n_future+1): # 扣掉最後預測天數已符合y_test的length 
        X.append(input_set_sc[i-n_past:i, :])             # X = 前30天資料
        y.append(input_set_sc[i:i+n_future, 0])           # y = 後7天價格

    X, y = np.array(X), np.array(y) 
    
    print("X's shape: {}".format(X.shape))
    print("y's shape: {}".format(y.shape))
    
    return X, y

# %% [markdown]
# ##### 建立模型

# %%
def model_creator(n_steps, n_features):
    model = Sequential()
    
    # 1st layer 
    # input_shape => n_step, n_feature 

    model.add(LSTM(units=64, activation="relu", input_shape=(n_steps, n_features), return_sequences=True)) 

    model.add(LSTM(units=32, activation="relu", return_sequences=False))          

    model.add(Dropout(0.2))

    model.add(Dense(y_train.shape[1]))          

    model.summary() 
     
    return model

# %% [markdown]
# ##### 訓練模型

# %%
def model_trainer(model, X_train, y_train, epoch, batch_size):
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    # 提升訓練效率
    es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
    rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
    mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
    
    history = model.fit(X_train, y_train, epochs=epoch, 
                        batch_size=batch_size,
                        callbacks=[es, rlr, mcp], 
                        validation_split=0.1, 
                        verbose=1)
    # 視覺化
#     plt.plot(history.history['loss'], label='Training loss')
#     plt.plot(history.history['val_loss'], label='Validation loss')
#     plt.legend()
    print("loss: ", history.history['loss'][-1])
    print("val_loss: ", history.history['val_loss'][-1])
    
    return model

# %% [markdown]
# ##### 驗證模型準確率

# %%
def model_validation(model, X, y, sc_target):
    
    # 預測
    prediction = model.predict(X)
    prediction = sc_target.inverse_transform(prediction)
    actual = sc_target.inverse_transform(y)
    
    rmse_result = []
    for i in range(len(prediction)):
        rmse = mean_squared_error(prediction[i], actual[i], squared=False)
        rmse_result.append(rmse)

#     pd.DataFrame({"rmse":rmse_result}).plot()
    
    return prediction, actual

# %%
from my_libs.my_model_trainer import *

# %% [markdown]
# ### 從SQL取資料進行模型訓練 => 完成後存成h5檔(共8個)

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []

for Fruit, Type in fruits.items():
    for market in markets:
        print(f"Ongoing: {Fruit}_{market}" + "==="*30)
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=30, n_past=15)

        # 創造momdel
        model = model_creator(n_steps=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=12, batch_size=128)

        # 訓練集驗證
        # prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        X_test, y_test = split_Xy(test_set_sc, n_future=30, n_past=15)

        # 測試集驗證
        prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        pred_list.append(prediction_test)
        actual_list.append(actual_test)
        
        # 儲存模型
        #trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_Price/{market}.h5")
# Out:
# Ongoing: banana_台北二==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 15, 64)            18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 38ms/step - loss: 0.9095 - val_loss: 0.1470
#
# Epoch 00001: val_loss improved from inf to 0.14703, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.5744 - val_loss: 0.1125
#
# Epoch 00002: val_loss improved from 0.14703 to 0.11249, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.3823 - val_loss: 0.1086
#
# Epoch 00003: val_loss improved from 0.11249 to 0.10865, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.2860 - val_loss: 0.1237
#
# Epoch 00004: val_loss did not improve from 0.10865
# Epoch 5/12
# 22/22 [==============================] - 0s 18ms/step - loss: 0.2528 - val_loss: 0.1247
#
# Epoch 00005: val_loss did not improve from 0.10865
# Epoch 6/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2290 - val_loss: 0.1489
#
# Epoch 00006: val_loss did not improve from 0.10865
# Epoch 7/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.2170 - val_loss: 0.1305
#
# Epoch 00007: val_loss did not improve from 0.10865
# Epoch 8/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.2087 - val_loss: 0.1507
#
# Epoch 00008: val_loss did not improve from 0.10865
# Epoch 9/12
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1990 - val_loss: 0.1322
#
# Epoch 00009: val_loss did not improve from 0.10865
# Epoch 10/12
# 22/22 [==============================] - 0s 20ms/step - loss: 0.1910 - val_loss: 0.1451
#
# Epoch 00010: val_loss did not improve from 0.10865
# Epoch 11/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1837 - val_loss: 0.1231
#
# Epoch 00011: val_loss did not improve from 0.10865
# Epoch 12/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1740 - val_loss: 0.1267
#
# Epoch 00012: val_loss did not improve from 0.10865
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: banana_台北一==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 15, 64)            18176
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 3s 49ms/step - loss: 0.8867 - val_loss: 0.2036
#
# Epoch 00001: val_loss improved from inf to 0.20360, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.5706 - val_loss: 0.1895
#
# Epoch 00002: val_loss improved from 0.20360 to 0.18946, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 0s 18ms/step - loss: 0.4151 - val_loss: 0.1653
#
# Epoch 00003: val_loss improved from 0.18946 to 0.16531, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 0s 20ms/step - loss: 0.3354 - val_loss: 0.1557
#
# Epoch 00004: val_loss improved from 0.16531 to 0.15570, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2983 - val_loss: 0.1460
#
# Epoch 00005: val_loss improved from 0.15570 to 0.14596, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.2633 - val_loss: 0.1533
#
# Epoch 00006: val_loss did not improve from 0.14596
# Epoch 7/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.2370 - val_loss: 0.1503
#
# Epoch 00007: val_loss did not improve from 0.14596
# Epoch 8/12
# 22/22 [==============================] - 1s 23ms/step - loss: 0.2212 - val_loss: 0.1541
#
# Epoch 00008: val_loss did not improve from 0.14596
# Epoch 9/12
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2150 - val_loss: 0.1647
#
# Epoch 00009: val_loss did not improve from 0.14596
# Epoch 10/12
# 22/22 [==============================] - 0s 23ms/step - loss: 0.2044 - val_loss: 0.1744
#
# Epoch 00010: val_loss did not improve from 0.14596
# Epoch 11/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.1964 - val_loss: 0.1797
#
# Epoch 00011: val_loss did not improve from 0.14596
# Epoch 12/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1895 - val_loss: 0.2016
#
# Epoch 00012: val_loss did not improve from 0.14596
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: banana_三重區==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 15, 64)            18176
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 3s 38ms/step - loss: 0.9162 - val_loss: 0.1881
#
# Epoch 00001: val_loss improved from inf to 0.18808, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.5604 - val_loss: 0.1694
#
# Epoch 00002: val_loss improved from 0.18808 to 0.16943, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.3531 - val_loss: 0.1769
#
# Epoch 00003: val_loss did not improve from 0.16943
# Epoch 4/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.2626 - val_loss: 0.1851
#
# Epoch 00004: val_loss did not improve from 0.16943
# Epoch 5/12
# 22/22 [==============================] - 0s 20ms/step - loss: 0.2203 - val_loss: 0.1836
#
# Epoch 00005: val_loss did not improve from 0.16943
# Epoch 6/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.1939 - val_loss: 0.2027
#
# Epoch 00006: val_loss did not improve from 0.16943
# Epoch 7/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1745 - val_loss: 0.2138
#
# Epoch 00007: val_loss did not improve from 0.16943
# Epoch 8/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1626 - val_loss: 0.2002
#
# Epoch 00008: val_loss did not improve from 0.16943
# Epoch 9/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1528 - val_loss: 0.1959
#
# Epoch 00009: val_loss did not improve from 0.16943
# Epoch 10/12
# 22/22 [==============================] - 0s 22ms/step - loss: 0.1458 - val_loss: 0.2004
#
# Epoch 00010: val_loss did not improve from 0.16943
# Epoch 11/12
# 22/22 [==============================] - 1s 23ms/step - loss: 0.1375 - val_loss: 0.2320
#
# Epoch 00011: val_loss did not improve from 0.16943
# Epoch 12/12
# 22/22 [==============================] - 0s 19ms/step - loss: 0.1314 - val_loss: 0.1921
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00012: val_loss did not improve from 0.16943
# Epoch 00012: early stopping
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: banana_台中市==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 15, 64)            18176
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 43ms/step - loss: 1.0191 - val_loss: 0.1460
#
# Epoch 00001: val_loss improved from inf to 0.14598, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 0s 21ms/step - loss: 0.7873 - val_loss: 0.1227
#
# Epoch 00002: val_loss improved from 0.14598 to 0.12265, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 25ms/step - loss: 0.5405 - val_loss: 0.1147
#
# Epoch 00003: val_loss improved from 0.12265 to 0.11467, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 29ms/step - loss: 0.3620 - val_loss: 0.1141
#
# Epoch 00004: val_loss improved from 0.11467 to 0.11410, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.2850 - val_loss: 0.1155
#
# Epoch 00005: val_loss did not improve from 0.11410
# Epoch 6/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.2389 - val_loss: 0.1322
#
# Epoch 00006: val_loss did not improve from 0.11410
# Epoch 7/12
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2165 - val_loss: 0.1359
#
# Epoch 00007: val_loss did not improve from 0.11410
# Epoch 8/12
# 22/22 [==============================] - 1s 27ms/step - loss: 0.1991 - val_loss: 0.1298
#
# Epoch 00008: val_loss did not improve from 0.11410
# Epoch 9/12
# 22/22 [==============================] - 1s 26ms/step - loss: 0.1937 - val_loss: 0.1283
#
# Epoch 00009: val_loss did not improve from 0.11410
# Epoch 10/12
# 22/22 [==============================] - 1s 26ms/step - loss: 0.1785 - val_loss: 0.1578
#
# Epoch 00010: val_loss did not improve from 0.11410
# Epoch 11/12
# 22/22 [==============================] - 1s 25ms/step - loss: 0.1697 - val_loss: 0.1422
#
# Epoch 00011: val_loss did not improve from 0.11410
# Epoch 12/12
# 22/22 [==============================] - 1s 27ms/step - loss: 0.1651 - val_loss: 0.1462
#
# Epoch 00012: val_loss did not improve from 0.11410
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: guava_台北二==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 15, 64)            18176
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 51ms/step - loss: 0.9813 - val_loss: 0.6842
#
# Epoch 00001: val_loss improved from inf to 0.68424, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 29ms/step - loss: 0.8253 - val_loss: 0.5658
#
# Epoch 00002: val_loss improved from 0.68424 to 0.56584, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 29ms/step - loss: 0.6990 - val_loss: 0.4686
#
# Epoch 00003: val_loss improved from 0.56584 to 0.46862, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 30ms/step - loss: 0.5988 - val_loss: 0.4044
#
# Epoch 00004: val_loss improved from 0.46862 to 0.40440, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 30ms/step - loss: 0.5291 - val_loss: 0.4204
#
# Epoch 00005: val_loss did not improve from 0.40440
# Epoch 6/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.4717 - val_loss: 0.3941
#
# Epoch 00006: val_loss improved from 0.40440 to 0.39412, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 31ms/step - loss: 0.4346 - val_loss: 0.3952
#
# Epoch 00007: val_loss did not improve from 0.39412
# Epoch 8/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.4070 - val_loss: 0.3754
#
# Epoch 00008: val_loss improved from 0.39412 to 0.37544, saving model to weights.h5
# Epoch 9/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.3860 - val_loss: 0.3728
#
# Epoch 00009: val_loss improved from 0.37544 to 0.37282, saving model to weights.h5
# Epoch 10/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.3565 - val_loss: 0.3508
#
# Epoch 00010: val_loss improved from 0.37282 to 0.35083, saving model to weights.h5
# Epoch 11/12
# 22/22 [==============================] - 1s 40ms/step - loss: 0.3478 - val_loss: 0.3580
#
# Epoch 00011: val_loss did not improve from 0.35083
# Epoch 12/12
# 22/22 [==============================] - 1s 41ms/step - loss: 0.3290 - val_loss: 0.3463
#
# Epoch 00012: val_loss improved from 0.35083 to 0.34626, saving model to weights.h5
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: guava_台北一==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 15, 64)            18176
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 68ms/step - loss: 0.9683 - val_loss: 0.6157
#
# Epoch 00001: val_loss improved from inf to 0.61565, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 31ms/step - loss: 0.8304 - val_loss: 0.5126
#
# Epoch 00002: val_loss improved from 0.61565 to 0.51258, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.6962 - val_loss: 0.4333
#
# Epoch 00003: val_loss improved from 0.51258 to 0.43328, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 39ms/step - loss: 0.6002 - val_loss: 0.3674
#
# Epoch 00004: val_loss improved from 0.43328 to 0.36743, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 40ms/step - loss: 0.5235 - val_loss: 0.3659
#
# Epoch 00005: val_loss improved from 0.36743 to 0.36587, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.4832 - val_loss: 0.3499
#
# Epoch 00006: val_loss improved from 0.36587 to 0.34988, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.4449 - val_loss: 0.3772
#
# Epoch 00007: val_loss did not improve from 0.34988
# Epoch 8/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.4086 - val_loss: 0.3627
#
# Epoch 00008: val_loss did not improve from 0.34988
# Epoch 9/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.3779 - val_loss: 0.3792
#
# Epoch 00009: val_loss did not improve from 0.34988
# Epoch 10/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3632 - val_loss: 0.4368
#
# Epoch 00010: val_loss did not improve from 0.34988
# Epoch 11/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.3520 - val_loss: 0.4221
#
# Epoch 00011: val_loss did not improve from 0.34988
# Epoch 12/12
# 22/22 [==============================] - 1s 30ms/step - loss: 0.3608 - val_loss: 0.4032
#
# Epoch 00012: val_loss did not improve from 0.34988
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: guava_三重區==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 15, 64)            18176
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 47ms/step - loss: 0.9775 - val_loss: 0.6984
#
# Epoch 00001: val_loss improved from inf to 0.69836, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 0s 23ms/step - loss: 0.8569 - val_loss: 0.5993
#
# Epoch 00002: val_loss improved from 0.69836 to 0.59932, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 29ms/step - loss: 0.7417 - val_loss: 0.4902
#
# Epoch 00003: val_loss improved from 0.59932 to 0.49019, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 38ms/step - loss: 0.6309 - val_loss: 0.4067
#
# Epoch 00004: val_loss improved from 0.49019 to 0.40669, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.5406 - val_loss: 0.3601
#
# Epoch 00005: val_loss improved from 0.40669 to 0.36011, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.4731 - val_loss: 0.3337
#
# Epoch 00006: val_loss improved from 0.36011 to 0.33368, saving model to weights.h5
# Epoch 7/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.4410 - val_loss: 0.3267
#
# Epoch 00007: val_loss improved from 0.33368 to 0.32666, saving model to weights.h5
# Epoch 8/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.4115 - val_loss: 0.3197
#
# Epoch 00008: val_loss improved from 0.32666 to 0.31974, saving model to weights.h5
# Epoch 9/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.3899 - val_loss: 0.3443
#
# Epoch 00009: val_loss did not improve from 0.31974
# Epoch 10/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.3675 - val_loss: 0.3366
#
# Epoch 00010: val_loss did not improve from 0.31974
# Epoch 11/12
# 22/22 [==============================] - 1s 33ms/step - loss: 0.3417 - val_loss: 0.3164
#
# Epoch 00011: val_loss improved from 0.31974 to 0.31639, saving model to weights.h5
# Epoch 12/12
# 22/22 [==============================] - 1s 34ms/step - loss: 0.3380 - val_loss: 0.3520
#
# Epoch 00012: val_loss did not improve from 0.31639
# X's shape: (730, 15, 6)
# y's shape: (730, 30)
# Ongoing: guava_台中市==========================================================================================
# X's shape: (3053, 15, 6)
# y's shape: (3053, 30)
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 15, 64)            18176
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 22/22 [==============================] - 4s 82ms/step - loss: 0.9653 - val_loss: 0.6227
#
# Epoch 00001: val_loss improved from inf to 0.62265, saving model to weights.h5
# Epoch 2/12
# 22/22 [==============================] - 1s 25ms/step - loss: 0.7746 - val_loss: 0.4528
#
# Epoch 00002: val_loss improved from 0.62265 to 0.45283, saving model to weights.h5
# Epoch 3/12
# 22/22 [==============================] - 1s 32ms/step - loss: 0.6335 - val_loss: 0.3725
#
# Epoch 00003: val_loss improved from 0.45283 to 0.37250, saving model to weights.h5
# Epoch 4/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.5460 - val_loss: 0.3567
#
# Epoch 00004: val_loss improved from 0.37250 to 0.35673, saving model to weights.h5
# Epoch 5/12
# 22/22 [==============================] - 1s 40ms/step - loss: 0.4903 - val_loss: 0.3364
#
# Epoch 00005: val_loss improved from 0.35673 to 0.33640, saving model to weights.h5
# Epoch 6/12
# 22/22 [==============================] - 1s 44ms/step - loss: 0.4409 - val_loss: 0.3850
#
# Epoch 00006: val_loss did not improve from 0.33640
# Epoch 7/12
# 22/22 [==============================] - 1s 40ms/step - loss: 0.3976 - val_loss: 0.4020
#
# Epoch 00007: val_loss did not improve from 0.33640
# Epoch 8/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3590 - val_loss: 0.3401
#
# Epoch 00008: val_loss did not improve from 0.33640
# Epoch 9/12
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3415 - val_loss: 0.3160
#
# Epoch 00009: val_loss improved from 0.33640 to 0.31595, saving model to weights.h5
# Epoch 10/12
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3194 - val_loss: 0.4010
#
# Epoch 00010: val_loss did not improve from 0.31595
# Epoch 11/12
# 22/22 [==============================] - 1s 35ms/step - loss: 0.3053 - val_loss: 0.4565
#
# Epoch 00011: val_loss did not improve from 0.31595
# Epoch 12/12
# 22/22 [==============================] - 1s 41ms/step - loss: 0.3162 - val_loss: 0.3195
#
# Epoch 00012: val_loss did not improve from 0.31595
# X's shape: (730, 15, 6)
# y's shape: (730, 30)

# %% [markdown]
# ### Visualization

# %%
pred_list[i][-1]
# Out:
# array([31.253231, 31.387037, 32.614613, 31.7286  , 32.67921 , 32.271145,
#        33.29961 , 33.05652 , 32.671246, 32.621914, 31.876493, 31.917885,
#        32.833004, 32.723724, 33.09902 , 31.901978, 31.831924, 31.919737,
#        31.136032, 31.569778, 31.99433 , 32.217827, 30.94789 , 30.216791,
#        32.110744, 31.361824, 31.695175, 31.124853, 31.882736, 30.899582],
#       dtype=float32)

# %%
actual_list[i][-1]
# Out:
# array([28. , 30.5, 29.4, 29.8, 29.2, 28.7, 30. , 29.4, 28.8, 27.6, 23.4,
#        25.3, 27.2, 27.4, 25.1, 24.5, 21.7, 23.9, 22.1, 20.3, 20.5, 19.7,
#        21.1, 17.6, 17.7, 17.8, 17.8, 19.7, 18.1, 19.4])

# %%
fig, axes = plt.subplots(2, 4, figsize=(30,10), sharex=True, sharey=True) #, squeeze=True)

#     ax.xaxis.set_major_locator(plt.NullLocator())
#     ax.yaxis.set_major_locator(plt.NullLocator())

markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = ["Banana", "Guava"]

for i in list(range(8)):
    ax = fig.add_subplot(2, 4, i+1)
    ax.plot(np.arange(30), pred_list[i][-1], label="Predicted Price", color="orange")
    ax.plot(np.arange(30), actual_list[i][-1], label="Actual Price")
    ax.set_xticks(np.arange(0, 31, 5))
    if i <= 4:
        fruit = fruits[0]
    else:
        fruit = fruits[1]
        
    ax.set_title(f"1-month price {fruit} forecasts for {markets[i%4]} Market")
    #ax.set_yticks(np.arange(0, 50, 10))
    
    ax.legend(loc="upper right")

# %% [markdown]
# ### 預測結果評估(rmse, mape, mad)
# - mape : 平均絕對百分比誤差(Mean absolute percentage error)
# - rmse : 均方根差(root-mean-square error)
# - mad : 平均絕對偏差（Mean Absolute Deviation)

# %%
# mean_absolute_percentage_error => 版本問題無法import
from sklearn.metrics import mean_squared_error

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def mad(y_true, y_pred):
    return sum(np.abs((y_true - y_pred) / len(y_true)))

# %%
markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = ["Banana", "Guava"]

indexs = []
for f in fruits:
    for m in markets:
        indexs.append(f"{f}_{m}")

# %%
rmse_output = []
mape_output = []
mad_output = []

for i in list(range(8)):
    rmse_output.append(mean_squared_error(pred_list[i][-1], actual_list[i][-1], squared=False))
    mape_output.append(mape(actual_list[i][-1], pred_list[i][-1]))
    mad_output.append(mad(pred_list[i][-1], actual_list[i][-1]))

indexs = ['Banana_Taipei1', 'Banana_Taipei2', 'Banana_Sanchong', 'Banana_Taichung',
        'Guava_Taipei1', 'Guava_Taipei2', 'Guava_Sanchong','Guava_Taichung']

df_result_evaluation = pd.DataFrame({"RMSE" : rmse_output,
                                     "MAPE" : mape_output,
                                     "MAD" : mad_output}, index= indexs)

df_result_evaluation
# Out:
#                       RMSE       MAPE        MAD
# Banana_Taipei1    5.254433  12.150325   4.351217
# Banana_Taipei2    3.071305   9.232211   2.581610
# Banana_Sanchong   4.576449  11.400666   3.602571
# Banana_Taichung   2.256509   6.489130   1.944239
# Guava_Taipei1     7.901891  23.929959   7.405178
# Guava_Taipei2    16.893634  56.240030  15.817361
# Guava_Sanchong    8.431280  32.882585   7.773472
# Guava_Taichung    8.883034  37.322462   7.904815

# %% [markdown]
# ### 從SQL取分析資料進行價格預測
# - 直接透過query取得資料進行分析
# - 預測結果存入DB

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_output = []
actual_output = []

for Fruit, Type in fruits.items():
    for market in markets:
        
        product = Type[0]
        same = Type[1]
        sub = Type[2]
        
        # 從SQL讀取分析資料，轉換成矩陣
        df_set = pd.read_sql_query(f"""select `{product}_平均價`, `{product}_交易量`, `{same}_平均價`, 
                                       `{sub}_平均價`, `{product}_前日平均價`, `{product}_5日平均價` 
                                       from {product}_{market}
                                       order by `日期` desc
                                       limit 30""", con).values 
        
        # 標準化
        df_set_sc, sc_target = data_normalization(df_set)
        
        # reshape => 需符合input的shape
        df_set_sc = df_set_sc.reshape(-1, 30, 6)
        
        # 載入model
        model_loaded = keras.models.load_model(f"models/{product}_Price/{market}.h5")
        
        # 進行預測
        pred_result = model_loaded(df_set_sc) # 使用model_loaded.predict(df_set_sc)會跳出tensorflow warning
        
        # 透過inverse_transform還原為原本數值
        output = sc_target.inverse_transform(pred_result).reshape(-1).round(1)
        
        print(f"{Fruit}_{market}市場未來7日預測價: ", output)
# Out:
# banana_台北二市場未來7日預測價:  [35.8 35.9 36.1 35.7 35.8 36.2 36.1]
# banana_台北一市場未來7日預測價:  [29.2 29.1 29.4 29.5 29.6 29.4 29.3]
# banana_三重區市場未來7日預測價:  [30.2 30.1 30.1 29.9 30.5 30.5 30.2]
# banana_台中市市場未來7日預測價:  [30.1 30.2 30.1 30.2 30.1 30.2 30.2]
# guava_台北二市場未來7日預測價:  [37.3 36.7 36.9 37.  37.7 37.6 37.9]
# guava_台北一市場未來7日預測價:  [36.3 36.6 36.1 36.9 36.7 36.2 37. ]
# guava_三重區市場未來7日預測價:  [29.4 29.2 29.3 29.2 30.  29.3 29.7]
# guava_台中市市場未來7日預測價:  [28.4 29.2 29.6 29.2 29.  28.9 29.1]
