# %%
import pandas as pd
import numpy as np
import pymysql
from datetime import datetime, timedelta
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard

from tensorflow import keras

# %% [markdown]
# ### Loading Data From Database(local MySQL)

# %%
# username = 'cfb101spade'
# password = 'jo3m4284gj4rm4'
# host_port = '34.81.77.216:3306'
# database = 'twfruits'

# engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
# con = engine.connect()

# %%
username = 'root'
password = 'yuting1101'
host_port = 'localhost:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
# test

fruit = "banana"
market = "台北二"
df_test = pd.read_sql(f"{fruit}_{market}", engine)
df_test.tail()
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價
# 3868          35.2          37.7
# 3869          37.9          38.3
# 3870          40.7          38.0
# 3871          38.3          39.6
# 3872          46.1          42.1

# %% [markdown]
# ### LSTM模型訓練

# %% [markdown]
# ##### 訓練集&測試集

# %%
def train_test_split(df):
    test_samples = int(df.shape[0]*0.2) # 82
    
    # 訓練集
    train_data = df.iloc[:-test_samples, :]
    #train_data.drop(columns="日期", inplace=True)
    train_set = train_data.iloc[:, 1:].values           # 取得train_set(array)
 
    
    # 測試集
    test_data = df.iloc[-test_samples:, :]
    #test_data.drop(columns="日期", inplace=True)
    test_set = test_data.iloc[:, 1:].values             # 取得test_set(array)
       
    return train_set, test_set

# %%
a , b = train_test_split(df_test)

# %%
a
# Out:
# array([[   31.4,  9645. ,    36.5,    45. ,    31.4,    32.2],
#        [   32. , 12230. ,    50. ,    47.5,    31.4,    32.2],
#        [   32.2, 12103. ,    46.2,    47.5,    32. ,    32.2],
#        ...,
#        [   30.5, 12007.5,    30. ,    20.9,    29.7,    31.4],
#        [   31.4, 10140. ,    32.5,    23.4,    30.5,    31. ],
#        [   29.4, 13965. ,    27. ,    21. ,    31.4,    29.8]])

# %%
b
# Out:
# array([[   26.5, 10791. ,    28.5,    19.3,    29.4,    29.5],
#        [   25.4, 15240. ,    26.4,    19.6,    26.5,    28.6],
#        [   24.4,  9060. ,    28. ,    19.3,    25.4,    27.4],
#        ...,
#        [   38.3,  5891. ,    38.6,    32.9,    40.7,    38. ],
#        [   46.1,  4681. ,    42.3,    29.9,    38.3,    39.6],
#        [   47.5,  4485. ,    40.4,    48.4,    46.1,    42.1]])

# %% [markdown]
# ##### 資料標準化

# %%
def data_normalization(input_set):
    
    sc = StandardScaler()
    input_set_sc = sc.fit_transform(input_set[:, :])

    sc_target = StandardScaler()
    sc_target.fit_transform(input_set[:, 0:1])
    
    return input_set_sc, sc_target

# %% [markdown]
# ##### 創造X、y資料

# %%
def split_Xy(input_set_sc, n_future, n_past):
    X = []
    y = []

    for i in range(n_past, len(input_set_sc)-n_future+1): # 扣掉最後預測天數已符合y_test的length 
        X.append(input_set_sc[i-n_past:i, :])             # X = 前30天資料
        y.append(input_set_sc[i:i+n_future, 0])           # y = 後7天價格

    X, y = np.array(X), np.array(y) 
    
    print("X's shape: {}".format(X.shape))
    print("y's shape: {}".format(y.shape))
    
    return X, y

# %% [markdown]
# ##### 建立模型

# %%
def model_creator(n_steps, n_features):
    model = Sequential()
    
    # 1st layer 
    # input_shape => n_step, n_feature 

    model.add(LSTM(units=64, activation="relu", input_shape=(n_steps, n_features), return_sequences=True)) 

    model.add(LSTM(units=32, activation="relu", return_sequences=False))          

    model.add(Dropout(0.2))

    model.add(Dense(y_train.shape[1]))          

    model.summary() 
     
    return model

# %% [markdown]
# ##### 訓練模型

# %%
def model_trainer(model, X_train, y_train, epoch, batch_size):
    
    model.compile(optimizer="adam", loss="mean_squared_error")
    
    # 提升訓練效率
    es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
    rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
    mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
    
    history = model.fit(X_train, y_train, epochs=epoch, 
                        batch_size=batch_size,
                        callbacks=[es, rlr, mcp], 
                        validation_split=0.1, 
                        verbose=1)
    # 視覺化
#     plt.plot(history.history['loss'], label='Training loss')
#     plt.plot(history.history['val_loss'], label='Validation loss')
#     plt.legend()
    print("loss: ", history.history['loss'][-1])
    print("val_loss: ", history.history['val_loss'][-1])
    
    return model

# %% [markdown]
# ##### 驗證模型準確率

# %%
def model_validation(model, X, y, sc_target):
    
    # 預測
    prediction = model.predict(X)
    prediction = sc_target.inverse_transform(prediction)
    actual = sc_target.inverse_transform(y)
    
    rmse_result = []
    for i in range(len(prediction)):
        rmse = mean_squared_error(prediction[i], actual[i], squared=False)
        rmse_result.append(rmse)

#     pd.DataFrame({"rmse":rmse_result}).plot()
    
    return prediction, actual

# %%
from my_model_trainer import *

# %% [markdown]
# ### 從SQL取資料進行模型訓練 => 完成後存成h5檔(共8個)

# %%
fruits = {#"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []
# 參數設定
n_future = 7
n_past = 30
epochs = 30
batch_size = 128


for Fruit, Type in fruits.items():
    for market in markets:
        print(f"Ongoing: {Fruit}_{market}" + "==="*30)
        
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=n_future, n_past=n_past)

        # 創造momdel
        model = model_creator(n_past=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=epochs, batch_size=batch_size)

        # 訓練集驗證
        # prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        X_test, y_test = split_Xy(test_set_sc, n_future=n_future, n_past=n_past)

        # 測試集驗證
        prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        pred_list.append(prediction_test)
        actual_list.append(actual_test)
        
        
        # 儲存模型
        #trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_Price/{market}.h5")
# Out:
# Ongoing: guava_台北二==========================================================================================
# X's shape: (3063, 30, 6)
# y's shape: (3063, 7)
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_34 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 22/22 [==============================] - 7s 72ms/step - loss: 0.7723 - val_loss: 0.3864
#
# Epoch 00001: val_loss improved from inf to 0.38642, saving model to weights.h5
# Epoch 2/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.4599 - val_loss: 0.2319
#
# Epoch 00002: val_loss improved from 0.38642 to 0.23192, saving model to weights.h5
# Epoch 3/30
# 22/22 [==============================] - 2s 87ms/step - loss: 0.3036 - val_loss: 0.5370
#
# Epoch 00003: val_loss did not improve from 0.23192
# Epoch 4/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.2198 - val_loss: 0.3066
#
# Epoch 00004: val_loss did not improve from 0.23192
# Epoch 5/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.2018 - val_loss: 0.1342
#
# Epoch 00005: val_loss improved from 0.23192 to 0.13420, saving model to weights.h5
# Epoch 6/30
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1828 - val_loss: 0.1365
#
# Epoch 00006: val_loss did not improve from 0.13420
# Epoch 7/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1742 - val_loss: 0.1343
#
# Epoch 00007: val_loss did not improve from 0.13420
# Epoch 8/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1619 - val_loss: 0.1406
#
# Epoch 00008: val_loss did not improve from 0.13420
# Epoch 9/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1529 - val_loss: 0.2002
#
# Epoch 00009: val_loss did not improve from 0.13420
# Epoch 10/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1454 - val_loss: 0.1536
#
# Epoch 00010: val_loss did not improve from 0.13420
# Epoch 11/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1467 - val_loss: 0.1499
#
# Epoch 00011: val_loss did not improve from 0.13420
# Epoch 12/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1381 - val_loss: 0.1223
#
# Epoch 00012: val_loss improved from 0.13420 to 0.12226, saving model to weights.h5
# Epoch 13/30
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1356 - val_loss: 0.1434
#
# Epoch 00013: val_loss did not improve from 0.12226
# Epoch 14/30
# 22/22 [==============================] - 1s 42ms/step - loss: 0.1296 - val_loss: 0.1498
#
# Epoch 00014: val_loss did not improve from 0.12226
# Epoch 15/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1308 - val_loss: 0.1601
#
# Epoch 00015: val_loss did not improve from 0.12226
# Epoch 16/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1257 - val_loss: 0.1262
#
# Epoch 00016: val_loss did not improve from 0.12226
# Epoch 17/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1193 - val_loss: 0.1233
#
# Epoch 00017: val_loss did not improve from 0.12226
# Epoch 18/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1203 - val_loss: 0.1984
#
# Epoch 00018: val_loss did not improve from 0.12226
# Epoch 19/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1137 - val_loss: 0.1275
#
# Epoch 00019: val_loss did not improve from 0.12226
# Epoch 20/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1092 - val_loss: 0.1215
#
# Epoch 00020: val_loss improved from 0.12226 to 0.12145, saving model to weights.h5
# Epoch 21/30
# 22/22 [==============================] - 2s 97ms/step - loss: 0.1093 - val_loss: 0.1315
#
# Epoch 00021: val_loss did not improve from 0.12145
# Epoch 22/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1049 - val_loss: 0.1184
#
# Epoch 00022: val_loss improved from 0.12145 to 0.11840, saving model to weights.h5
# Epoch 23/30
# 22/22 [==============================] - 2s 88ms/step - loss: 0.1019 - val_loss: 0.1598
#
# Epoch 00023: val_loss did not improve from 0.11840
# Epoch 24/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1026 - val_loss: 0.1300
#
# Epoch 00024: val_loss did not improve from 0.11840
# Epoch 25/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1043 - val_loss: 0.1703
#
# Epoch 00025: val_loss did not improve from 0.11840
# Epoch 26/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1019 - val_loss: 0.1599
#
# Epoch 00026: val_loss did not improve from 0.11840
# Epoch 27/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0957 - val_loss: 0.1644
#
# Epoch 00027: val_loss did not improve from 0.11840
# Epoch 28/30
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0983 - val_loss: 0.1363
#
# Epoch 00028: val_loss did not improve from 0.11840
# Epoch 29/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0978 - val_loss: 0.1842
#
# Epoch 00029: val_loss did not improve from 0.11840
# Epoch 30/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.0944 - val_loss: 0.1611
#
# Epoch 00030: val_loss did not improve from 0.11840
# X's shape: (738, 30, 6)
# y's shape: (738, 7)
# Ongoing: guava_台北一==========================================================================================
# X's shape: (3063, 30, 6)
# y's shape: (3063, 7)
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_36 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 22/22 [==============================] - 5s 71ms/step - loss: 0.7502 - val_loss: 0.3222
#
# Epoch 00001: val_loss improved from inf to 0.32221, saving model to weights.h5
# Epoch 2/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.4209 - val_loss: 0.1716
#
# Epoch 00002: val_loss improved from 0.32221 to 0.17162, saving model to weights.h5
# Epoch 3/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.3140 - val_loss: 0.1213
#
# Epoch 00003: val_loss improved from 0.17162 to 0.12133, saving model to weights.h5
# Epoch 4/30
# 22/22 [==============================] - 2s 78ms/step - loss: 0.2538 - val_loss: 0.1364
#
# Epoch 00004: val_loss did not improve from 0.12133
# Epoch 5/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.2201 - val_loss: 0.1190
#
# Epoch 00005: val_loss improved from 0.12133 to 0.11897, saving model to weights.h5
# Epoch 6/30
# 22/22 [==============================] - 2s 100ms/step - loss: 0.2066 - val_loss: 0.1230
#
# Epoch 00006: val_loss did not improve from 0.11897
# Epoch 7/30
# 22/22 [==============================] - 1s 43ms/step - loss: 0.1926 - val_loss: 0.1162
#
# Epoch 00007: val_loss improved from 0.11897 to 0.11616, saving model to weights.h5
# Epoch 8/30
# 22/22 [==============================] - 2s 102ms/step - loss: 0.1865 - val_loss: 0.1155
#
# Epoch 00008: val_loss improved from 0.11616 to 0.11547, saving model to weights.h5
# Epoch 9/30
# 22/22 [==============================] - 2s 103ms/step - loss: 0.1759 - val_loss: 0.1268
#
# Epoch 00009: val_loss did not improve from 0.11547
# Epoch 10/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1673 - val_loss: 0.1368
#
# Epoch 00010: val_loss did not improve from 0.11547
# Epoch 11/30
# 22/22 [==============================] - 1s 45ms/step - loss: 0.1673 - val_loss: 0.1174
#
# Epoch 00011: val_loss did not improve from 0.11547
# Epoch 12/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1581 - val_loss: 0.1410
#
# Epoch 00012: val_loss did not improve from 0.11547
# Epoch 13/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1549 - val_loss: 0.1314
#
# Epoch 00013: val_loss did not improve from 0.11547
# Epoch 14/30
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1551 - val_loss: 0.1321
#
# Epoch 00014: val_loss did not improve from 0.11547
# Epoch 15/30
# 22/22 [==============================] - 1s 49ms/step - loss: 0.1527 - val_loss: 0.1481
#
# Epoch 00015: val_loss did not improve from 0.11547
# Epoch 16/30
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1483 - val_loss: 0.1357
#
# Epoch 00016: val_loss did not improve from 0.11547
# Epoch 17/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.1380 - val_loss: 0.1196
#
# Epoch 00017: val_loss did not improve from 0.11547
# Epoch 18/30
# 22/22 [==============================] - 1s 44ms/step - loss: 0.1442 - val_loss: 0.1303
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00018: val_loss did not improve from 0.11547
# Epoch 00018: early stopping
# X's shape: (738, 30, 6)
# y's shape: (738, 7)
# Ongoing: guava_三重區==========================================================================================
# X's shape: (3063, 30, 6)
# y's shape: (3063, 7)
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_38 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 22/22 [==============================] - 7s 86ms/step - loss: 0.6853 - val_loss: 0.2874
#
# Epoch 00001: val_loss improved from inf to 0.28743, saving model to weights.h5
# Epoch 2/30
# 22/22 [==============================] - 1s 52ms/step - loss: 0.3668 - val_loss: 0.1924
#
# Epoch 00002: val_loss improved from 0.28743 to 0.19242, saving model to weights.h5
# Epoch 3/30
# 22/22 [==============================] - 2s 108ms/step - loss: 0.2569 - val_loss: 0.1294
#
# Epoch 00003: val_loss improved from 0.19242 to 0.12935, saving model to weights.h5
# Epoch 4/30
# 22/22 [==============================] - 1s 54ms/step - loss: 0.2055 - val_loss: 0.1439
#
# Epoch 00004: val_loss did not improve from 0.12935
# Epoch 5/30
# 22/22 [==============================] - 1s 57ms/step - loss: 0.1960 - val_loss: 0.1375
#
# Epoch 00005: val_loss did not improve from 0.12935
# Epoch 6/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1649 - val_loss: 0.1178
#
# Epoch 00006: val_loss improved from 0.12935 to 0.11779, saving model to weights.h5
# Epoch 7/30
# 22/22 [==============================] - 1s 59ms/step - loss: 0.1606 - val_loss: 0.1198
#
# Epoch 00007: val_loss did not improve from 0.11779
# Epoch 8/30
# 22/22 [==============================] - 1s 59ms/step - loss: 0.1525 - val_loss: 0.1229
#
# Epoch 00008: val_loss did not improve from 0.11779
# Epoch 9/30
# 22/22 [==============================] - 1s 59ms/step - loss: 0.1479 - val_loss: 0.1169
#
# Epoch 00009: val_loss improved from 0.11779 to 0.11686, saving model to weights.h5
# Epoch 10/30
# 22/22 [==============================] - 1s 60ms/step - loss: 0.1385 - val_loss: 0.1196
#
# Epoch 00010: val_loss did not improve from 0.11686
# Epoch 11/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1367 - val_loss: 0.1193
#
# Epoch 00011: val_loss did not improve from 0.11686
# Epoch 12/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1296 - val_loss: 0.1126
#
# Epoch 00012: val_loss improved from 0.11686 to 0.11263, saving model to weights.h5
# Epoch 13/30
# 22/22 [==============================] - 3s 124ms/step - loss: 0.1251 - val_loss: 0.1184
#
# Epoch 00013: val_loss did not improve from 0.11263
# Epoch 14/30
# 22/22 [==============================] - 1s 54ms/step - loss: 0.1180 - val_loss: 0.1115
#
# Epoch 00014: val_loss improved from 0.11263 to 0.11148, saving model to weights.h5
# Epoch 15/30
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1200 - val_loss: 0.1164
#
# Epoch 00015: val_loss did not improve from 0.11148
# Epoch 16/30
# 22/22 [==============================] - 1s 53ms/step - loss: 0.1202 - val_loss: 0.1204
#
# Epoch 00016: val_loss did not improve from 0.11148
# Epoch 17/30
# 22/22 [==============================] - 1s 57ms/step - loss: 0.1130 - val_loss: 0.1122
#
# Epoch 00017: val_loss did not improve from 0.11148
# Epoch 18/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1046 - val_loss: 0.1124
#
# Epoch 00018: val_loss did not improve from 0.11148
# Epoch 19/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1002 - val_loss: 0.1123
#
# Epoch 00019: val_loss did not improve from 0.11148
# Epoch 20/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1080 - val_loss: 0.1100
#
# Epoch 00020: val_loss improved from 0.11148 to 0.10997, saving model to weights.h5
# Epoch 21/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0989 - val_loss: 0.1117
#
# Epoch 00021: val_loss did not improve from 0.10997
# Epoch 22/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0948 - val_loss: 0.1074
#
# Epoch 00022: val_loss improved from 0.10997 to 0.10735, saving model to weights.h5
# Epoch 23/30
# 22/22 [==============================] - 3s 129ms/step - loss: 0.0948 - val_loss: 0.1099
#
# Epoch 00023: val_loss did not improve from 0.10735
# Epoch 24/30
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0922 - val_loss: 0.1107
#
# Epoch 00024: val_loss did not improve from 0.10735
# Epoch 25/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0911 - val_loss: 0.1099
#
# Epoch 00025: val_loss did not improve from 0.10735
# Epoch 26/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0888 - val_loss: 0.1147
#
# Epoch 00026: val_loss did not improve from 0.10735
# Epoch 27/30
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0889 - val_loss: 0.1080
#
# Epoch 00027: val_loss did not improve from 0.10735
# Epoch 28/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.0845 - val_loss: 0.1187
#
# Epoch 00028: val_loss did not improve from 0.10735
# Epoch 29/30
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0831 - val_loss: 0.1136
#
# Epoch 00029: val_loss did not improve from 0.10735
# Epoch 30/30
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0831 - val_loss: 0.1180
#
# Epoch 00030: val_loss did not improve from 0.10735
# X's shape: (738, 30, 6)
# y's shape: (738, 7)
# Ongoing: guava_台中市==========================================================================================
# X's shape: (3063, 30, 6)
# y's shape: (3063, 7)
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_40 (LSTM)               (None, 30, 64)            18176
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 22/22 [==============================] - 6s 84ms/step - loss: 0.6880 - val_loss: 0.2712
#
# Epoch 00001: val_loss improved from inf to 0.27118, saving model to weights.h5
# Epoch 2/30
# 22/22 [==============================] - 1s 51ms/step - loss: 0.4185 - val_loss: 0.1419
#
# Epoch 00002: val_loss improved from 0.27118 to 0.14194, saving model to weights.h5
# Epoch 3/30
# 22/22 [==============================] - 2s 110ms/step - loss: 0.2870 - val_loss: 0.1075
#
# Epoch 00003: val_loss improved from 0.14194 to 0.10748, saving model to weights.h5
# Epoch 4/30
# 22/22 [==============================] - 2s 94ms/step - loss: 0.2169 - val_loss: 0.0968
#
# Epoch 00004: val_loss improved from 0.10748 to 0.09679, saving model to weights.h5
# Epoch 5/30
# 22/22 [==============================] - 1s 61ms/step - loss: 0.1800 - val_loss: 0.0949
#
# Epoch 00005: val_loss improved from 0.09679 to 0.09494, saving model to weights.h5
# Epoch 6/30
# 22/22 [==============================] - 1s 63ms/step - loss: 0.1607 - val_loss: 0.0757
#
# Epoch 00006: val_loss improved from 0.09494 to 0.07574, saving model to weights.h5
# Epoch 7/30
# 22/22 [==============================] - 1s 64ms/step - loss: 0.1418 - val_loss: 0.0782
#
# Epoch 00007: val_loss did not improve from 0.07574
# Epoch 8/30
# 22/22 [==============================] - 1s 58ms/step - loss: 0.1361 - val_loss: 0.0747
#
# Epoch 00008: val_loss improved from 0.07574 to 0.07467, saving model to weights.h5
# Epoch 9/30
# 22/22 [==============================] - 1s 68ms/step - loss: 0.1306 - val_loss: 0.0912
#
# Epoch 00009: val_loss did not improve from 0.07467
# Epoch 10/30
# 22/22 [==============================] - 1s 52ms/step - loss: 0.1257 - val_loss: 0.0808
#
# Epoch 00010: val_loss did not improve from 0.07467
# Epoch 11/30
# 22/22 [==============================] - 1s 51ms/step - loss: 0.1190 - val_loss: 0.0832
#
# Epoch 00011: val_loss did not improve from 0.07467
# Epoch 12/30
# 22/22 [==============================] - 1s 47ms/step - loss: 0.1166 - val_loss: 0.0736
#
# Epoch 00012: val_loss improved from 0.07467 to 0.07363, saving model to weights.h5
# Epoch 13/30
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1111 - val_loss: 0.0726
#
# Epoch 00013: val_loss improved from 0.07363 to 0.07258, saving model to weights.h5
# Epoch 14/30
# 22/22 [==============================] - 2s 101ms/step - loss: 0.1044 - val_loss: 0.0991
#
# Epoch 00014: val_loss did not improve from 0.07258
# Epoch 15/30
# 22/22 [==============================] - 1s 49ms/step - loss: 0.1083 - val_loss: 0.0595
#
# Epoch 00015: val_loss improved from 0.07258 to 0.05953, saving model to weights.h5
# Epoch 16/30
# 22/22 [==============================] - 2s 109ms/step - loss: 0.1032 - val_loss: 0.0580
#
# Epoch 00016: val_loss improved from 0.05953 to 0.05795, saving model to weights.h5
# Epoch 17/30
# 22/22 [==============================] - 1s 54ms/step - loss: 0.0981 - val_loss: 0.0641
#
# Epoch 00017: val_loss did not improve from 0.05795
# Epoch 18/30
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0965 - val_loss: 0.0744
#
# Epoch 00018: val_loss did not improve from 0.05795
# Epoch 19/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0911 - val_loss: 0.0981
#
# Epoch 00019: val_loss did not improve from 0.05795
# Epoch 20/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0951 - val_loss: 0.0773
#
# Epoch 00020: val_loss did not improve from 0.05795
# Epoch 21/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0919 - val_loss: 0.0589
#
# Epoch 00021: val_loss did not improve from 0.05795
# Epoch 22/30
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0939 - val_loss: 0.0750
#
# Epoch 00022: val_loss did not improve from 0.05795
# Epoch 23/30
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0833 - val_loss: 0.0560
#
# Epoch 00023: val_loss improved from 0.05795 to 0.05601, saving model to weights.h5
# Epoch 24/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0841 - val_loss: 0.0805
#
# Epoch 00024: val_loss did not improve from 0.05601
# Epoch 25/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0810 - val_loss: 0.0846
#
# Epoch 00025: val_loss did not improve from 0.05601
# Epoch 26/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0833 - val_loss: 0.0785
#
# Epoch 00026: val_loss did not improve from 0.05601
# Epoch 27/30
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0780 - val_loss: 0.0559
#
# Epoch 00027: val_loss improved from 0.05601 to 0.05591, saving model to weights.h5
# Epoch 28/30
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0776 - val_loss: 0.0680
#
# Epoch 00028: val_loss did not improve from 0.05591
# Epoch 29/30
# 22/22 [==============================] - 1s 57ms/step - loss: 0.0759 - val_loss: 0.0966
#
# Epoch 00029: val_loss did not improve from 0.05591
# Epoch 30/30
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0784 - val_loss: 0.0743
#
# Epoch 00030: val_loss did not improve from 0.05591
# X's shape: (738, 30, 6)
# y's shape: (738, 7)

# %% [markdown]
# ### Visualization

# %%
# fig, axes = plt.subplots(2, 4, figsize=(30,10), sharex=True, sharey=True) #, squeeze=True)

# #     ax.xaxis.set_major_locator(plt.NullLocator())
# #     ax.yaxis.set_major_locator(plt.NullLocator())

# markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
# fruits = ["Banana", "Guava"]

# n = 200

# for i in list(range(8)):
#     ax = fig.add_subplot(2, 4, i+1)
#     ax.plot(np.arange(30), pred_list[i][n], label="Predicted Price", color="orange")
#     ax.plot(np.arange(30), actual_list[i][n], label="Actual Price")
#     ax.set_xticks(np.arange(0, 31, 5))
#     if i <= 4:
#         fruit = fruits[0]
#     else:
#         fruit = fruits[1]
        
#     ax.set_title(f"1-month price {fruit} forecasts for {markets[i%4]} Market")
#     #ax.set_yticks(np.arange(0, 50, 10))
    
#     ax.legend(loc="upper right")

fig, axes = plt.subplots(2, 4, figsize=(30,10), sharex=True, sharey=True) #, squeeze=True)

#     ax.xaxis.set_major_locator(plt.NullLocator())
#     ax.yaxis.set_major_locator(plt.NullLocator())

markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = ["Guava", "Banana"]

n = 7
index = 200 # 200

for i in list(range(8)):
    ax = fig.add_subplot(2, 4, i+1)
    ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="o")
    ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
    #ax.set_xticks(np.arange(0, 31, 5))
    if i <= 4:
        fruit = fruits[0]
    else:
        fruit = fruits[1]
        
    ax.set_title(f"{markets[i%4]} - {fruit} price forecast (7 days)")
    #ax.set_yticks(np.arange(0, 50, 10))
    
    ax.legend(loc="upper right")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-0ac5dcb79c22> in <module>
#      37 for i in list(range(8)):
#      38     ax = fig.add_subplot(2, 4, i+1)
# ---> 39     ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="o")
#      40     ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
#      41     #ax.set_xticks(np.arange(0, 31, 5))
#
# IndexError: list index out of range

# %% [markdown]
# ### 預測結果評估(rmse, mape, mad)
# - mape : 平均絕對百分比誤差(Mean absolute percentage error)
# - rmse : 均方根差(root-mean-square error)
# - mad : 平均絕對偏差（Mean Absolute Deviation)

# %%
# mean_absolute_percentage_error => sklearn版本問題無法import
from sklearn.metrics import mean_squared_error

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def mad(y_true, y_pred):
    return sum(np.abs((y_true - y_pred) / len(y_true)))

# %%
rmse_output = []
mape_output = []
mad_output = []

n = 200

for i in list(range(8)):
    rmse_output.append(round(mean_squared_error(pred_list[i][n], actual_list[i][n], squared=False), 2))
    mape_output.append(round(mape(actual_list[i][n], pred_list[i][n]),2))
    mad_output.append(round(mad(actual_list[i][n], pred_list[i][n]),2))

indexs = ['Banana_Taipei1', 'Banana_Taipei2', 'Banana_Sanchong', 'Banana_Taichung',
        'Guava_Taipei1', 'Guava_Taipei2', 'Guava_Sanchong','Guava_Taichung']

df_result_evaluation = pd.DataFrame({"RMSE" : rmse_output,
                                     "MAPE" : mape_output,
                                     "MAD" : mad_output}, index= indexs)

df_result_evaluation
# Out:
#                  RMSE   MAPE   MAD
# Banana_Taipei1   2.81   6.00  2.38
# Banana_Taipei2   2.51   5.70  1.95
# Banana_Sanchong  6.70  16.98  6.53
# Banana_Taichung  2.07   4.77  1.68
# Guava_Taipei1    8.52  31.72  6.66
# Guava_Taipei2    7.12  29.18  5.88
# Guava_Sanchong   7.34  36.46  6.61
# Guava_Taichung   4.82  22.41  3.99

# %% [markdown]
# ### 從SQL取分析資料進行價格預測
# - 直接透過query取得資料進行分析
# - 預測結果存入DB

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_output = []
actual_output = []

# date
tmr = (datetime.now() + timedelta(days=1)).strftime('%Y-%m-%d')
future_dates = list(pd.date_range(start=tmr, freq="d", periods=7))

# sql schema
df_for_sql = pd.DataFrame(columns=["水果","市場", "日期", "價格"])

# prediction
for Fruit, Type in fruits.items():
    for market in markets:
        
        product = Type[0]
        same = Type[1]
        sub = Type[2]
        
        # 從SQL讀取分析資料，轉換成矩陣
        df_set = pd.read_sql_query(f"""select `{product}_平均價`, `{product}_交易量`, `{same}_平均價`, 
                                       `{sub}_平均價`, `{product}_前日平均價`, `{product}_5日平均價` 
                                       from {product}_{market}
                                       order by `日期` desc
                                       limit 30""", con).values 
        
        # 標準化
        df_set_sc, sc_target = data_normalization(df_set)
        
        # reshape => 需符合input的shape
        df_set_sc = df_set_sc.reshape(-1, 30, 6)
        
        # 載入model
        model_loaded = keras.models.load_model(f"models/{product}_Price/{market}.h5")
        
        # 進行預測
        pred_result = model_loaded(df_set_sc)                                                                          # 使用model_loaded.predict(df_set_sc)會跳出tensorflow warning
        
        # 透過inverse_transform還原為原本數值
        output = sc_target.inverse_transform(pred_result).reshape(-1).round(2)
        
        for date, price in zip(future_dates, output):
            df_for_sql = df_for_sql.append({"水果":Fruit, "市場":market, "日期":date, "價格":price}, ignore_index=True)
                                           
        print(f"{Fruit}_{market}市場未來7日預測價: ", output)
# Out:
# banana_台北二市場未來7日預測價:  [33.85 34.33 34.61 33.75 34.16 34.53 34.29]
# banana_台北一市場未來7日預測價:  [27.49 27.35 27.52 27.37 27.69 27.53 27.64]
# banana_三重區市場未來7日預測價:  [29.55 29.33 29.47 29.07 29.81 29.86 29.33]
# banana_台中市市場未來7日預測價:  [30.44 30.46 30.35 30.46 30.4  30.58 30.53]
# guava_台北二市場未來7日預測價:  [34.33 33.99 33.98 33.98 34.5  34.31 34.69]
# guava_台北一市場未來7日預測價:  [33.37 33.77 33.14 33.76 33.75 33.57 33.69]
# guava_三重區市場未來7日預測價:  [27.93 27.84 27.86 27.89 28.42 28.09 28.1 ]
# guava_台中市市場未來7日預測價:  [28.88 29.81 30.42 30.55 30.2  29.96 30.25]

# %%
df_for_sql["價格"] = df_for_sql["價格"].apply(lambda x:round(x,2))

# %%
# 預測結果寫入MySQL中
df_for_sql.to_sql(name='predicted price', 
                  con=con, if_exists='append', index=False)
