# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, RepeatVector
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from tensorflow import keras

# %% [markdown]
# ## 讀取檔案

# %%
username = 'root'
password = 'yuting1101'
host_port = 'localhost:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
fruit = "banana"
market = "台北二"
df= pd.read_sql(f"{fruit}_{market}", engine)
df
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 0    2011-01-01        31.4      9645.0               36.5       45.0
# 1    2011-01-02        32.0     12230.0               50.0       47.5
# 2    2011-01-03        32.2     12103.0               46.2       47.5
# 3    2011-01-04        32.4     11976.0               42.5       47.5
# 4    2011-01-05        33.2      7520.0               34.8       45.8
# ...         ...         ...         ...                ...        ...
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價
# 0             31.4          32.2
# 1             31.4          32.2
# 2             32.0          32.2
# 3             32.2          32.2
# 4             32.4          32.2
# ...            ...           ...
# 3868          35.2          37.7
# 3869          37.9          38.3
# 3870          40.7          38.0
# 3871          38.3          39.6
# 3872          46.1          42.1
#
# [3873 rows x 7 columns]

# %%
df["中價"] = df["banana_平均價"].apply(lambda x: round(x,0))
df
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 0    2011-01-01        31.4      9645.0               36.5       45.0
# 1    2011-01-02        32.0     12230.0               50.0       47.5
# 2    2011-01-03        32.2     12103.0               46.2       47.5
# 3    2011-01-04        32.4     11976.0               42.5       47.5
# 4    2011-01-05        33.2      7520.0               34.8       45.8
# ...         ...         ...         ...                ...        ...
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價    中價
# 0             31.4          32.2  31.0
# 1             31.4          32.2  32.0
# 2             32.0          32.2  32.0
# 3             32.2          32.2  32.0
# 4             32.4          32.2  33.0
# ...            ...           ...   ...
# 3868          35.2          37.7  38.0
# 3869          37.9          38.3  41.0
# 3870          40.7          38.0  38.0
# 3871          38.3          39.6  46.0
# 3872          46.1          42.1  48.0
#
# [3873 rows x 8 columns]

# %% [markdown]
# ### 單一市場測試

# %%
# 測試
from my_libs.my_model_trainer_banana import *

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []

n_future = 7
n_past = 30

Fruit = 'banana'
market = '台北一'

# for Fruit, Type in fruits.items():
#     for market in markets:

print(f"Ongoing: {Fruit}_{market}" + "==="*30)

# 讀取分析資料
df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
df_merged["中價"] = df_merged["banana_平均價"].apply(lambda x: round(x,0))


# 訓練集、測試集
train_set, test_set = train_test_split(df_merged)

### 訓練集part
# 訓練集(sc)、訓練集預測(scaler)
train_set_sc, sc_train_target = data_normalization(train_set)

# 訓練集
X_train, y_train = split_Xy(train_set_sc, n_future=n_future, n_past=n_past)

# 創造momdel
model = model_creator(n_past=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

# 訓練model
trained_model = model_trainer(model, X_train, y_train, epoch=30, batch_size=128, loss_visualize=True)

# 訓練集驗證
prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

### 測試集part
# 測試集(sc)、測試集預測(scaler)
test_set_sc, sc_test_target = data_normalization(test_set)

# 測試集、test_scaler
X_test, y_test = split_Xy(test_set_sc, n_future=n_future, n_past=n_past)

# 測試集驗證
prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)

pred_list.append(prediction_test)
actual_list.append(actual_test)

#         # 儲存模型
#         #trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_Price/{market}.h5")
# Out:
# Ongoing: banana_台北一==========================================================================================
# X's shape: (3063, 30, 7)
# y's shape: (3063, 7)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 64)            18432
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 231
# =================================================================
# Total params: 31,079
# Trainable params: 31,079
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 5s 69ms/step - loss: 1.3769 - val_loss: 0.6083
# Epoch 2/30
# 20/20 [==============================] - 1s 43ms/step - loss: 1.0851 - val_loss: 0.1800
# Epoch 3/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.7804 - val_loss: 0.3045
# Epoch 4/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.7137 - val_loss: 0.2702
# Epoch 5/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.4940 - val_loss: 0.0695
# Epoch 6/30
# 20/20 [==============================] - 1s 51ms/step - loss: 0.4167 - val_loss: 0.2001
# Epoch 7/30
# 20/20 [==============================] - 1s 49ms/step - loss: 0.4115 - val_loss: 0.0720
# Epoch 8/30
# 20/20 [==============================] - 1s 51ms/step - loss: 0.4284 - val_loss: 0.2535
# Epoch 9/30
# 20/20 [==============================] - 1s 50ms/step - loss: 0.3825 - val_loss: 0.1320
# Epoch 10/30
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2749 - val_loss: 0.0381
# Epoch 11/30
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2349 - val_loss: 0.0625
# Epoch 12/30
# 20/20 [==============================] - 2s 81ms/step - loss: 0.2323 - val_loss: 0.0421
# Epoch 13/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.2159 - val_loss: 0.0493
# Epoch 14/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.2033 - val_loss: 0.0375
# Epoch 15/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1998 - val_loss: 0.0462
# Epoch 16/30
# 20/20 [==============================] - 1s 49ms/step - loss: 0.1906 - val_loss: 0.0374
# Epoch 17/30
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1811 - val_loss: 0.0430
# Epoch 18/30
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1808 - val_loss: 0.0427
# Epoch 19/30
# 20/20 [==============================] - 1s 48ms/step - loss: 0.1770 - val_loss: 0.0440
# Epoch 20/30
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1694 - val_loss: 0.0380
# Epoch 21/30
# 20/20 [==============================] - 1s 56ms/step - loss: 0.1689 - val_loss: 0.0485
# Epoch 22/30
# 20/20 [==============================] - 1s 48ms/step - loss: 0.1708 - val_loss: 0.0389
# Epoch 23/30
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1603 - val_loss: 0.0541
# Epoch 24/30
# 20/20 [==============================] - 1s 54ms/step - loss: 0.1583 - val_loss: 0.0470
# Epoch 25/30
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1560 - val_loss: 0.0552
# Epoch 26/30
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1623 - val_loss: 0.0695
# Epoch 00026: early stopping
# X's shape: (738, 30, 7)
# y's shape: (738, 7)

# %%
index = -1
pred = pred_list[0][index].reshape(-1).tolist()
acutal = actual_list[0][index].tolist()

df_visual = pd.DataFrame({"pred":pred, "acutal":acutal})
df_visual.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 四大市場共同測試

# %%
# 測試
from my_libs.my_model_trainer_banana import *

# %%
fruits = {"banana": ["banana", "scarletbanana", "guava"],
          "guava":  ["guava", 'emperorguava', 'banana']}

markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []

# 參數設定
n_future = 30
n_past = 60
epochs = 30
batch_size = 128


for Fruit, Type in fruits.items():
    for market in markets:
        print(f"Ongoing: {Fruit}_{market}" + "==="*30)
        
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=n_future, n_past=n_past)

        # 創造momdel
        model = model_creator(n_past=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=epochs, batch_size=batch_size)

        # 訓練集驗證
        # prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        X_test, y_test = split_Xy(test_set_sc, n_future=n_future, n_past=n_past)

        # 測試集驗證
        prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        pred_list.append(prediction_test)
        actual_list.append(actual_test)
        
        # 儲存模型
        #trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_Price/{market}.h5")
    break
# Out:
# Ongoing: banana_台北二==========================================================================================
# X's shape: (3010, 60, 6)
# y's shape: (3010, 30)
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 60, 64)            18176
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 113ms/step - loss: 3.0537 - val_loss: 0.7048
# Epoch 2/30
# 19/19 [==============================] - 1s 74ms/step - loss: 1.9611 - val_loss: 0.3219
# Epoch 3/30
# 19/19 [==============================] - 1s 75ms/step - loss: 1.2795 - val_loss: 0.3945
# Epoch 4/30
# 19/19 [==============================] - 1s 75ms/step - loss: 1.1857 - val_loss: 0.2672
# Epoch 5/30
# 19/19 [==============================] - 1s 76ms/step - loss: 0.9782 - val_loss: 0.3291
# Epoch 6/30
# 19/19 [==============================] - 1s 75ms/step - loss: 1.0159 - val_loss: 0.1497
# Epoch 7/30
# 19/19 [==============================] - 1s 76ms/step - loss: 1.3125 - val_loss: 0.2676
# Epoch 8/30
# 19/19 [==============================] - 1s 74ms/step - loss: 0.8804 - val_loss: 0.3772
# Epoch 9/30
# 19/19 [==============================] - 1s 75ms/step - loss: 0.8389 - val_loss: 0.3091
# Epoch 10/30
# 19/19 [==============================] - 1s 74ms/step - loss: 0.7072 - val_loss: 0.1780
# Epoch 11/30
# 19/19 [==============================] - 1s 74ms/step - loss: 0.6271 - val_loss: 0.2613
# Epoch 12/30
# 19/19 [==============================] - 1s 74ms/step - loss: 0.5539 - val_loss: 0.1625
# Epoch 13/30
# 19/19 [==============================] - 1s 74ms/step - loss: 0.4559 - val_loss: 0.1688
# Epoch 14/30
# 19/19 [==============================] - 1s 75ms/step - loss: 0.4233 - val_loss: 0.0908
# Epoch 15/30
# 19/19 [==============================] - 2s 83ms/step - loss: 0.3917 - val_loss: 0.1118
# Epoch 16/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3637 - val_loss: 0.0910
# Epoch 17/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3365 - val_loss: 0.0925
# Epoch 18/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3366 - val_loss: 0.0844
# Epoch 19/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.3165 - val_loss: 0.0853
# Epoch 20/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3183 - val_loss: 0.0868
# Epoch 21/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.3035 - val_loss: 0.0870
# Epoch 22/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.3090 - val_loss: 0.0872
# Epoch 23/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.3004 - val_loss: 0.0909
# Epoch 24/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.2861 - val_loss: 0.0979
# Epoch 25/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2829 - val_loss: 0.0901
# Epoch 26/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2812 - val_loss: 0.0860
# Epoch 27/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2785 - val_loss: 0.0882
# Epoch 28/30
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2773 - val_loss: 0.0878
# Epoch 00028: early stopping
# X's shape: (685, 60, 6)
# y's shape: (685, 30)
# Ongoing: banana_台北一==========================================================================================
# X's shape: (3010, 60, 6)
# y's shape: (3010, 30)
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_20 (LSTM)               (None, 60, 64)            18176
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 5s 126ms/step - loss: 2.8953 - val_loss: 0.7418
# Epoch 2/30
# 19/19 [==============================] - 2s 94ms/step - loss: 1.6654 - val_loss: 0.3589
# Epoch 3/30
# 19/19 [==============================] - 2s 102ms/step - loss: 1.3009 - val_loss: 0.3798
# Epoch 4/30
# 19/19 [==============================] - 2s 116ms/step - loss: 0.9680 - val_loss: 0.3386
# Epoch 5/30
# 19/19 [==============================] - 3s 142ms/step - loss: 0.8421 - val_loss: 0.2595
# Epoch 6/30
# 19/19 [==============================] - 3s 160ms/step - loss: 0.6766 - val_loss: 0.2289
# Epoch 7/30
# 19/19 [==============================] - 3s 134ms/step - loss: 0.6115 - val_loss: 0.1323
# Epoch 8/30
# 19/19 [==============================] - 2s 117ms/step - loss: 0.6730 - val_loss: 0.2312
# Epoch 9/30
# 19/19 [==============================] - 2s 128ms/step - loss: 0.5373 - val_loss: 0.1811
# Epoch 10/30
# 19/19 [==============================] - 2s 124ms/step - loss: 0.4446 - val_loss: 0.1311
# Epoch 11/30
# 19/19 [==============================] - 3s 147ms/step - loss: 0.4047 - val_loss: 0.1117
# Epoch 12/30
# 19/19 [==============================] - 3s 145ms/step - loss: 0.3857 - val_loss: 0.1381
# Epoch 13/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3724 - val_loss: 0.1436
# Epoch 14/30
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3576 - val_loss: 0.1157
# Epoch 15/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3259 - val_loss: 0.1286
# Epoch 16/30
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3280 - val_loss: 0.0955
# Epoch 17/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.3062 - val_loss: 0.1110
# Epoch 18/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.2976 - val_loss: 0.0982
# Epoch 19/30
# 19/19 [==============================] - 2s 104ms/step - loss: 0.2969 - val_loss: 0.1158
# Epoch 20/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2877 - val_loss: 0.0956
# Epoch 21/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2856 - val_loss: 0.1142
# Epoch 22/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2767 - val_loss: 0.1148
# Epoch 23/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2748 - val_loss: 0.1094
# Epoch 24/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2673 - val_loss: 0.0947
# Epoch 25/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2606 - val_loss: 0.0983
# Epoch 26/30
# 19/19 [==============================] - 2s 103ms/step - loss: 0.2550 - val_loss: 0.1206
# Epoch 27/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2602 - val_loss: 0.1203
# Epoch 28/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2508 - val_loss: 0.1102
# Epoch 29/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.2461 - val_loss: 0.1045
# Epoch 30/30
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2408 - val_loss: 0.1020
# X's shape: (685, 60, 6)
# y's shape: (685, 30)
# Ongoing: banana_三重區==========================================================================================
# X's shape: (3010, 60, 6)
# y's shape: (3010, 30)
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_22 (LSTM)               (None, 60, 64)            18176
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 101ms/step - loss: 4.6822 - val_loss: 1.5824
# Epoch 2/30
# 19/19 [==============================] - 2s 94ms/step - loss: 2.3576 - val_loss: 0.6455
# Epoch 3/30
# 19/19 [==============================] - 2s 103ms/step - loss: 2.0877 - val_loss: 0.4079
# Epoch 4/30
# 19/19 [==============================] - 2s 130ms/step - loss: 1.3434 - val_loss: 0.4198
# Epoch 5/30
# 19/19 [==============================] - 3s 136ms/step - loss: 1.2756 - val_loss: 0.3375
# Epoch 6/30
# 19/19 [==============================] - 2s 123ms/step - loss: 1.1596 - val_loss: 0.2962
# Epoch 7/30
# 19/19 [==============================] - 2s 130ms/step - loss: 0.9908 - val_loss: 0.3241
# Epoch 8/30
# 19/19 [==============================] - 2s 118ms/step - loss: 0.8498 - val_loss: 0.2920
# Epoch 9/30
# 19/19 [==============================] - 2s 110ms/step - loss: 0.7060 - val_loss: 0.2128
# Epoch 10/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.8006 - val_loss: 0.3108
# Epoch 11/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.7009 - val_loss: 0.2275
# Epoch 12/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.5862 - val_loss: 0.1607
# Epoch 13/30
# 19/19 [==============================] - 2s 93ms/step - loss: 0.6299 - val_loss: 0.2300
# Epoch 14/30
# 19/19 [==============================] - 2s 117ms/step - loss: 0.5169 - val_loss: 0.1414
# Epoch 15/30
# 19/19 [==============================] - 2s 121ms/step - loss: 0.4552 - val_loss: 0.1331
# Epoch 16/30
# 19/19 [==============================] - 2s 102ms/step - loss: 0.4075 - val_loss: 0.1146
# Epoch 17/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.4027 - val_loss: 0.1184
# Epoch 18/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.4003 - val_loss: 0.1105
# Epoch 19/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.3672 - val_loss: 0.1173
# Epoch 20/30
# 19/19 [==============================] - 2s 109ms/step - loss: 0.3820 - val_loss: 0.1162
# Epoch 21/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3738 - val_loss: 0.1520
# Epoch 22/30
# 19/19 [==============================] - 2s 94ms/step - loss: 0.3604 - val_loss: 0.1036
# Epoch 23/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.3315 - val_loss: 0.1115
# Epoch 24/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3374 - val_loss: 0.1032
# Epoch 25/30
# 19/19 [==============================] - 2s 104ms/step - loss: 0.3245 - val_loss: 0.1054
# Epoch 26/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3192 - val_loss: 0.1014
# Epoch 27/30
# 19/19 [==============================] - 2s 106ms/step - loss: 0.3048 - val_loss: 0.0932
# Epoch 28/30
# 19/19 [==============================] - 2s 113ms/step - loss: 0.3099 - val_loss: 0.1008
# Epoch 29/30
# 19/19 [==============================] - 3s 135ms/step - loss: 0.3013 - val_loss: 0.0914
# Epoch 30/30
# 19/19 [==============================] - 2s 108ms/step - loss: 0.2842 - val_loss: 0.0932
# X's shape: (685, 60, 6)
# y's shape: (685, 30)
# Ongoing: banana_台中市==========================================================================================
# X's shape: (3010, 60, 6)
# y's shape: (3010, 30)
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_24 (LSTM)               (None, 60, 64)            18176
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 30)                990
# =================================================================
# Total params: 31,582
# Trainable params: 31,582
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 19/19 [==============================] - 4s 108ms/step - loss: 2.7357 - val_loss: 0.6843
# Epoch 2/30
# 19/19 [==============================] - 2s 96ms/step - loss: 1.5226 - val_loss: 0.4348
# Epoch 3/30
# 19/19 [==============================] - 2s 93ms/step - loss: 1.1628 - val_loss: 0.2429
# Epoch 4/30
# 19/19 [==============================] - 2s 95ms/step - loss: 1.0713 - val_loss: 0.2233
# Epoch 5/30
# 19/19 [==============================] - 2s 90ms/step - loss: 0.8887 - val_loss: 0.2522
# Epoch 6/30
# 19/19 [==============================] - 2s 88ms/step - loss: 0.8028 - val_loss: 0.2172
# Epoch 7/30
# 19/19 [==============================] - 2s 107ms/step - loss: 0.6973 - val_loss: 0.1931
# Epoch 8/30
# 19/19 [==============================] - 2s 111ms/step - loss: 0.6136 - val_loss: 0.2398
# Epoch 9/30
# 19/19 [==============================] - 2s 130ms/step - loss: 0.5438 - val_loss: 0.1052
# Epoch 10/30
# 19/19 [==============================] - 3s 133ms/step - loss: 0.5498 - val_loss: 0.2030
# Epoch 11/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.6118 - val_loss: 0.1306
# Epoch 12/30
# 19/19 [==============================] - 3s 140ms/step - loss: 0.4766 - val_loss: 0.1085
# Epoch 13/30
# 19/19 [==============================] - 2s 105ms/step - loss: 0.3660 - val_loss: 0.1140
# Epoch 14/30
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3519 - val_loss: 0.1220
# Epoch 15/30
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3160 - val_loss: 0.0629
# Epoch 16/30
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3040 - val_loss: 0.1130
# Epoch 17/30
# 19/19 [==============================] - 2s 101ms/step - loss: 0.2962 - val_loss: 0.0737
# Epoch 18/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.2755 - val_loss: 0.0706
# Epoch 19/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2683 - val_loss: 0.0671
# Epoch 20/30
# 19/19 [==============================] - 2s 98ms/step - loss: 0.2692 - val_loss: 0.0757
# Epoch 21/30
# 19/19 [==============================] - 2s 95ms/step - loss: 0.2570 - val_loss: 0.0666
# Epoch 22/30
# 19/19 [==============================] - 2s 91ms/step - loss: 0.2513 - val_loss: 0.0745
# Epoch 23/30
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2468 - val_loss: 0.0721
# Epoch 24/30
# 19/19 [==============================] - 2s 128ms/step - loss: 0.2365 - val_loss: 0.0681
# Epoch 25/30
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2374 - val_loss: 0.0640
# Epoch 00025: early stopping
# X's shape: (685, 60, 6)
# y's shape: (685, 30)

# %% [markdown]
# ### Visualization

# %%
fig, axes = plt.subplots(2, 4, figsize=(30,10), sharex=True, sharey=True) #, squeeze=True)

#     ax.xaxis.set_major_locator(plt.NullLocator())
#     ax.yaxis.set_major_locator(plt.NullLocator())

markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = ["Banana", "Guava"]

n = 30
index = 200 # 200

for i in list(range(8)):
    ax = fig.add_subplot(2, 4, i+1)
    ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="x")
    ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
    #ax.set_xticks(np.arange(0, 31, 5))
    if i <= 4:
        fruit = fruits[0]
    else:
        fruit = fruits[1]
        
    ax.set_title(f"7 days price {fruit} forecasts for {markets[i%4]} Market")
    #ax.set_yticks(np.arange(0, 50, 10))
    
    ax.legend(loc="upper right")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-a05d2f160f60> in <module>
#      12 for i in list(range(8)):
#      13     ax = fig.add_subplot(2, 4, i+1)
# ---> 14     ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="x")
#      15     ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
#      16     #ax.set_xticks(np.arange(0, 31, 5))
#
# IndexError: list index out of range

# %% [markdown]
# ### 預測結果評估(rmse, mape, mad)
# - mape : 平均絕對百分比誤差(Mean absolute percentage error)
# - rmse : 均方根差(root-mean-square error)
# - mad : 平均絕對偏差（Mean Absolute Deviation)

# %%
# mean_absolute_percentage_error => sklearn版本問題無法import
from sklearn.metrics import mean_squared_error

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def mad(y_true, y_pred):
    return sum(np.abs((y_true - y_pred) / len(y_true)))

# %%
rmse_output = []
mape_output = []
mad_output = []

n = -1

for i in list(range(4)):
    rmse_output.append(mean_squared_error(pred_list[i][n], actual_list[i][n], squared=False))
    mape_output.append(mape(actual_list[i][n], pred_list[i][n]))
    mad_output.append(mad(pred_list[i][n], actual_list[i][n]))

indexs = ['Banana_Taipei1', 'Banana_Taipei2', 'Banana_Sanchong', 'Banana_Taichung']#,
        #'Guava_Taipei1', 'Guava_Taipei2', 'Guava_Sanchong','Guava_Taichung']

df_result_evaluation = pd.DataFrame({"RMSE" : rmse_output,
                                     "MAPE" : mape_output,
                                     "MAD" : mad_output}, index= indexs)

df_result_evaluation
# Out:
#                      RMSE      MAPE       MAD
# Banana_Taipei1   3.731455  6.034858  3.088556
# Banana_Taipei2   3.062059  5.452581  2.591184
# Banana_Sanchong  3.400015  6.919312  2.967570
# Banana_Taichung  1.749852  3.041344  1.364827
