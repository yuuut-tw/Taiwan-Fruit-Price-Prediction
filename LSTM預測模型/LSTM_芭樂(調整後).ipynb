# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import re
import os
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'

# %%
import math
import matplotlib.pyplot as plt
import datetime as dt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, RepeatVector
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from tensorflow import keras

# %% [markdown]
# ### MySQL連線

# %%
username = 'root'
password = pwd
host_port = 'localhost:3306' 
database = 'twfruits'

engine = create_engine("mysql+pymysql://{}:{}@{}/{}".format(username, password, host_port, database))
con = engine.connect()

# %%
# test
fruit = "banana"
market = "台北二"
df= pd.read_sql(f"{fruit}_{market}", engine)
df
# Out:
#              日期  banana_平均價  banana_交易量  scarletbanana_平均價  guava_平均價  \
# 0    2011-01-01        31.4      9645.0               36.5       45.0
# 1    2011-01-02        32.0     12230.0               50.0       47.5
# 2    2011-01-03        32.2     12103.0               46.2       47.5
# 3    2011-01-04        32.4     11976.0               42.5       47.5
# 4    2011-01-05        33.2      7520.0               34.8       45.8
# ...         ...         ...         ...                ...        ...
# 3868 2021-08-04        37.9      5550.0               35.2       31.4
# 3869 2021-08-05        40.7      5530.0               38.0       29.3
# 3870 2021-08-06        38.3      5891.0               38.6       32.9
# 3871 2021-08-07        46.1      4681.0               42.3       29.9
# 3872 2021-08-08        47.5      4485.0               40.4       48.4
#
#       banana_前日平均價  banana_5日平均價
# 0             31.4          32.2
# 1             31.4          32.2
# 2             32.0          32.2
# 3             32.2          32.2
# 4             32.4          32.2
# ...            ...           ...
# 3868          35.2          37.7
# 3869          37.9          38.3
# 3870          40.7          38.0
# 3871          38.3          39.6
# 3872          46.1          42.1
#
# [3873 rows x 7 columns]

# %% [markdown]
# ### 四大市場共同測試

# %%
from my_libs.my_model_trainer_guava import *

# %%
fruits = {"guava":  ["guava", 'emperorguava', 'banana']}
markets = ['台北二', '台北一', '三重區', '台中市']

pred_list = []
actual_list = []

# 參數設定
n_future = 7
n_past = 60
epochs = 20
batch_size = 128


for Fruit, Type in fruits.items():
    for market in markets:
        print(f"Ongoing: {Fruit}_{market}" + "==="*30)
        
        # 讀取分析資料
        df_merged = pd.read_sql(f"{Fruit}_{market}", engine)
    
        # 訓練集、測試集
        train_set, test_set = train_test_split(df_merged)

        ### 訓練集part
        # 訓練集(sc)、訓練集預測(scaler)
        train_set_sc, sc_train_target = data_normalization(train_set)

        # 訓練集
        X_train, y_train = split_Xy(train_set_sc, n_future=n_future, n_past=n_past)

        # 創造momdel
        model = model_creator(n_past=X_train.shape[1], n_features=X_train.shape[2], output=y_train.shape[1])

        # 訓練model
        trained_model = model_trainer(model, X_train, y_train, epoch=epochs, batch_size=batch_size)

        # 訓練集驗證
        prediction_train, actual_train = model_validation(trained_model, X_train, y_train, sc_train_target)

        ### 測試集part
        # 測試集(sc)、測試集預測(scaler)
        test_set_sc, sc_test_target = data_normalization(test_set)

        # 測試集、test_scaler
        X_test, y_test = split_Xy(test_set_sc, n_future=n_future, n_past=n_past)

        # 測試集驗證
        prediction_test, actual_test = model_validation(trained_model, X_test, y_test, sc_test_target)
        
        pred_list.append(prediction_test)
        actual_list.append(actual_test)
        
        # 儲存模型
        trained_model.save(f"C:/Users/Tibame/PycharmProjects/PythonETL/Fruit Price Prediction/models/{Fruit}_predict_adjusted/{market}.h5")
# Out:
# Ongoing: guava_台北二==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 64)            18176
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 96ms/step - loss: 2.0645 - val_loss: 1.0670
#
# Epoch 00001: val_loss improved from inf to 1.06705, saving model to weights.h5
# Epoch 2/20
# 19/19 [==============================] - 2s 79ms/step - loss: 0.8381 - val_loss: 0.4093
#
# Epoch 00002: val_loss improved from 1.06705 to 0.40931, saving model to weights.h5
# Epoch 3/20
# 19/19 [==============================] - 1s 75ms/step - loss: 1.0369 - val_loss: 0.4990
#
# Epoch 00003: val_loss did not improve from 0.40931
# Epoch 4/20
# 19/19 [==============================] - 1s 72ms/step - loss: 0.6846 - val_loss: 0.2643
#
# Epoch 00004: val_loss improved from 0.40931 to 0.26425, saving model to weights.h5
# Epoch 5/20
# 19/19 [==============================] - 1s 70ms/step - loss: 0.7492 - val_loss: 0.2208
#
# Epoch 00005: val_loss improved from 0.26425 to 0.22080, saving model to weights.h5
# Epoch 6/20
# 19/19 [==============================] - 1s 68ms/step - loss: 0.5401 - val_loss: 0.1901
#
# Epoch 00006: val_loss improved from 0.22080 to 0.19010, saving model to weights.h5
# Epoch 7/20
# 19/19 [==============================] - 1s 69ms/step - loss: 0.5289 - val_loss: 0.1676
#
# Epoch 00007: val_loss improved from 0.19010 to 0.16757, saving model to weights.h5
# Epoch 8/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.4960 - val_loss: 0.1536
#
# Epoch 00008: val_loss improved from 0.16757 to 0.15362, saving model to weights.h5
# Epoch 9/20
# 19/19 [==============================] - 2s 86ms/step - loss: 0.4452 - val_loss: 0.1460
#
# Epoch 00009: val_loss improved from 0.15362 to 0.14596, saving model to weights.h5
# Epoch 10/20
# 19/19 [==============================] - 2s 86ms/step - loss: 0.4226 - val_loss: 0.1464
#
# Epoch 00010: val_loss did not improve from 0.14596
# Epoch 11/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.4168 - val_loss: 0.1284
#
# Epoch 00011: val_loss improved from 0.14596 to 0.12843, saving model to weights.h5
# Epoch 12/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3883 - val_loss: 0.1259
#
# Epoch 00012: val_loss improved from 0.12843 to 0.12588, saving model to weights.h5
# Epoch 13/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3640 - val_loss: 0.1186
#
# Epoch 00013: val_loss improved from 0.12588 to 0.11856, saving model to weights.h5
# Epoch 14/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.3515 - val_loss: 0.1187
#
# Epoch 00014: val_loss did not improve from 0.11856
# Epoch 15/20
# 19/19 [==============================] - 2s 85ms/step - loss: 0.3370 - val_loss: 0.1173
#
# Epoch 00015: val_loss improved from 0.11856 to 0.11732, saving model to weights.h5
# Epoch 16/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3235 - val_loss: 0.1103
#
# Epoch 00016: val_loss improved from 0.11732 to 0.11032, saving model to weights.h5
# Epoch 17/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.3086 - val_loss: 0.1080
#
# Epoch 00017: val_loss improved from 0.11032 to 0.10802, saving model to weights.h5
# Epoch 18/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3021 - val_loss: 0.1067
#
# Epoch 00018: val_loss improved from 0.10802 to 0.10673, saving model to weights.h5
# Epoch 19/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.2994 - val_loss: 0.1058
#
# Epoch 00019: val_loss improved from 0.10673 to 0.10575, saving model to weights.h5
# Epoch 20/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.3026 - val_loss: 0.1032
#
# Epoch 00020: val_loss improved from 0.10575 to 0.10324, saving model to weights.h5
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: guava_台北一==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 93ms/step - loss: 2.0240 - val_loss: 1.0292
#
# Epoch 00001: val_loss improved from inf to 1.02918, saving model to weights.h5
# Epoch 2/20
# 19/19 [==============================] - 2s 87ms/step - loss: 1.2757 - val_loss: 0.4867
#
# Epoch 00002: val_loss improved from 1.02918 to 0.48675, saving model to weights.h5
# Epoch 3/20
# 19/19 [==============================] - 2s 80ms/step - loss: 0.9747 - val_loss: 0.2971
#
# Epoch 00003: val_loss improved from 0.48675 to 0.29709, saving model to weights.h5
# Epoch 4/20
# 19/19 [==============================] - 2s 82ms/step - loss: 0.8295 - val_loss: 0.2667
#
# Epoch 00004: val_loss improved from 0.29709 to 0.26668, saving model to weights.h5
# Epoch 5/20
# 19/19 [==============================] - 2s 81ms/step - loss: 0.7231 - val_loss: 0.2223
#
# Epoch 00005: val_loss improved from 0.26668 to 0.22234, saving model to weights.h5
# Epoch 6/20
# 19/19 [==============================] - 2s 82ms/step - loss: 0.6292 - val_loss: 0.1891
#
# Epoch 00006: val_loss improved from 0.22234 to 0.18911, saving model to weights.h5
# Epoch 7/20
# 19/19 [==============================] - 2s 88ms/step - loss: 0.5749 - val_loss: 0.1645
#
# Epoch 00007: val_loss improved from 0.18911 to 0.16455, saving model to weights.h5
# Epoch 8/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.5124 - val_loss: 0.1399
#
# Epoch 00008: val_loss improved from 0.16455 to 0.13990, saving model to weights.h5
# Epoch 9/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.4425 - val_loss: 0.1148
#
# Epoch 00009: val_loss improved from 0.13990 to 0.11480, saving model to weights.h5
# Epoch 10/20
# 19/19 [==============================] - 2s 81ms/step - loss: 0.3868 - val_loss: 0.1020
#
# Epoch 00010: val_loss improved from 0.11480 to 0.10202, saving model to weights.h5
# Epoch 11/20
# 19/19 [==============================] - 2s 81ms/step - loss: 0.3318 - val_loss: 0.0923
#
# Epoch 00011: val_loss improved from 0.10202 to 0.09227, saving model to weights.h5
# Epoch 12/20
# 19/19 [==============================] - 2s 80ms/step - loss: 0.3352 - val_loss: 0.0861
#
# Epoch 00012: val_loss improved from 0.09227 to 0.08606, saving model to weights.h5
# Epoch 13/20
# 19/19 [==============================] - 2s 80ms/step - loss: 0.3218 - val_loss: 0.0825
#
# Epoch 00013: val_loss improved from 0.08606 to 0.08253, saving model to weights.h5
# Epoch 14/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.2926 - val_loss: 0.0821
#
# Epoch 00014: val_loss improved from 0.08253 to 0.08212, saving model to weights.h5
# Epoch 15/20
# 19/19 [==============================] - 2s 81ms/step - loss: 0.2883 - val_loss: 0.0783
#
# Epoch 00015: val_loss improved from 0.08212 to 0.07832, saving model to weights.h5
# Epoch 16/20
# 19/19 [==============================] - 2s 80ms/step - loss: 0.2822 - val_loss: 0.0740
#
# Epoch 00016: val_loss improved from 0.07832 to 0.07405, saving model to weights.h5
# Epoch 17/20
# 19/19 [==============================] - 2s 82ms/step - loss: 0.2676 - val_loss: 0.0721
#
# Epoch 00017: val_loss improved from 0.07405 to 0.07207, saving model to weights.h5
# Epoch 18/20
# 19/19 [==============================] - 1s 79ms/step - loss: 0.2654 - val_loss: 0.0721
#
# Epoch 00018: val_loss did not improve from 0.07207
# Epoch 19/20
# 19/19 [==============================] - 2s 81ms/step - loss: 0.2534 - val_loss: 0.0689
#
# Epoch 00019: val_loss improved from 0.07207 to 0.06886, saving model to weights.h5
# Epoch 20/20
# 19/19 [==============================] - 2s 79ms/step - loss: 0.2414 - val_loss: 0.0701
#
# Epoch 00020: val_loss did not improve from 0.06886
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: guava_三重區==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 88ms/step - loss: 1.5346 - val_loss: 0.5354
#
# Epoch 00001: val_loss improved from inf to 0.53542, saving model to weights.h5
# Epoch 2/20
# 19/19 [==============================] - 1s 78ms/step - loss: 1.1060 - val_loss: 0.4203
#
# Epoch 00002: val_loss improved from 0.53542 to 0.42033, saving model to weights.h5
# Epoch 3/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.8665 - val_loss: 0.3224
#
# Epoch 00003: val_loss improved from 0.42033 to 0.32244, saving model to weights.h5
# Epoch 4/20
# 19/19 [==============================] - 2s 98ms/step - loss: 0.8048 - val_loss: 0.2443
#
# Epoch 00004: val_loss improved from 0.32244 to 0.24435, saving model to weights.h5
# Epoch 5/20
# 19/19 [==============================] - 2s 85ms/step - loss: 0.6180 - val_loss: 0.1901
#
# Epoch 00005: val_loss improved from 0.24435 to 0.19015, saving model to weights.h5
# Epoch 6/20
# 19/19 [==============================] - 2s 83ms/step - loss: 0.5106 - val_loss: 0.1371
#
# Epoch 00006: val_loss improved from 0.19015 to 0.13712, saving model to weights.h5
# Epoch 7/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.4489 - val_loss: 0.1200
#
# Epoch 00007: val_loss improved from 0.13712 to 0.11998, saving model to weights.h5
# Epoch 8/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3817 - val_loss: 0.1110
#
# Epoch 00008: val_loss improved from 0.11998 to 0.11102, saving model to weights.h5
# Epoch 9/20
# 19/19 [==============================] - 2s 82ms/step - loss: 0.3551 - val_loss: 0.1060
#
# Epoch 00009: val_loss improved from 0.11102 to 0.10598, saving model to weights.h5
# Epoch 10/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.3242 - val_loss: 0.0975
#
# Epoch 00010: val_loss improved from 0.10598 to 0.09747, saving model to weights.h5
# Epoch 11/20
# 19/19 [==============================] - 2s 84ms/step - loss: 0.2965 - val_loss: 0.0951
#
# Epoch 00011: val_loss improved from 0.09747 to 0.09513, saving model to weights.h5
# Epoch 12/20
# 19/19 [==============================] - 2s 86ms/step - loss: 0.2940 - val_loss: 0.0953
#
# Epoch 00012: val_loss did not improve from 0.09513
# Epoch 13/20
# 19/19 [==============================] - 2s 88ms/step - loss: 0.2728 - val_loss: 0.0936
#
# Epoch 00013: val_loss improved from 0.09513 to 0.09364, saving model to weights.h5
# Epoch 14/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2556 - val_loss: 0.0875
#
# Epoch 00014: val_loss improved from 0.09364 to 0.08755, saving model to weights.h5
# Epoch 15/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.2512 - val_loss: 0.0852
#
# Epoch 00015: val_loss improved from 0.08755 to 0.08523, saving model to weights.h5
# Epoch 16/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2426 - val_loss: 0.0824
#
# Epoch 00016: val_loss improved from 0.08523 to 0.08241, saving model to weights.h5
# Epoch 17/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2228 - val_loss: 0.0792
#
# Epoch 00017: val_loss improved from 0.08241 to 0.07924, saving model to weights.h5
# Epoch 18/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.2304 - val_loss: 0.0771
#
# Epoch 00018: val_loss improved from 0.07924 to 0.07708, saving model to weights.h5
# Epoch 19/20
# 19/19 [==============================] - 2s 92ms/step - loss: 0.2188 - val_loss: 0.0746
#
# Epoch 00019: val_loss improved from 0.07708 to 0.07464, saving model to weights.h5
# Epoch 20/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.2041 - val_loss: 0.0758
#
# Epoch 00020: val_loss did not improve from 0.07464
# X's shape: (708, 60, 6)
# y's shape: (708, 7)
# Ongoing: guava_台中市==========================================================================================
# X's shape: (3033, 60, 6)
# y's shape: (3033, 7)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 60, 64)            18176
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 30,823
# Trainable params: 30,823
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 4s 94ms/step - loss: 1.5561 - val_loss: 0.5593
#
# Epoch 00001: val_loss improved from inf to 0.55931, saving model to weights.h5
# Epoch 2/20
# 19/19 [==============================] - 2s 88ms/step - loss: 0.8829 - val_loss: 0.3334
#
# Epoch 00002: val_loss improved from 0.55931 to 0.33338, saving model to weights.h5
# Epoch 3/20
# 19/19 [==============================] - 2s 92ms/step - loss: 0.8976 - val_loss: 0.2999
#
# Epoch 00003: val_loss improved from 0.33338 to 0.29990, saving model to weights.h5
# Epoch 4/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.6918 - val_loss: 0.2241
#
# Epoch 00004: val_loss improved from 0.29990 to 0.22414, saving model to weights.h5
# Epoch 5/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.6824 - val_loss: 0.2051
#
# Epoch 00005: val_loss improved from 0.22414 to 0.20508, saving model to weights.h5
# Epoch 6/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.5839 - val_loss: 0.1781
#
# Epoch 00006: val_loss improved from 0.20508 to 0.17805, saving model to weights.h5
# Epoch 7/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.5532 - val_loss: 0.1555
#
# Epoch 00007: val_loss improved from 0.17805 to 0.15554, saving model to weights.h5
# Epoch 8/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.4793 - val_loss: 0.1468
#
# Epoch 00008: val_loss improved from 0.15554 to 0.14675, saving model to weights.h5
# Epoch 9/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.4428 - val_loss: 0.1502
#
# Epoch 00009: val_loss did not improve from 0.14675
# Epoch 10/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.4070 - val_loss: 0.1279
#
# Epoch 00010: val_loss improved from 0.14675 to 0.12787, saving model to weights.h5
# Epoch 11/20
# 19/19 [==============================] - 2s 92ms/step - loss: 0.3964 - val_loss: 0.1213
#
# Epoch 00011: val_loss improved from 0.12787 to 0.12126, saving model to weights.h5
# Epoch 12/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.3662 - val_loss: 0.1183
#
# Epoch 00012: val_loss improved from 0.12126 to 0.11826, saving model to weights.h5
# Epoch 13/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.3447 - val_loss: 0.1192
#
# Epoch 00013: val_loss did not improve from 0.11826
# Epoch 14/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.3224 - val_loss: 0.1123
#
# Epoch 00014: val_loss improved from 0.11826 to 0.11231, saving model to weights.h5
# Epoch 15/20
# 19/19 [==============================] - 2s 88ms/step - loss: 0.3304 - val_loss: 0.1066
#
# Epoch 00015: val_loss improved from 0.11231 to 0.10655, saving model to weights.h5
# Epoch 16/20
# 19/19 [==============================] - 2s 89ms/step - loss: 0.3227 - val_loss: 0.1030
#
# Epoch 00016: val_loss improved from 0.10655 to 0.10305, saving model to weights.h5
# Epoch 17/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.3010 - val_loss: 0.1008
#
# Epoch 00017: val_loss improved from 0.10305 to 0.10084, saving model to weights.h5
# Epoch 18/20
# 19/19 [==============================] - 2s 90ms/step - loss: 0.3033 - val_loss: 0.0970
#
# Epoch 00018: val_loss improved from 0.10084 to 0.09699, saving model to weights.h5
# Epoch 19/20
# 19/19 [==============================] - 2s 91ms/step - loss: 0.2831 - val_loss: 0.0925
#
# Epoch 00019: val_loss improved from 0.09699 to 0.09246, saving model to weights.h5
# Epoch 20/20
# 19/19 [==============================] - 2s 97ms/step - loss: 0.2786 - val_loss: 0.0899
#
# Epoch 00020: val_loss improved from 0.09246 to 0.08991, saving model to weights.h5
# X's shape: (708, 60, 6)
# y's shape: (708, 7)

# %% [markdown]
# ### Visualization

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True) #, squeeze=True)

markets = ["Taipei1", "Taipei2", "Sanchong", "Taichung"]
fruits = ["Guava"]

n = 7
index = 300
for i in list(range(4)):
    ax = fig.add_subplot(2, 2, i+1)
    ax.plot(np.arange(n), pred_list[i][index][:n], label="Predicted Price", color="orange", marker="o")
    ax.plot(np.arange(n), actual_list[i][index][:n], label="Actual Price", marker="o")
    if i <= 4:
        fruit = fruits[0]
    else:
        fruit = fruits[1]
        
    ax.set_title(f"{markets[i%4]} - {fruit} price forecast (7 days)")
    ax.legend(loc="upper right")

# %% [markdown]
# ### 預測結果評估(rmse, mape, mad)
# - mape : 平均絕對百分比誤差(Mean absolute percentage error)
# - rmse : 均方根差(root-mean-square error)
# - mad : 平均絕對偏差（Mean Absolute Deviation)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# 數值評估
def evaluation_funcs(y_pred, y_true):
    RMSE = round(mean_squared_error(y_pred, y_true, squared=False), 2)
    MAPE = round(np.mean(np.abs((y_true - y_pred) / y_true)) * 100, 2)
    MAD = round(sum(np.abs((y_true - y_pred) / len(y_true))), 2)
    
    return RMSE, MAPE, MAD

# %%
rmse_output = []
mape_output = []
mad_output = []

index = 300

for i in list(range(4)):
    RMSE, MAPE, MAD = evaluation_funcs(pred_list[i][index], actual_list[i][index])
    rmse_output.append(RMSE)
    mape_output.append(MAPE)
    mad_output.append(MAD)

indexs = ['Guava_Taipei1', 'Guava_Taipei2', 'Guava_Sanchong', 'Guava_Taichung']
df_result_evaluation = pd.DataFrame({"RMSE" : rmse_output,
                                     "MAPE" : mape_output,
                                     "MAD" : mad_output}, index= indexs)

df_result_evaluation
# Out:
#                 RMSE  MAPE   MAD
# Guava_Taipei1   0.95  1.45  0.71
# Guava_Taipei2   1.05  1.84  0.90
# Guava_Sanchong  1.14  2.63  1.05
# Guava_Taichung  0.95  1.98  0.79
