# %%
import requests
import pandas as pd
import json

# %%
url = "https://data.coa.gov.tw/Service/OpenData/FromM/TownCropData.aspx"
headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'
            }

res = requests.get(url, headers=headers)
data = json.loads(res.text)

# %%
df = pd.json_normalize(data)
df
# Out:
#        年度   期作   縣市   鄉鎮  作物代碼      作物  收穫面積(公頃)  種植面積(公頃)  每公頃收穫量(公斤)  收量(公斤)
# 0     108   裡作  基隆市  安樂區  470   其他(果菜)      0.27      0.27     10500.0  2835.0
# 1     108  一期作  基隆市  安樂區  470   其他(果菜)      0.11      0.11     10500.0  1155.0
# 2     108  二期作  基隆市  安樂區  470   其他(果菜)      0.29      0.29     11000.0  3190.0
# 3     108   全年  基隆市  安樂區  470   其他(果菜)      0.67      0.67     10716.0  7180.0
# 4     108  一期作  基隆市  安樂區  473       胡瓜      0.07      0.07     11000.0   770.0
# ...   ...  ...  ...  ...   ...     ...       ...       ...         ...     ...
# 9994  108  一期作  苗栗縣  苑裡鎮  301       芝麻      3.60      3.60      1000.0  3600.0
# 9995  108   全年  苗栗縣  苑裡鎮  301       芝麻      3.60      3.60      1000.0  3600.0
# 9996  108  二期作  苗栗縣  苑裡鎮  303      向日葵      0.31      0.31       500.0   155.0
# 9997  108   全年  苗栗縣  苑裡鎮  303      向日葵      0.31      0.31       500.0   155.0
# 9998  108   裡作  苗栗縣  苑裡鎮  425     食用番茄      0.13      0.13     15000.0  1950.0
#
# [9999 rows x 10 columns]

# %%
df.to_csv("data/農情調查(108年各縣市鄉鎮生產概況).csv",index=False)
