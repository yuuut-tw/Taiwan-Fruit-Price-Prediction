# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("cleaned data/價格_全國鳳梨交易資料(初步清洗).csv", usecols=[0, 1, 2, 3, 4, 5, 6, 7])
df.head()
# Out:
#            日期       市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 0  2011-01-01  104 台北二  B2 鳳梨 金鑽鳳梨  29.4  23.0  13.2       22.3     3885
# 1  2011-01-02  104 台北二  B2 鳳梨 金鑽鳳梨  30.1  22.6  12.3       22.1     5468
# 2  2011-01-04  104 台北二  B2 鳳梨 金鑽鳳梨  28.3  21.6  10.1       20.7     5068
# 3  2011-01-05  104 台北二  B2 鳳梨 金鑽鳳梨  27.5  16.9   7.4       17.1     5212
# 4  2011-01-06  104 台北二  B2 鳳梨 金鑽鳳梨  31.4  19.7   9.0       19.9      620

# %%
df["日期"] = pd.to_datetime(df["日期"])

# %%
df["市場"].unique()
# Out:
# array(['104 台北二', '109 台北一', '220 板橋區', '241 三重區', '260 宜蘭市', '338 桃農',
#        '400 台中市', '420 豐原區', '600 嘉義市', '800 高雄市', '830 鳳山區', '930 台東市'],
#       dtype=object)

# %% [markdown]
# ### **台北一市場各年度價格＆交易量**

# %%
df_taipei = df.loc[df["市場"] == "109 台北一"]
df_taipei.head()
# Out:
#              日期       市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 3145 2011-01-01  109 台北一  B2 鳳梨 金鑽鳳梨  34.4  28.1  16.4       27.0     8912
# 3146 2011-01-02  109 台北一  B2 鳳梨 金鑽鳳梨  31.4  25.8  15.8       24.9    20203
# 3147 2011-01-04  109 台北一  B2 鳳梨 金鑽鳳梨  26.0  21.0  13.3       20.5    17912
# 3148 2011-01-05  109 台北一  B2 鳳梨 金鑽鳳梨  25.2  20.9  12.4       20.1     6372
# 3149 2011-01-06  109 台北一  B2 鳳梨 金鑽鳳梨  24.2  20.1  12.1       19.3     4039

# %%
df_taipei.set_index("日期", inplace=True)
df_taipei.head()
# Out:
#                  市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 日期
# 2011-01-01  109 台北一  B2 鳳梨 金鑽鳳梨  34.4  28.1  16.4       27.0     8912
# 2011-01-02  109 台北一  B2 鳳梨 金鑽鳳梨  31.4  25.8  15.8       24.9    20203
# 2011-01-04  109 台北一  B2 鳳梨 金鑽鳳梨  26.0  21.0  13.3       20.5    17912
# 2011-01-05  109 台北一  B2 鳳梨 金鑽鳳梨  25.2  20.9  12.4       20.1     6372
# 2011-01-06  109 台北一  B2 鳳梨 金鑽鳳梨  24.2  20.1  12.1       19.3     4039

# %%
df_taipei_month = df_taipei.resample("M").mean().round(1)
df_taipei_month
# Out:
#               上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 日期
# 2011-01-31  25.2  19.5  12.0       19.1  10167.5
# 2011-02-28  26.9  18.7  11.4       18.9  18469.7
# 2011-03-31  27.9  18.7  12.9       19.4  27227.0
# 2011-04-30  30.4  18.7  12.9       19.9  41889.4
# 2011-05-31  31.7  20.3  12.4       21.0  53212.3
# ...          ...   ...   ...        ...      ...
# 2021-02-28  33.7  21.7  11.3       22.0  14672.6
# 2021-03-31  42.0  31.2  20.0       31.1  35142.3
# 2021-04-30  35.9  24.9  17.6       25.7  47919.2
# 2021-05-31  43.0  28.1  18.3       29.1  39681.8
# 2021-06-30  37.5  19.5  11.0       21.4  40637.2
#
# [126 rows x 5 columns]

# %%
df_taipei_month["Year"] = list(df_taipei_month.reset_index()["日期"].dt.year)
df_taipei_month
# Out:
#               上價    中價    下價  平均價(元/公斤)  交易量(公斤)  Year
# 日期
# 2011-01-31  25.2  19.5  12.0       19.1  10167.5  2011
# 2011-02-28  26.9  18.7  11.4       18.9  18469.7  2011
# 2011-03-31  27.9  18.7  12.9       19.4  27227.0  2011
# 2011-04-30  30.4  18.7  12.9       19.9  41889.4  2011
# 2011-05-31  31.7  20.3  12.4       21.0  53212.3  2011
# ...          ...   ...   ...        ...      ...   ...
# 2021-02-28  33.7  21.7  11.3       22.0  14672.6  2021
# 2021-03-31  42.0  31.2  20.0       31.1  35142.3  2021
# 2021-04-30  35.9  24.9  17.6       25.7  47919.2  2021
# 2021-05-31  43.0  28.1  18.3       29.1  39681.8  2021
# 2021-06-30  37.5  19.5  11.0       21.4  40637.2  2021
#
# [126 rows x 6 columns]

# %%
x = np.arange(1, 13)
y = df_taipei_month.loc[df_taipei_month["Year"] == 2011] # test

# %%
y
# Out:
#               上價    中價    下價  平均價(元/公斤)  交易量(公斤)  Year
# 日期
# 2011-01-31  25.2  19.5  12.0       19.1  10167.5  2011
# 2011-02-28  26.9  18.7  11.4       18.9  18469.7  2011
# 2011-03-31  27.9  18.7  12.9       19.4  27227.0  2011
# 2011-04-30  30.4  18.7  12.9       19.9  41889.4  2011
# 2011-05-31  31.7  20.3  12.4       21.0  53212.3  2011
# 2011-06-30  43.2  30.6  18.1       30.6  39858.9  2011
# 2011-07-31  32.8  20.4  12.2       21.2  35070.8  2011
# 2011-08-31  35.3  21.7  12.0       22.4  12318.2  2011
# 2011-09-30  35.4  24.2  13.6       24.3   8808.0  2011
# 2011-10-31  35.8  23.5  13.2       23.9  10204.9  2011
# 2011-11-30  33.6  24.0  14.1       23.9   9209.5  2011
# 2011-12-31  27.9  21.3  13.6       21.0   7229.0  2011

# %%
x = np.arange(1, 13)
num = 1

fig_test = plt.figure(figsize=(30,20))
    
for year in range(2011, 2021):
    
    y = df_taipei_month.loc[df_taipei_month["Year"] == year]
    #fig,ax1 = plt.subplots(figsize=(4,3))
    
    ax1 = fig_test.add_subplot(4,3,num)
    
    width = 0.2
    ax1.set_xticks(x)
    ax1.bar(x, y["交易量(公斤)"], width=0.4, alpha=0.4)
    ax1.set_xlabel("Month")
    ax1.set_ylabel("Volume(kg)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(x, y["平均價(元/公斤)"], "--", marker="o", color="darkred",label="Average price")
    ax2.set_ylabel("price(NTD/kg)", color="darkred")
    ax2.tick_params(axis="y", labelcolor="darkred")

    #fig.tight_layout()
    plt.title(f"{year} Taipei market (Pineapple)")
    plt.legend()
    
    num+=1
plt.savefig("taipei.jpg")

# %% [markdown]
# ### **台中市場各年度價格＆交易量**

# %%
df_taichung = df.loc[df["市場"] == "400 台中市"]

# %%
df_taichung
# Out:
#               日期       市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 14569 2011-01-01  400 台中市  B2 鳳梨 金鑽鳳梨  21.2  17.3  12.0       17.0    17027
# 14570 2011-01-02  400 台中市  B2 鳳梨 金鑽鳳梨  21.2  18.1  11.7       17.4    23476
# 14571 2011-01-04  400 台中市  B2 鳳梨 金鑽鳳梨  20.7  16.2  10.8       17.6    51764
# 14572 2011-01-05  400 台中市  B2 鳳梨 金鑽鳳梨  20.0  16.9  10.0       17.5    11247
# 14573 2011-01-06  400 台中市  B2 鳳梨 金鑽鳳梨  20.0  15.2  15.0       18.4     2354
# ...          ...      ...         ...   ...   ...   ...        ...      ...
# 17708 2021-06-10  400 台中市  B2 鳳梨 金鑽鳳梨  29.0  18.2   9.7       21.0   163380
# 17709 2021-06-11  400 台中市  B2 鳳梨 金鑽鳳梨  28.5  17.8   8.0       21.1    87697
# 17710 2021-06-12  400 台中市  B2 鳳梨 金鑽鳳梨  28.0  15.2   5.7       20.3    82402
# 17711 2021-06-13  400 台中市  B2 鳳梨 金鑽鳳梨  26.5  16.1   7.4       19.4    85591
# 17712 2021-06-14  400 台中市  B2 鳳梨 金鑽鳳梨  24.1  12.3   6.4       19.2    42877
#
# [3144 rows x 8 columns]

# %%
df_taichung.set_index("日期", inplace=True)
df_taichung
# Out:
#                  市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 日期
# 2011-01-01  400 台中市  B2 鳳梨 金鑽鳳梨  21.2  17.3  12.0       17.0    17027
# 2011-01-02  400 台中市  B2 鳳梨 金鑽鳳梨  21.2  18.1  11.7       17.4    23476
# 2011-01-04  400 台中市  B2 鳳梨 金鑽鳳梨  20.7  16.2  10.8       17.6    51764
# 2011-01-05  400 台中市  B2 鳳梨 金鑽鳳梨  20.0  16.9  10.0       17.5    11247
# 2011-01-06  400 台中市  B2 鳳梨 金鑽鳳梨  20.0  15.2  15.0       18.4     2354
# ...             ...         ...   ...   ...   ...        ...      ...
# 2021-06-10  400 台中市  B2 鳳梨 金鑽鳳梨  29.0  18.2   9.7       21.0   163380
# 2021-06-11  400 台中市  B2 鳳梨 金鑽鳳梨  28.5  17.8   8.0       21.1    87697
# 2021-06-12  400 台中市  B2 鳳梨 金鑽鳳梨  28.0  15.2   5.7       20.3    82402
# 2021-06-13  400 台中市  B2 鳳梨 金鑽鳳梨  26.5  16.1   7.4       19.4    85591
# 2021-06-14  400 台中市  B2 鳳梨 金鑽鳳梨  24.1  12.3   6.4       19.2    42877
#
# [3144 rows x 7 columns]

# %%
df_taichung_month = df_taichung.resample("M").mean()
df_taichung_month
# Out:
#                    上價         中價         下價  平均價(元/公斤)        交易量(公斤)
# 日期
# 2011-01-31  20.640741  16.529630  11.796296  17.792593   18963.407407
# 2011-02-28  18.783333  12.644444   8.355556  16.183333   30647.000000
# 2011-03-31  19.770370  13.303704   9.562963  14.525926   57689.259259
# 2011-04-30  20.036000  13.124000   9.636000  14.200000   94742.400000
# 2011-05-31  23.769231  15.457692  10.453846  16.011538  107679.923077
# ...               ...        ...        ...        ...            ...
# 2021-02-28  23.461111  15.383333   8.688889  16.816667   29417.500000
# 2021-03-31  35.928000  24.268000  13.888000  22.964000   64442.640000
# 2021-04-30  29.728000  20.156000  11.664000  20.428000  102321.080000
# 2021-05-31  34.807692  23.180769  13.492308  23.950000  110492.461538
# 2021-06-30  28.691667  17.866667   8.308333  20.908333  107881.083333
#
# [126 rows x 5 columns]

# %%
df_taichung_month["Year"] = list(df_taichung_month.reset_index()["日期"].dt.year)
df_taichung_month.head()
# Out:
#                    上價         中價         下價  平均價(元/公斤)        交易量(公斤)  Year
# 日期
# 2011-01-31  20.640741  16.529630  11.796296  17.792593   18963.407407  2011
# 2011-02-28  18.783333  12.644444   8.355556  16.183333   30647.000000  2011
# 2011-03-31  19.770370  13.303704   9.562963  14.525926   57689.259259  2011
# 2011-04-30  20.036000  13.124000   9.636000  14.200000   94742.400000  2011
# 2011-05-31  23.769231  15.457692  10.453846  16.011538  107679.923077  2011

# %%
x = np.arange(1, 13)
num = 1

fig_test = plt.figure(figsize=(30,20))
    
for year in range(2011, 2021):
    
    y = df_taichung_month.loc[df_taichung_month["Year"] == year]
    #fig,ax1 = plt.subplots(figsize=(4,3))
    
    ax1 = fig_test.add_subplot(4,3,num)
    
    width = 0.2
    ax1.set_xticks(x)
    ax1.bar(x, y["交易量(公斤)"], width=0.4, alpha=0.4)
    ax1.set_xlabel("Month")
    ax1.set_ylabel("Volume(kg)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(x, y["平均價(元/公斤)"], "--", marker="o", color="darkred",label="Average price")
    ax2.set_ylabel("price(NTD/kg)", color="darkred")
    ax2.tick_params(axis="y", labelcolor="darkred")

    #fig.tight_layout()
    plt.title(f"{year} Taichung market (Pineapple)")
    plt.legend()
    
    num+=1
plt.savefig("taichung.jpg")

# %% [markdown]
# ## 全國市場個年度價格＆交易量

# %%
df_test = pd.read_csv("cleaned data/價格_全國鳳梨交易資料(初步清洗).csv", usecols=[0, 1, 2, 3, 4, 5, 6, 7])
df_test
# Out:
#                日期       市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 0      2011-01-01  104 台北二  B2 鳳梨 金鑽鳳梨  29.4  23.0  13.2       22.3     3885
# 1      2011-01-02  104 台北二  B2 鳳梨 金鑽鳳梨  30.1  22.6  12.3       22.1     5468
# 2      2011-01-04  104 台北二  B2 鳳梨 金鑽鳳梨  28.3  21.6  10.1       20.7     5068
# 3      2011-01-05  104 台北二  B2 鳳梨 金鑽鳳梨  27.5  16.9   7.4       17.1     5212
# 4      2011-01-06  104 台北二  B2 鳳梨 金鑽鳳梨  31.4  19.7   9.0       19.9      620
# ...           ...      ...         ...   ...   ...   ...        ...      ...
# 31491  2021-06-08  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       16.5     3899
# 31492  2021-06-09  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       17.3     3152
# 31493  2021-06-10  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.6  12.0       19.3     4528
# 31494  2021-06-11  930 台東市  B2 鳳梨 金鑽鳳梨  23.0  15.8  11.0       16.7     3258
# 31495  2021-06-12  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.9  13.0       19.7     2757
#
# [31496 rows x 8 columns]

# %%
df_test["日期"] = pd.to_datetime(df_test["日期"])
df_test
# Out:
#               日期       市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 0     2011-01-01  104 台北二  B2 鳳梨 金鑽鳳梨  29.4  23.0  13.2       22.3     3885
# 1     2011-01-02  104 台北二  B2 鳳梨 金鑽鳳梨  30.1  22.6  12.3       22.1     5468
# 2     2011-01-04  104 台北二  B2 鳳梨 金鑽鳳梨  28.3  21.6  10.1       20.7     5068
# 3     2011-01-05  104 台北二  B2 鳳梨 金鑽鳳梨  27.5  16.9   7.4       17.1     5212
# 4     2011-01-06  104 台北二  B2 鳳梨 金鑽鳳梨  31.4  19.7   9.0       19.9      620
# ...          ...      ...         ...   ...   ...   ...        ...      ...
# 31491 2021-06-08  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       16.5     3899
# 31492 2021-06-09  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       17.3     3152
# 31493 2021-06-10  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.6  12.0       19.3     4528
# 31494 2021-06-11  930 台東市  B2 鳳梨 金鑽鳳梨  23.0  15.8  11.0       16.7     3258
# 31495 2021-06-12  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.9  13.0       19.7     2757
#
# [31496 rows x 8 columns]

# %%
df_test.set_index("日期", inplace=True)
df_test
# Out:
#                  市場          產品    上價    中價    下價  平均價(元/公斤)  交易量(公斤)
# 日期
# 2011-01-01  104 台北二  B2 鳳梨 金鑽鳳梨  29.4  23.0  13.2       22.3     3885
# 2011-01-02  104 台北二  B2 鳳梨 金鑽鳳梨  30.1  22.6  12.3       22.1     5468
# 2011-01-04  104 台北二  B2 鳳梨 金鑽鳳梨  28.3  21.6  10.1       20.7     5068
# 2011-01-05  104 台北二  B2 鳳梨 金鑽鳳梨  27.5  16.9   7.4       17.1     5212
# 2011-01-06  104 台北二  B2 鳳梨 金鑽鳳梨  31.4  19.7   9.0       19.9      620
# ...             ...         ...   ...   ...   ...        ...      ...
# 2021-06-08  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       16.5     3899
# 2021-06-09  930 台東市  B2 鳳梨 金鑽鳳梨  22.0  15.8  10.0       17.3     3152
# 2021-06-10  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.6  12.0       19.3     4528
# 2021-06-11  930 台東市  B2 鳳梨 金鑽鳳梨  23.0  15.8  11.0       16.7     3258
# 2021-06-12  930 台東市  B2 鳳梨 金鑽鳳梨  25.0  18.9  13.0       19.7     2757
#
# [31496 rows x 7 columns]

# %%
output = df_test.resample("M").mean().round(1)

# %%
# 參考
output["Year"] = list(output.reset_index()["日期"].dt.year)
output
# Out:
#               上價    中價    下價  平均價(元/公斤)  交易量(公斤)  Year
# 日期
# 2011-01-31  23.9  18.6  12.7       18.7   8113.9  2011
# 2011-02-28  23.6  17.3  11.3       17.8  13718.5  2011
# 2011-03-31  23.1  16.5  11.8       16.9  21761.3  2011
# 2011-04-30  23.6  16.2  11.5       16.7  34524.0  2011
# 2011-05-31  25.0  17.3  12.0       17.8  39250.9  2011
# ...          ...   ...   ...        ...      ...   ...
# 2021-02-28  24.0  16.5  11.2       16.9   8670.9  2021
# 2021-03-31  31.8  22.9  16.5       23.1  17813.7  2021
# 2021-04-30  28.2  20.0  13.9       20.3  27624.3  2021
# 2021-05-31  32.4  22.5  15.4       22.9  25135.6  2021
# 2021-06-30  27.7  17.3  10.9       18.1  24294.7  2021
#
# [126 rows x 6 columns]

# %%
output["year"] = list(output.reset_index()["日期"].dt.year)

# %%
output[output["Year"] == 2011]
# Out:
#               上價    中價    下價  平均價(元/公斤)  交易量(公斤)  Year  year
# 日期
# 2011-01-31  23.9  18.6  12.7       18.7   8113.9  2011  2011
# 2011-02-28  23.6  17.3  11.3       17.8  13718.5  2011  2011
# 2011-03-31  23.1  16.5  11.8       16.9  21761.3  2011  2011
# 2011-04-30  23.6  16.2  11.5       16.7  34524.0  2011  2011
# 2011-05-31  25.0  17.3  12.0       17.8  39250.9  2011  2011
# 2011-06-30  35.4  25.7  17.3       26.1  29675.4  2011  2011
# 2011-07-31  27.6  19.4  12.3       19.9  23958.6  2011  2011
# 2011-08-31  27.2  18.7  11.5       19.4  14211.6  2011  2011
# 2011-09-30  27.5  19.1  11.7       20.0  10077.1  2011  2011
# 2011-10-31  29.5  20.4  12.0       21.1   9641.2  2011  2011
# 2011-11-30  28.3  20.8  13.3       21.1   8020.2  2011  2011
# 2011-12-31  25.1  19.6  13.8       19.7   6164.7  2011  2011

# %%
x = np.arange(1, 13)
num = 1

fig_test = plt.figure(figsize=(30,20))
    
for year in range(2011, 2021):
    
    y = output.loc[output["Year"] == year]
    ax1 = fig_test.add_subplot(4,3,num)
    
    width = 0.2
    ax1.set_xticks(x)
    ax1.bar(x, y["交易量(公斤)"], width=0.4, alpha=0.4)
    ax1.set_xlabel("Month")
    ax1.set_ylabel("Volume(kg)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")

    ax2 = ax1.twinx()
    ax2.plot(x, y["平均價(元/公斤)"], "--", marker="o", color="darkred",label="Average price")
    ax2.set_ylabel("price(NTD/kg)", color="darkred")
    ax2.tick_params(axis="y", labelcolor="darkred")

    #fig.tight_layout()
    plt.title(f"{year} Pineapple market overall")
    plt.legend(loc="upper left")
    
    num+=1
    
plt.savefig("全國鳳梨各年度價格＆交易量.jpg")
