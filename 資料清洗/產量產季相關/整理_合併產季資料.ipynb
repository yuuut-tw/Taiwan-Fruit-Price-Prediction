# %%
import pandas as pd

# %% [markdown]
# ## 合併產季資料（可參考性低，資料中看不出大小月）

# %%
df = pd.read_csv("../data/產量_台灣水果產季(月份&分布).csv")
df.head()
# Out:
#   type  month crop variety county town
# 0   水果      1   椪柑     NaN    苗栗縣  卓蘭鎮
# 1   水果      1   椪柑     NaN    台中市  東勢區
# 2   水果      1   椪柑     NaN    雲林縣  古坑鄉
# 3   水果      1   椪柑     NaN    嘉義縣  番路鄉
# 4   水果      1   椪柑     NaN    嘉義縣  梅山鄉

# %%
t = df.loc[df["crop"] == "香蕉"]

# %%
t.groupby(["month","county"]).count()
# Out:
#               type  crop  variety  town
# month county
# 1     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 2     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 3     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 4     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 5     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 6     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 7     南投縣        4     4        4     4
#       屏東縣        3     3        3     3
#       高雄市        2     2        2     2
# 8     南投縣        4     4        4     4
# ...
